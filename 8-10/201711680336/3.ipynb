# %%
#练习 2：写程序，可由键盘读入两个整数m与n(n不等于0)，
#询问用户意图，
#如果要求和则计算从m到n的和输出，
#如果要乘积则计算从m到n的积并输出，
#如果要求余数则计算m除以n的余数的值并输出，
#否则则计算m整除n的值并输出。
m=int(input('输入第一个整数'))
n=int(input('输入第二个非零整数'))
c=input('求和请输入+，求积请输入*，求余数请输入%，求商请输入/')
if c=='+':
    sum=(m+n)*abs(n-m+1)/2
    print(sum)
elif c=='*':
    if m>n:
        i=n
        j=n
        while i<m:
            i +=1
            j *=i
        print(j)
    elif m<n:
        i=m
        k=m
        while i<n:
            i +=1
            k *=i
        print(k)
elif c=='%':
    print(m%n)
elif c=='/':
    print(m/n)
# Out:
# 输入第一个整数2
# 输入第二个非零整数4
# 求和请输入+，求积请输入*，求余数请输入%，求商请输入/+
# 9.0

# %%
#练习 4：英文单词单数转复数，
#要求输入一个英文名词（单数形式），能够得到其复数形式，或给出单数转复数形式的建议
#（提示，some_string.endswith(some_letter)函数可以判断某字符串结尾字符，
#可尝试运行：'myname'.endswith('me')，liupengyuan'.endswith('n')）。
noun = input('请输入一个英语名词,回车结束。')
if noun.endswith('s'):  
    t=str('es')
    print(noun+t)
elif noun.endswith('sh'):
    t=str('es')
    print(noun+t)
elif noun.endswith('ch'):
    t=str('es')
    print(noun+t)
elif noun.endswith('x'):
    t=str('es')
    print(noun+t)
elif noun.endswith('o'):
    print('该名词变为复数时根据前字母可能加s或es')
elif noun.endswith('f'): 
    print('该名词变为复数通常把末尾的f变为v加es')
elif noun.endswith('fe'): 
    print('该名词变为复数时通常把末尾的fe变为v加es')
else:
    t=str('s')
    print(noun+t)
# Out:
# 请输入一个英语名词,回车结束。apple
# apples
