# %%
import random

def menu():
    print(
        '''
             =====游戏菜单=====
                1. 游戏说明
                2. 开始古诗游戏
                3. 退出游戏
             =====游戏菜单=====''')

def show_instruction():
    print(
        '''
      ======欢迎来到和古诗游戏=======
        
                     /  \     ,    ,
           _._     _ |oo| _  / \__/ \
    
          _||||   ((/ () \))   /   \
    
          |||||/|  ( ==== )    |oo|    
           \____/  _`\  /'_    /   \
    
           /   /.-' /\<>/\ `\.( () )_._      
           |    `  /  \/  \  /`'--'////)
            \__,-'`|  |.  |\/ |/\/\|"\"` 
                   |  |.  | \___/\___/  
                   |  |.  |   |    |
       你需要根据给出的多个汉字猜测正确的
                  古诗       
      ======欢迎来到古诗游戏=======
        '''
    )
    
def win():
    print(
        '''
           ======恭喜你，你赢了=======
        
    
                ."".    ."",
                |  |   /  /
                |  |  /  /
                |  | /  /
                |  |/  ;-._ 
                }  ` _/  / ;
                |  /` ) /  /
                | /  /_/\_/\
                |/  /      |
                (  ' \ '-  |
                 \    `.  /
                  |      |
                  |      |
          
          ======恭喜你，你赢了=======
        '''
    )
    
def lose():
    print(
        '''
           ======YOU LOSE=======
        
    
                

                   .-"      "-.
                  /            \
                 |              |
                 |,  .-.  .-.  ,|
                 | )(__/  \__)( |
                 |/     /\     \|
       (@_       (_     ^^     _)
  _     ) \_______\__|IIIIII|__/__________________________
 (_)@8@8{}<________|-\IIIIII/-|___________________________>
        )_/        \          /
       (@           `--------`
       
       
       
          ======YOU LOSE=======
        '''
    )
    
def game_over():
    print(
        '''
           ======GAME OVER=======
        
             _________ 
            / ======= \ 
           / __________\ 
          | ___________ | 
          | | -       | | 
          | |         | | 
          | |_________| |________________ 
          \=____________/                ) 
          / """"""""""" \               / 
         / ::::::::::::: \          =D-' 
        (_________________) 

       
          ======GAME OVER=======
        '''
    )
    
def get_ch_table(line):
    ch_table = []
    for ch in line:
        if ch not in ch_table:
            ch_table.append(ch)
    return ch_table

fh=open(r"d:\temp\五言诗库.txt")
text = fh.read()
idioms = text.split()
idiom = random.choice(idioms)
chs = get_ch_table(text.replace('\n', ' '))
print(len(chs),chs)

guess_ch_table = [ch for ch in idiom]
while len(guess_ch_table) < 14:
    ch = random.choice(chs)
    if ch not in guess_ch_table:
        guess_ch_table.append(ch)
        
random.shuffle(guess_ch_table)
    
for i in range(0,14,2):
    print(guess_ch_table[i], guess_ch_table[i+1])

    

def guess_game(game):
    
    score = 10
    while score >= 0:
        answer_idiom = input('请输入猜测诗句，回车结束，直接回车表示退出游戏：')
        if answer_idiom in  chs:
            print('答对了，加十分')
            score += 10
            print('你当前的分数是：', score)
            if score == 100:
                win()
                reture

        else:
            print('答错了，减十分')
            score=score-10
            print('你当前的分数是：',score)

    
def main():
    while True:
        menu()
        choice = int(input('请输入你的选择（回车）'))
        if choice == 1:
            show_instruction()
        elif choice == 2:
            game = 2
            guess_game(game)
        elif choice == 3:
            game_over()
            break

main()
# Out:
# 1351 ['绝', '代', '有', '佳', '人', '，', '幽', '居', '在', '空', '谷', '。', ' ', '自', '云', '良', '家', '子', '零', '落', '依', '草', '木', '关', '中', '昔', '丧', '乱', '兄', '弟', '遭', '杀', '戮', '官', '高', '何', '足', '论', '不', '得', '收', '骨', '肉', '世', '情', '恶', '衰', '歇', '万', '事', '随', '转', '烛', '夫', '婿', '轻', '薄', '儿', '新', '美', '如', '玉', '合', '昏', '尚', '知', '时', '鸳', '鸯', '独', '宿', '但', '见', '笑', '那', '闻', '旧', '哭', '山', '泉', '水', '清', '出', '浊', '侍', '婢', '卖', '珠', '回', '牵', '萝', '补', '茅', '屋', '摘', '花', '插', '发', '采', '柏', '动', '盈', '掬', '天', '寒', '翠', '袖', '日', '暮', '倚', '修', '竹', '死', '别', '已', '吞', '声', '生', '常', '恻', '江', '南', '瘴', '疠', '地', '逐', '客', '无', '消', '息', '故', '入', '我', '梦', '明', '长', '相', '忆', '君', '今', '罗', '网', '以', '羽', '翼', '恐', '非', '平', '魂', '路', '远', '可', '测', '来', '枫', '林', '青', '返', '塞', '黑', '月', '满', '梁', '犹', '疑', '照', '颜', '色', '深', '波', '浪', '阔', '使', '蛟', '龙', '浮', '终', '行', '游', '久', '至', '三', '夜', '频', '亲', '意', '告', '归', '局', '促', '苦', '道', '易', '湖', '多', '风', '舟', '楫', '失
# ...

# %%
import itertools
import re
text = ("白","日","依","山","尽")
guesses = itertools.permutations(text, 5)
fh = open(r"d:\temp\五言诗库.txt")
text= fh.read()
textplace=text.replace('\n','')
poems=re.split('，|。',textplace)
fh.close()
your_guess=input('输入你猜的五言诗为：')
for guess in guesses:
    if ''.join(guess) in poems:
        correct=''.join(guess)
        print('答案是：', guess)
if your_guess==correct:
    print('你太棒了，猜对了')
else:
    print('别灰心，再来一次！')
# Out:
# 输入你猜的五言诗为：白日依山尽
# 答案是： ('白', '日', '依', '山', '尽')
# 你太棒了，猜对了
