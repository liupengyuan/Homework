# %%
#写函数，返回一个list中所有数字的和
numbers=[]


#写函数，返回某个元素/对象在一个list中的位置，如果不在，则返回-1.


print(sum(numbers))
# Out:
# 请输入list中元素的个数5
# 请输入一个数1
# 请输入一个数2
# 请输入一个数3
# 请输入一个数4
# 请输入一个数5
# 15

# %%
#写函数，返回一个list中最小的数
numbers=[]

n=int(input('请输入list中元素的个数'))
for i in range(n):
    word=int(input('请输入一个数'))
    numbers.append(word)
print(min(numbers))
# Out:
# 请输入list中元素的个数5
# 请输入一个数134
# 请输入一个数5
# 请输入一个数32
# 请输入一个数4
# 请输入一个数2
# 2

# %%
#写函数，返回某个元素/对象在一个list中的位置，如果不在，则返回-1.
number=[]
i=0
n=int(input('请输入list中的元素的个数'))

for i in range(n):
    word=input('请输入一个元素')
    number.append(word)
    
m=input('请输入你要搜索的元素')

if m in number:
    number.index(m)
    print('这个元素的位置为',number.index(m))
else:
    print('list中不存在该对象,函数返回值为：-1')
# Out:
# 请输入list中的元素的个数5
# 请输入一个元素sa
# 请输入一个元素sasad
# 请输入一个元素asasadad
# 请输入一个元素dasda
# 请输入一个元素dada
# 请输入你要搜索的元素sa
# 这个元素的位置为 0

# %%
#写函数，可求两个向量的夹角余弦值，向量可放在list中。主程序调用该函数。
??????
# Out:
# Object `` not found.

# %%
#挑战性习题：python语言老师为了激励学生学python，自费买了100个完全相同的Macbook Pro，分给三个班级，每个班级至少分5个，用穷举法计算共有多少种分法？
for i in range(5,91):
    for m in range(5,96-i):
        n=100-i-m
        print('一班分得',i,'个','二班分得',m,'个','三班分得',n,'个')
# Out:
# 一班分得 5 个 二班分得 5 个 三班分得 90 个
# 一班分得 5 个 二班分得 6 个 三班分得 89 个
# 一班分得 5 个 二班分得 7 个 三班分得 88 个
# 一班分得 5 个 二班分得 8 个 三班分得 87 个
# 一班分得 5 个 二班分得 9 个 三班分得 86 个
# 一班分得 5 个 二班分得 10 个 三班分得 85 个
# 一班分得 5 个 二班分得 11 个 三班分得 84 个
# 一班分得 5 个 二班分得 12 个 三班分得 83 个
# 一班分得 5 个 二班分得 13 个 三班分得 82 个
# 一班分得 5 个 二班分得 14 个 三班分得 81 个
# 一班分得 5 个 二班分得 15 个 三班分得 80 个
# 一班分得 5 个 二班分得 16 个 三班分得 79 个
# 一班分得 5 个 二班分得 17 个 三班分得 78 个
# 一班分得 5 个 二班分得 18 个 三班分得 77 个
# 一班分得 5 个 二班分得 19 个 三班分得 76 个
# 一班分得 5 个 二班分得 20 个 三班分得 75 个
# 一班分得 5 个 二班分得 21 个 三班分得 74 个
# 一班分得 5 个 二班分得 22 个 三班分得 73 个
# 一班分得 5 个 二班分得 23 个 三班分得 72 个
# 一班分得 5 个 二班分得 24 个 三班分得 71 个
# 一班分得 5 个 二班分得 25 个 三班分得 70 个
# 一班分得 5 个 二班分得 26 个 三班分得 69 个
# 一班分得 5 个 二班分得 27 个 三班分得 68 个
# 一班分得 5 个 二班分得 28 个 三班分得 67 个
# 一班分得 5 个 二班分得 29 个 三班分得 66 个
# 一班分得 5 个 二班分得 30 个 三班分得 65 个
# 一班分得 5 个 二班分得 31 个 三班分得 64 个
# 一班分得 5 个 二班分得 32 个 三班分得 63 个
# 一班分得 5 个 二班分得 33 个 三班分得 62 个
# 一班分得 5 个 二班分得 34 个 三班分得 61 个
# 一班分得 5 个 二班分得 35 个 三班分得 60 个
# 一班分得 5 个 二班分得 36 个 三班分得 59 个
# ...
