# %%
#练习一
numbers = []
n = int(input('请输入一个整数，表示list中的数字个数:'))
def sum_num(n):
    i = 0
    total=0
    while i < n:
        num =int(input('请输入一个随机数，回车结束:'))
        numbers.append(num)
        i += 1
        total=total+num
    print(numbers)
    return(total)
print('和为:',sum_num(num))
# Out:
# 请输入一个整数，表示list中的数字个数:4
# 请输入一个随机数，回车结束:1
# 请输入一个随机数，回车结束:2
# 请输入一个随机数，回车结束:3
# 请输入一个随机数，回车结束:4
# [1, 2, 3, 4]
# 和为: 10

# %%
#练习二
numbers = []
n = int(input('请输入一个整数，表示list中的数字个数:'))
i = 0
total=0
while i < n:
    num =int(input('请输入一个随机数，回车结束:'))
    numbers.append(num)
    i += 1
def min_numer(num):
    list_min = numbers[0]
    for num in numbers:
        if list_min > num:
            list_min = num
    return list_min
print('最小值为:',min(numbers))
# Out:
# 请输入一个整数，表示list中的数字个数:3
# 请输入一个随机数，回车结束:2
# 请输入一个随机数，回车结束:3
# 请输入一个随机数，回车结束:4
# 最小值为: 2

# %%
#练习三
list1=[1,3,5,6]
list2=[1,2,3,4]
n=input('请输入一个10以内的随机整数:')
print('列表为:',list1)
if n in list1:
    print(list2[n])
else:
    print('-1','该数不在列表中')
# Out:
# 请输入一个10以内的随机整数:4
# 列表为: [1, 3, 5, 6]
# -1 该数不在列表中

# %%
#练习四
a=int(input('请输入任意整数:'))
b=int(input('请输入任意整数:'))
c=int(input('请输入任意整数:'))
d=int(input('请输入任意整数:'))
n=a*c+b*d
q=(a**2+b**2)**1/2
f=(c**2+d**2)**1/2
s=n/(q+f)
print('向量j为:',(a,b))
print('向量k为:',(c,d))
print('余弦值为:',s)
# Out:
# 请输入任意整数:1
# 请输入任意整数:2
# 请输入任意整数:3
# 请输入任意整数:4
# 向量j为: (1, 2)
# 向量k为: (3, 4)
# 余弦值为: 0.7333333333333333

# %%
#挑战性习题
sum_method=1
a_num=0
b_num=0
c_num=0
for i in range(5,91):
    a_num=i
    for j in range(5,96-i):
        b_num=j
        c_num=100-i-j
        print("第%d种方法，每班分别为：%d %d %d" %(sum_method,a_num,b_num,c_num))
        sum_method+=1
print("一共有%d种分开的方法" %(sum_method-1))
# Out:
# 第1种方法，每班分别为：5 5 90
# 第2种方法，每班分别为：5 6 89
# 第3种方法，每班分别为：5 7 88
# 第4种方法，每班分别为：5 8 87
# 第5种方法，每班分别为：5 9 86
# 第6种方法，每班分别为：5 10 85
# 第7种方法，每班分别为：5 11 84
# 第8种方法，每班分别为：5 12 83
# 第9种方法，每班分别为：5 13 82
# 第10种方法，每班分别为：5 14 81
# 第11种方法，每班分别为：5 15 80
# 第12种方法，每班分别为：5 16 79
# 第13种方法，每班分别为：5 17 78
# 第14种方法，每班分别为：5 18 77
# 第15种方法，每班分别为：5 19 76
# 第16种方法，每班分别为：5 20 75
# 第17种方法，每班分别为：5 21 74
# 第18种方法，每班分别为：5 22 73
# 第19种方法，每班分别为：5 23 72
# 第20种方法，每班分别为：5 24 71
# 第21种方法，每班分别为：5 25 70
# 第22种方法，每班分别为：5 26 69
# 第23种方法，每班分别为：5 27 68
# 第24种方法，每班分别为：5 28 67
# 第25种方法，每班分别为：5 29 66
# 第26种方法，每班分别为：5 30 65
# 第27种方法，每班分别为：5 31 64
# 第28种方法，每班分别为：5 32 63
# 第29种方法，每班分别为：5 33 62
# 第30种方法，每班分别为：5 34 61
# 第31种方法，每班分别为：5 35 60
# 第32种方法，每班分别为：5 36 59
# 第33种方法，每班分别为：5 37 58
# 第34种方法，每班分别为：5 38 57
# 第35种方法，每班分别为：5 39 56
# 第36种方法，每班分别为：5 40 55
# 第37种方法，每班分别为：5 41 54
# 第38种方法，每班分别为：5 42 53
# 第39种方法，每班分别为：5 43 52
# 第40种方法，每班分别为：5 44 51
# 第41种方法，每班分别为：5 45 50
# 第42种方法，每班分别为：5 46 49
# 第43种方法，每班分别为：5 47 48
# 第44种方法，每班分别为：5 48 47
# ...
