# %%
#2、随机生成1万个整数，范围在0-10万之间，求其中每个整数出现的次数。并按照整数大小排序输出整数及出现次数。
import random

def sort(seq):
    
    seq.sort()
    
    int_freq_pairs = []
    for num in seq:
        for item in int_freq_pairs:
            if num == item[0]:
                item[1]+=1
                break
        else:
            int_freq_pairs.append([num,1])
        
    return int_freq_pairs

seq = [random.randint(0,100001) for i in range(10000)]
print(sort(seq))
# Out:
# [[19, 1], [25, 1], [47, 1], [70, 1], [74, 1], [79, 1], [109, 1], [112, 1], [127, 1], [129, 1], [134, 1], [136, 1], [137, 1], [139, 1], [158, 1], [159, 1], [175, 1], [200, 1], [211, 1], [214, 1], [234, 1], [248, 1], [255, 1], [261, 1], [301, 1], [318, 1], [326, 1], [337, 1], [338, 1], [343, 1], [356, 1], [396, 1], [402, 1], [414, 1], [425, 1], [443, 1], [469, 1], [502, 1], [519, 1], [524, 1], [553, 1], [574, 1], [585, 1], [586, 1], [590, 1], [591, 1], [606, 1], [621, 1], [625, 1], [628, 1], [632, 1], [637, 1], [642, 1], [644, 1], [655, 1], [656, 1], [678, 1], [689, 1], [694, 1], [706, 1], [714, 1], [722, 2], [726, 1], [733, 1], [752, 1], [759, 1], [765, 1], [784, 1], [791, 1], [799, 1], [810, 1], [817, 1], [822, 1], [823, 1], [830, 1], [844, 1], [881, 1], [887, 1], [891, 1], [892, 1], [900, 1], [905, 1], [908, 1], [916, 1], [922, 1], [926, 1], [937, 1], [940, 1], [957, 1], [996, 1], [1004, 1], [1009, 1], [1036, 1], [1058, 1], [1059, 1], [1063, 1], [1071, 1], [1095, 1], [1096, 1], [109
# ...

# %%
#对本任务中的语料.txt文件，随机抽取其5001-10000行存为test1.txt文件，写函数，可得到其与本任务中test.txt文件的共用字以及独用字（相关概念自行百度）。
with open(r'd:\temp\test.txt', 'w') as fw, open(r'd:\temp\语料.txt') as fr:
    line_number=0
    for line in fr:
        if 5001<line_number<10000:
            fw.write(line)
            line_number +=1
        
           
        else:
            break
   
            
    fw.close(),fr.close()
        
def count_words_freq():
    word_freq_pairs = []
    with open(r'd:\temp\test.txt', 'w') as fw, open(r'd:\temp\语料.txt') as fr:
   
        text2=fr.read()
        words2=[word.split('/')[0] for word in text2.split()]
    
    
    
    
        text1=fw.read()
        words1=[word.split('/')[0] for word in text1.split()]
       
        for word in words1:
            for item in words2:
                if word==item[0]:
                    item[1]+=1
                    break
                    
                else:
                    word_freq_pairs.append([word,1])
                
                
        print([word,item[1]])
        return word_freq_pairs
    
    
    
print(count_words_freq())
