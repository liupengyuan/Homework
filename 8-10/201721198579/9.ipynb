# %%
#2、随机生成1万个整数，范围在0-10万之间，求其中每个整数出现的次数。并按照整数大小排序输出整数及出现次数。

import random
from operator import itemgetter
def random_list():
    length=10000
    random_list=[]
    for i in range(0,length):
        random_list.append(random.randint(0,10000))
    return random_list

#传入随机数数组
def get_word_table(random_list):
    word_list=[]
    for num in random_list:
        if num not in word_list:
            word_list.append(num)
    return word_list

#传入不同数字的数组
def count_number(word_list,random_list):
    count_list=[]
    for num in word_list:
        countnum=random_list.count(num)
        count_list.append([num,countnum])
    return count_list

#排序
def sortlist(count_list):
    count_list.sort(key=itemgetter(1))
    return count_list
  
randomlist=[]
wordlist=[]
countlist=[]

randomlist=random_list()  
wordlist=get_word_table(randomlist)
countlist=count_number(wordlist,randomlist)
countlist=sortlist(countlist)
print(countlist)
# Out:
# [[7927, 1], [2392, 1], [8337, 1], [234, 1], [8131, 1], [2110, 1], [3630, 1], [1886, 1], [3101, 1], [7435, 1], [5520, 1], [8739, 1], [9942, 1], [9418, 1], [4981, 1], [566, 1], [2642, 1], [4030, 1], [7614, 1], [9059, 1], [1094, 1], [9737, 1], [8676, 1], [3744, 1], [9454, 1], [7875, 1], [7482, 1], [6428, 1], [3533, 1], [7696, 1], [1425, 1], [7431, 1], [1954, 1], [2002, 1], [5776, 1], [2792, 1], [6347, 1], [3959, 1], [9202, 1], [3822, 1], [292, 1], [9257, 1], [2920, 1], [110, 1], [4524, 1], [4999, 1], [9961, 1], [3115, 1], [7982, 1], [8838, 1], [9424, 1], [9875, 1], [5358, 1], [5930, 1], [4034, 1], [2553, 1], [8136, 1], [8921, 1], [197, 1], [7874, 1], [2237, 1], [4241, 1], [8309, 1], [4780, 1], [4895, 1], [3866, 1], [7746, 1], [9253, 1], [6943, 1], [9646, 1], [6963, 1], [4000, 1], [7574, 1], [4532, 1], [7728, 1], [4786, 1], [2695, 1], [2803, 1], [6058, 1], [8410, 1], [2899, 1], [2715, 1], [6258, 1], [4056, 1], [4533, 1], [974, 1], [3140, 1], [2364, 1], [6613, 1], [5388, 1], [7104, 1], [2
# ...

# %%
#3、对本任务中的语料.txt文件，随机抽取其5001-10000行存为test1.txt文件，写函数，可得到其与本任务中test.txt文件的共用字以及独用字（相关概念自行百度）。

from operator import itemgetter
with open(r'E:\python作业\语料\test.txt', 'w') as fw, open(r'E:\python作业\语料\语料.txt','r') as fr:
    line_number = 0
    for line in fr:
        if line_number > 5000 and line_number < 10000:
            fw.write(line)
        line_number += 1
        if line_number >10001:
            break

def count_words_freq(filename):
    word_freq_pairs = []
    
    with open(filename) as f:
        text = f.read() 
    words = [word.split('/')[0] for word in text.split()]
    for word in words:
        for item in word_freq_pairs:
            if word == item[0]:
                item[1] += 1
                break
        else:
            word_freq_pairs.append([word, 1])
    return word_freq_pairs

filename = r'E:\python作业\语料\test.txt'
table = count_words_freq(filename)
table.sort(key=itemgetter(1))
print(len(table))
print(table[len(table)-2])
print(table[0])
# Out:
# 25538
# ['的', 8139]
# ['工龄', 1]
