# %% [markdown]
# #2.随机生成1万个整数，范围在0-10万之间，求其中每个整数出现的次数。并按照整数大小排序输出整数及出现次数。

# %%
import random
from collections import defaultdict
def count_n(nums):
    num_freq_dict = defaultdict(int)
    for num in nums:
        num_freq_dict[num] += 1    
    return num_freq_dict 
def main():
    nums=[random.randint(0,10000) for x in range(10000)]
    nums.sort(reverse=True) 
    print(count_n(nums))
if __name__ == '__main__':
    main()
# Out:
# defaultdict(<class 'int'>, {10000: 2, 9998: 1, 9997: 1, 9995: 1, 9994: 2, 9993: 1, 9992: 1, 9989: 1, 9987: 1, 9986: 1, 9985: 1, 9984: 1, 9982: 1, 9981: 2, 9979: 1, 9977: 2, 9976: 2, 9975: 1, 9974: 1, 9973: 1, 9971: 1, 9970: 1, 9969: 4, 9964: 2, 9962: 1, 9961: 1, 9957: 1, 9956: 1, 9955: 2, 9952: 1, 9951: 1, 9950: 1, 9948: 1, 9947: 1, 9945: 1, 9944: 4, 9943: 2, 9940: 1, 9938: 1, 9937: 2, 9936: 2, 9935: 2, 9933: 1, 9931: 2, 9930: 3, 9929: 3, 9928: 1, 9927: 2, 9926: 1, 9924: 1, 9923: 2, 9921: 1, 9920: 4, 9918: 1, 9916: 1, 9915: 2, 9914: 2, 9913: 3, 9910: 1, 9909: 1, 9906: 1, 9904: 1, 9903: 1, 9902: 3, 9901: 1, 9900: 2, 9898: 3, 9896: 1, 9895: 3, 9894: 1, 9891: 1, 9890: 1, 9887: 2, 9885: 1, 9884: 1, 9881: 1, 9880: 2, 9879: 2, 9877: 1, 9876: 2, 9874: 1, 9873: 2, 9872: 1, 9871: 1, 9870: 3, 9868: 2, 9866: 1, 9864: 1, 9863: 2, 9862: 1, 9861: 2, 9859: 2, 9858: 2, 9856: 3, 9855: 2, 9853: 2, 9851: 1, 9849: 1, 9848: 1, 9843: 2, 9842: 2, 9841: 1, 9839: 1, 9838: 1, 9837: 1, 9836: 2, 9834: 1, 9833: 
# ...

# %% [markdown]
# #3.对本任务中的语料.txt文件，随机抽取其5001-10000行存为test1.txt文件，写函数，可得到其与本任务中test.txt文件的共用字以及独用字（相关概念自行百度）。

# %%
def GetSet(filename):
    word_table = set()
    with open(filename) as f:
        for line in f:
            word_table |= {word.split('/')[0] for word in line.split()}  
    return word_table

def main():
    f1 = r'e:\yanyi\Python\text.txt'
    f2 = r'e:\yanyi\Python\text1.txt'
    set0=GetSet(f1)
    set1=GetSet(f2)
    print('共用字集合：')
    print(set0|set1)
    print('test.txt 独用字集合：')
    print(set0-set1)
    print('test1.txt 独用字集合：')
    print(set1-set0)


if __name__ == '__main__':
    main()
# Out:
# 共用字集合：
# ...
