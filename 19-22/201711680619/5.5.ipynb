# %% [markdown]
# # 练习 1：写函数，求n个随机整数均值的平方根，整数范围在m与k之间（n,m,k由用户输入）。

# %%
import random,math

n=int(input())
m=int(input())
k=int(input())

i = 0
while i<n:
    a=random.randint(m,k)
    print(a)
    i += 1
print(math.sqrt(a/n))
# Out:
# 3
# 2
# 5
# 3
# 2
# 4
# 1.1547005383792515

# %% [markdown]
# # 练习 2：写函数，共n个随机整数，整数范围在m与k之间，（n,m,k由用户输入）。求1：西格玛log(随机整数)，2：西格玛1/log(随机整数)

# %%
import random,math

n=int(input())
m=int(input())
k=int(input())

i = 0
b = 0
while i<n:
    a=random.randint(m,k)
    print(a)
    c = math.log(a)
    b = b+c
    i +=1
    
print(b)
print(1/(b))
# Out:
# 3
# 2
# 5
# 2
# 3
# 2
# 2.4849066497880004
# 0.40242960438184466

# %% [markdown]
# # 练习 3：写函数，求s=a+aa+aaa+aaaa+aa...a的值，其中a是[1,9]之间的随机整数。例如2+22+222+2222+22222(此时共有5个数相加)，几个数相加由键盘输入。

# %%
import random,math

n = int(input())
a = random.randint(1,9)
s = 0
i = 0
m = 0

while i<n:
    b = 10**m*a+s
    s = b+s
    m +=1
    i +=1
print(s)
# Out:
# 2
# 24

# %% [markdown]
# # 挑战性练习：仿照task5，将猜数游戏改成由用户随便选择一个整数，让计算机来猜测的猜数游戏，要求和task5中人猜测的方法类似，但是人机角色对换，由人来判断猜测是大、小还是相等，请写出完整的猜数游戏。

# %%
import random,math
def menu():
    print('''           =====游戏菜单=====
                1. 游戏说明
                2. 开始游戏
                3. 退出游戏
                4. 制作团队
             =====游戏菜单=====''')
    
def welcome():
    print(
        '''
           ======欢迎来到人机大战=======
        
                     /  \     ,    ,
           _._     _ |oo| _  / \__/ \
    
          _||||   ((/ () \))   /   \
    
          |||||/|  ( ==== )    |oo|    
           \____/  _`\  /'_    /   \
    
           /   /.-' /\<>/\ `\.( () )_._      
           |    `  /  \/  \  /`'--'////)
            \__,-'`|  |.  |\/ |/\/\|"\"` 
                   |  |.  | \___/\___/  
                   |  |.  |   |    |
          
          ======欢迎来到人机大战=======
        ''' )
    
def show_instruction():
    print('这是场人机殊死搏斗！')
def win():
    print(
        '''
           ======大吉大利，人类才是地球的统治者！=======
        
    
                ."".    ."",
                |  |   /  /
                |  |  /  /
                |  | /  /
                |  |/  ;-._ 
                }  ` _/  / ;
                |  /` ) /  /
                | /  /_/\_/\
                |/  /      |
                (  ' \ '-  |
                 \    `.  /
                  |      |
                  |      |
          
          ======大吉大利，人类才是地球的统治者！=======
        '''
    )
    
def lose():
    print(
        '''
           ======完了，人类要被计算机统治了QAQ=======
        
    
                

                   .-"      "-.
                  /            \
                 |              |
                 |,  .-.  .-.  ,|
                 | )(__/  \__)( |
                 |/     /\     \|
       (@_       (_     ^^     _)
  _     ) \_______\__|IIIIII|__/__________________________
 (_)@8@8{}<________|-\IIIIII/-|___________________________>
        )_/        \          /
       (@           `--------`
       
       
       
          =======完了，人类要被计算机统治了QAQ=======
        '''
    )
    
def game_over():
    print(
        '''
           ======GAME OVER=======
        
             _________ 
            / ======= \ 
           / __________\ 
          | ___________ | 
          | | -       | | 
          | |         | | 
          | |_________| |________________ 
          \=____________/                ) 
          / """"""""""" \               / 
         / ::::::::::::: \          =D-' 
        (_________________) 

       
          ======GAME OVER=======
        '''
    )

def main():
    while True:
        menu()
        choice = int(input('请输入你的选择'))
        if choice == 1:
            show_instruction()
        elif choice == 2:
            guess_game()
        elif choice == 3:
            game_over()
            break
        else:
            show_team()    
    
    
    
def guess_game():
    n = int(input('请输入一个大于0的整数，作为神秘整数的上界，回车结束。'))
    number = int(input('输入你想让机子猜的数。'))
    max_times = math.ceil(math.log2(n))
    guess_times = 0
    while guess_times < max_times:
        guess = random.randint(1,n)
        guess_times += 1
        print('一共可以猜', max_times, '次')
        print('机子已经猜了', guess_times, '次')
        
        if guess == number:
            lose()
           
            print('计算机比标准次数少', max_times-guess_times, '次')
            
        elif guess > number:
            print('傻逼计算机猜大了')
        else:
            print('傻逼计算机猜小了')
   
        win()
if __name__=='__main__':
    main()
# Out:
#            =====游戏菜单=====
#                 1. 游戏说明
#                 2. 开始游戏
#                 3. 退出游戏
#                 4. 制作团队
#              =====游戏菜单=====
# 请输入你的选择2
# 请输入一个大于0的整数，作为神秘整数的上界，回车结束。8
# 输入你想让机子猜的数。3
# 一共可以猜 3 次
# 机子已经猜了 1 次
# 傻逼计算机猜大了
#
#            ======大吉大利，人类才是地球的统治者！=======
#
#
#                 ."".    ."",
#                 |  |   /  /
#                 |  |  /  /
#                 |  | /  /
#                 |  |/  ;-._
#                 }  ` _/  / ;
#                 |  /` ) /  /
#                 | /  /_/\_/                |/  /      |
#                 (  ' \ '-  |
#                  \    `.  /
#                   |      |
#                   |      |
#
#           ======大吉大利，人类才是地球的统治者！=======
#
# 一共可以猜 3 次
# 机子已经猜了 2 次
# 傻逼计算机猜大了
#
#            ======大吉大利，人类才是地球的统治者！=======
#
#
#                 ."".    ."",
#                 |  |   /  /
#                 |  |  /  /
#                 |  | /  /
#                 |  |/  ;-._
#                 }  ` _/  / ;
#                 |  /` ) /  /
#                 | /  /_/\_/                |/  /      |
#                 (  ' \ '-  |
#                  \    `.  /
#                   |      |
#                   |      |
#
#           ======大吉大利，人类才是地球的统治者！=======
#
# 一共可以猜 3 次
# 机子已经猜了 3 次
#
#            ======完了，人类要被计算机统治了QAQ=======
#
#
#
#
#                    .-"      "-.
#                   /                             |              |
#                  |,  .-.  .-.  ,|
#                  | )(__/  \__)( |
#                  |/     /\     \|
#        (@_       (_     ^^     _)
#   _     ) \_______\__|IIIIII|__/__________________________
#  (_)@8@8{}<________|-\IIIIII/-|___________________________>
#         )_/        \          /
#        (@           `--------`
#
#
#
#           =======完了，人类要被计算机统治了QAQ=======
#
# 计算机比标准次数少 0 次
#
#            ======大吉大利，人类才是地球的统治者！=======
#
#
#                 ."".    ."",
#                 |  |   /  /
#                 |  |  /  /
#                 |  | /  /
#                 |  |/  ;-._
#                 }  ` _/  / ;
#                 |  /` ) /  /
#                 | /  /_/\_/                |/  /      |
#                 (  ' \ '-  |
#                  \    `.  /
#                   |      |
#                   |      |
#
#           ======大吉大利，人类才是地球的统治者！=======
#
#            =====游戏菜单=====
#                 1. 游戏说明
#                 2. 开始游戏
#                 3. 退出游戏
#                 4. 制作团队
#              =====游戏菜单=====
