# %%
line = 'abcdefghijklmnopqrstuvwxyz'
for i in range(1,len(line)+1):
    for j in range(0,i):
        print(line[j], end='')
    print()
# Out:
# a
# ab
# abc
# abcd
# abcde
# abcdef
# abcdefg
# abcdefgh
# abcdefghi
# abcdefghij
# abcdefghijk
# abcdefghijkl
# abcdefghijklm
# abcdefghijklmn
# abcdefghijklmno
# abcdefghijklmnop
# abcdefghijklmnopq
# abcdefghijklmnopqr
# abcdefghijklmnopqrs
# abcdefghijklmnopqrst
# abcdefghijklmnopqrstu
# abcdefghijklmnopqrstuv
# abcdefghijklmnopqrstuvw
# abcdefghijklmnopqrstuvwx
# abcdefghijklmnopqrstuvwxy
# abcdefghijklmnopqrstuvwxyz

# %%
n=int(input('请输入你要输出的行数,回车结束.'))
line = '*'
for i in range(0, n):
    print((n-1-i)*' ' ,'* '*(i+1), end='')
    print()
# Out:
# 请输入你要输出的行数,回车结束.5
#      *
#     * *
#    * * *
#   * * * *
#  * * * * *
