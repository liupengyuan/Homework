# %%
#2、随机生成1万个整数，范围在0-10万之间，求其中每个整数出现的次数。并按照整数大小排序输出整数及出现次数。

# %%
import random
list=[random.randint(0,100000)for i in range(10000)]
list_1=sorted(list)
list_2=[]
for num in list_1:
    number = list_1.count(num)
    list_2.append([num,number])
list_3=[]
for x in list_2:
    if x not in list_3:
        list_3.append(x)
    else:
        pass
print(list_3)
# Out:
# [[2, 1], [21, 1], [30, 1], [33, 1], [47, 1], [66, 1], [69, 1], [89, 1], [101, 1], [107, 1], [128, 1], [163, 1], [170, 1], [188, 1], [194, 1], [200, 1], [204, 1], [208, 1], [215, 1], [222, 1], [239, 1], [250, 1], [255, 1], [276, 1], [280, 1], [288, 1], [292, 1], [304, 1], [316, 1], [320, 1], [325, 1], [347, 1], [355, 1], [356, 1], [371, 1], [376, 1], [378, 1], [382, 2], [386, 1], [388, 1], [391, 1], [396, 1], [433, 1], [460, 1], [471, 1], [474, 1], [476, 1], [504, 1], [507, 1], [513, 1], [532, 1], [539, 1], [544, 1], [558, 1], [560, 1], [561, 1], [564, 1], [572, 1], [578, 1], [588, 1], [593, 1], [596, 1], [623, 1], [630, 1], [632, 1], [646, 1], [648, 1], [652, 1], [663, 1], [665, 1], [670, 1], [672, 1], [707, 1], [710, 3], [722, 1], [735, 1], [752, 1], [753, 1], [765, 2], [785, 1], [793, 1], [808, 1], [810, 1], [814, 1], [856, 1], [858, 2], [865, 1], [886, 1], [888, 1], [891, 1], [892, 1], [898, 1], [903, 1], [905, 1], [910, 1], [916, 2], [918, 1], [932, 1], [942, 1], [959, 1], [974, 
# ...

# %%
#3、对本任务中的语料.txt文件，抽取其5001-10000行存为test1.txt文件，
#   写函数，可得到其与本任务中test.txt文件的共用字以及独用字（相关概念自行百度）。

# %%
with open(r'c:\temp\test1.txt', 'w') as fw, open(r'c:\temp\语料.txt') as fr:
    line_number = 0
    for line in fr:
        if 5001 <= line_number < 10000:
            fw.write(line)
            line_number += 1
        else:
            break

with open(r'c:\temp\语料.txt') as f1:
    for line in f1:
        word_1 = {word.split('/')[0] for word in line.split()}
with open(r'c:\temp\test1.txt') as f2:
    for line2 in f2:
        word_2 = {word.split('/')[0] for word in line2.split()}
print('共用字是',word_1 & word_2)
print('独用字是',word_1 - word_2)

# %%
#4、挑战性任务：统计本任务中的语料.txt文件，
#   得到每一个词对应不同词性的频次，可表示为：{词:[['n',1000], ['v', 98]...],...}，
#   即在dict对象中，key为词，value为列表，输出词频最高的50个条目。

# %%
def count_words_freq_dict(filename):
    words_freq_dict={}
    with open(filename) as f:
        for line in f:
            words = [word.split('/')[1] for word in line.split()]
            for word in words:
                if word in words_freq_dict:
                    words_freq_dict[word] += 1
                else:
                    words_freq_dict[word] = 1
    return words_freq_dict
filename = r'c:\temp\语料.txt'
from operator import itemgetter
table = count_words_freq_dict(filename)
words_freq_dict.sort(key=word,reverse=True)[:50]
