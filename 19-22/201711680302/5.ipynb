# %%
m=int(input("请输入一个整数作为随机数下界，回车结束。"))
k=int(input("请输入一个比m大的整数作为随机数上界，回车结束。"))

import random
n=int(input("请输入要输入的整数个数，回车结束。"))
i=0
total=0
x=0
while i<n:
    i+=1
    number_i=random.randint(m,k)
    total=total+number_i

x=total/n
print(x**0.5)
# Out:
# 请输入一个整数作为随机数下界，回车结束。1
# 请输入一个比m大的整数作为随机数上界，回车结束。100
# 请输入要输入的整数个数，回车结束。3
# 6.2182527020592095

# %%
m=int(input("请输入一个整数作为随机数下界，回车结束。"))
k=int(input("请输入一个比m大的整数作为随机数上界，回车结束。"))

import random
import math
n=int(input("请输入要输入的整数个数，回车结束。"))
i=0
a=0
b=0
total_1=0
total_2=0
while i<n:
    i+=1
    number_i=random.randint(m,k)
    a=math.log(number_i)
    b=1/a
    total_1=total_1+a
    total_2=total_2+b

print(total_1,total_2)
# Out:
# 请输入一个整数作为随机数下界，回车结束。1
# 请输入一个比m大的整数作为随机数上界，回车结束。100
# 请输入要输入的整数个数，回车结束。3
# 12.021073507212131 0.7552522764874735

# %%
m=int(input("请输入相加数个数，回车结束。"))
import random
a=random.randint(1,9)
i=1
x=0
s=a
number_i=a

while i<m:
    i+=1
    while x<m:
        x+=1
        number_i=number_i+a*10**x
        break
    s=s+number_i

print(s)
# Out:
# 请输入相加数个数，回车结束。3
# 861

# %%
#coding: utf-8

import random,math
def welcome():
    print(
        '''
           ======欢迎来到猜数游戏=======
        
                     /  \     ,    ,
           _._     _ |oo| _  / \__/ \
    
          _||||   ((/ () \))   /   \
    
          |||||/|  ( ==== )    |oo|    
           \____/  _`\  /'_    /   \
    
           /   /.-' /\<>/\ `\.( () )_._      
           |    `  /  \/  \  /`'--'////)
            \__,-'`|  |.  |\/ |/\/\|"\"` 
                   |  |.  | \___/\___/  
                   |  |.  |   |    |
          
          ======欢迎来到猜数游戏=======
        '''
    )

def win():
    print(
            '''
               ======恭喜你，你赢了=======
        
    
                    ."".    ."",
                    |  |   /  /
                    |  |  /  /
                    |  | /  /
                    |  |/  ;-._ 
                    }  ` _/  / ;
                    |  /` ) /  /
                    | /  /_/\_/\
                    |/  /      |
                    (  ' \ '-  |
                     \    `.  /
                      |      |
                      |      |
          
              ======恭喜你，你赢了=======
            '''
        )
    
def lose():
    print(
        '''
           ======YOU LOSE=======
        
    
                

                   .-"      "-.
                  /            \
                 |              |
                 |,  .-.  .-.  ,|
                 | )(__/  \__)( |
                 |/     /\     \|
       (@_       (_     ^^     _)
  _     ) \_______\__|IIIIII|__/__________________________
 (_)@8@8{}<________|-\IIIIII/-|___________________________>
        )_/        \          /
       (@           `--------`
       
       
       
          ======YOU LOSE=======
        '''
    )
    
def game_over():
    print(
        '''
           ======GAME OVER=======
        
             _________ 
            / ======= \ 
           / __________\ 
          | ___________ | 
          | | -       | | 
          | |         | | 
          | |_________| |________________ 
          \=____________/                ) 
          / """"""""""" \               / 
         / ::::::::::::: \          =D-' 
        (_________________) 

       
          ======GAME OVER=======
        '''
    )
    
def show_team():
    print("本游戏由幻影游戏公司制作，主创人：KCY")
    
def show_instruction():
    print('''由用户随便选择一个整数，让计算机来猜测.由用户选择猜测区域并输入最多可猜测的次数，计算机将猜测答案。
             每次猜测由用户提示计算机猜大了或是猜小了或者猜对了，直到计算机猜对答案或者猜测次数已用光，游戏结束.''')

def menu():
    print('''=====游戏菜单=====
                    1. 游戏说明
                    2. 开始游戏
                    3. 退出游戏
                    4. 制作团队
                 =====游戏菜单=====''')

def guess_game():
    n=int(input("请输入一个整数作为答案，回车结束。"))
    m=int(input("请输入一个比n小的整数作为猜测范围的下界，回车结束。"))
    k=int(input("请输入一个比n大的整数作为猜测范围的上界，回车结束。"))
    max_times=int(input("请输入允许电脑猜测的最大次数，回车结束。"))
    guess_times=0
    a=k-m
    
    while guess_times<max_times:
        guess_number=random.randint(m,k)
        print(guess_number)
        guess_times+=1
        
        x=int(input("请输入提示:如果猜大了，请输入1,猜小了，请输入2,猜对了，请输入3。"))
        if x==3:
            win()
            print(n)
            print("你比标准次数少",max_times - guess_times,"次")
            break
    
        elif x==2:
           
            m=guess_number
            guess_number=random.randint(m,k)
            print(guess_number)
    
        else:
            k=guess_number
            guess_number=random.randint(m,k)
            print(guess_number)
           
    else:
        print(n)
        lose()
def main():
    while True:
        menu()
        choice=int(input("请输入您所要进行的操作，回车结束。"))
        if choice==1:
            show_instruction()
        elif choice==2:
            guess_game()
        elif choice==3:
            game_over()
        break
    
    else:
        show_team()

main()
# Out:
# =====游戏菜单=====
#                     1. 游戏说明
#                     2. 开始游戏
#                     3. 退出游戏
#                     4. 制作团队
#                  =====游戏菜单=====
# 请输入您所要进行的操作，回车结束。2
# 请输入一个整数作为答案，回车结束。6
# 请输入一个比n小的整数作为猜测范围的下界，回车结束。1
# 请输入一个比n大的整数作为猜测范围的上界，回车结束。10
# 请输入允许电脑猜测的最大次数，回车结束。5
# 5
# 请输入提示:如果猜大了，请输入1,猜小了，请输入2,猜对了，请输入3。2
# 8
# 5
# 请输入提示:如果猜大了，请输入1,猜小了，请输入2,猜对了，请输入3。1
# 5
# 5
# 请输入提示:如果猜大了，请输入1,猜小了，请输入2,猜对了，请输入3。2
# 5
# 5
