# %%
import random
fh = open(r'C:\temp\idioms.txt')
text = fh.read()
fh.close()
chs=text.replace('、','')
idioms=chs.split('\n')
m=int(input())
txt=[]
i=0
n=0
while i < m:
    while n<(i+1)*10:
        ch = random.choice(chss)
        txt.append(ch)
        n=n+1
    print(txt)
    i=i+1
print(txt)
# Out:
# 6
# ['毛', '态', '云', '天', '山', '以', '一', '指', '女', '磨']
# ['毛', '态', '云', '天', '山', '以', '一', '指', '女', '磨', '众', '不', '沐', '流', '黔', '接', '空', '影', '达', '山']
# ['毛', '态', '云', '天', '山', '以', '一', '指', '女', '磨', '众', '不', '沐', '流', '黔', '接', '空', '影', '达', '山', '马', '运', '露', '卑', '孜', '愎', '车', '赅', '乐', '心']
# ['毛', '态', '云', '天', '山', '以', '一', '指', '女', '磨', '众', '不', '沐', '流', '黔', '接', '空', '影', '达', '山', '马', '运', '露', '卑', '孜', '愎', '车', '赅', '乐', '心', '兄', '声', '生', '人', '断', '源', '荆', '墨', '叶', '乐']
# ['毛', '态', '云', '天', '山', '以', '一', '指', '女', '磨', '众', '不', '沐', '流', '黔', '接', '空', '影', '达', '山', '马', '运', '露', '卑', '孜', '愎', '车', '赅', '乐', '心', '兄', '声', '生', '人', '断', '源', '荆', '墨', '叶', '乐', '名', '花', '高', '尸', '本', '五', '山', '子', '平', '苦']
# ...
