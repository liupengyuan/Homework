# %%
fh=open(r'C:\temp\idioms.txt')
text=fh.read()
fh.close()

text=text.replace('、', '')
idioms=text.split('\n')


fh=open(r'C:\temp\idioms_correct.txt', 'w')
fh.writelines(idioms)
fh.close()

fh=open(r'C:\temp\idioms_correct.txt')
text1=fh.read()
fh.close()

list1=[]
i=0
n=10
while i<n:
    import random
    idiom=random.choice(text1)
    list1.append(idiom)
    i+=1
print(list1)
fh=open(r'C:\temp\1.txt', 'w')
fh.writelines(list1)
fh.close()

list2=[]
i=0
n+=10
while i<n:
    import random
    idiom=random.choice(text1)
    list2.append(idiom)
    i+=1   
print(list2)
fh=open(r'C:\temp\2.txt', 'w')
fh.writelines(list2)
fh.close()

list3=[]
i=0
n+=10
while i<n:
    import random
    idiom=random.choice(text1)
    list3.append(idiom)
    i+=1   
print(list3)
fh=open(r'C:\temp\3.txt', 'w')
fh.writelines(list3)
fh.close()

list4=[]
i=0
n+=10
while i<n:
    import random
    idiom=random.choice(text1)
    list4.append(idiom)
    i+=1   
print(list4)
fh=open(r'C:\temp\4.txt', 'w')
fh.writelines(list4)
fh.close()

list5=[]
i=0
n+=10
while i<n:
    import random
    idiom=random.choice(text1)
    list5.append(idiom)
    i+=1   
print(list5)
fh=open(r'C:\temp\5.txt', 'w')
fh.writelines(list5)
fh.close()

list6=[]
i=0
n+=10
while i<n:
    import random
    idiom=random.choice(text1)
    list6.append(idiom)
    i+=1   
print(list6)
fh=open(r'C:\temp\6.txt', 'w')
fh.writelines(list6)
fh.close()

list7=[]
i=0
n+=10
while i<n:
    import random
    idiom=random.choice(text1)
    list7.append(idiom)
    i+=1   
print(list7)
fh=open(r'C:\temp\7.txt', 'w')
fh.writelines(list7)
fh.close()

list8=[]
i=0
n+=10
while i<n:
    import random
    idiom=random.choice(text1)
    list8.append(idiom)
    i+=1   
print(list8)
fh=open(r'C:\temp\8.txt', 'w')
fh.writelines(list8)
fh.close()

list9=[]
i=0
n+=10
while i<n:
    import random
    idiom=random.choice(text1)
    list9.append(idiom)
    i+=1   
print(list9)
fh=open(r'C:\temp\9.txt', 'w')
fh.writelines(list9)
fh.close()

list10=[]
i=0
n+=10
while i<n:
    import random
    idiom=random.choice(text1)
    list10.append(idiom)
    i+=1   
print(list10)
fh=open(r'C:\temp\10.txt', 'w')
fh.writelines(list10)
fh.close()
# Out:
# ['劝', '行', '不', '家', '若', '热', '止', '当', '打', '闻']
# ['山', '石', '腾', '高', '独', '沆', '马', '唳', '雨', '祥', '过', '神', '木', '待', '国', '守', '天', '哭', '牢', '暴']
# ['吁', '重', '袖', '肝', '及', '千', '阳', '理', '飞', '静', '掠', '前', '懈', '风', '待', '观', '服', '然', '良', '自', '助', '舌', '兵', '事', '如', '旷', '身', '兵', '地', '救']
# ['里', '流', '恐', '业', '转', '覆', '转', '好', '如', '视', '恒', '青', '渔', '声', '丧', '甘', '飞', '阳', '睛', '一', '玩', '一', '兔', '蓉', '绝', '钧', '干', '好', '叶', '器', '原', '风', '行', '无', '柴', '不', '鸿', '非', '病', '三']
# ['孤', '为', '色', '分', '涌', '大', '羊', '长', '较', '鸟', '仓', '人', '完', '大', '涯', '惑', '路', '雨', '仰', '多', '井', '成', '冲', '上', '在', '柳', '穿', '国', '成', '欢', '马', '念', '骄', '了', '接', '满', '亡', '玉', '龙', '杜', '学', '阿', '而', '风', '价', '校', '儒', '再', '天', '豹']
# ...
