# %%
#练习2、随机生成1万个整数，范围在0-10万之间，求其中每个整数出现的次数。并按照整数大小排序输出整数及出现次数。

# %%
import random

A=[]
i=0
while i<10000:
    a=random.randint(1,100001)
    A.append(a)
    i+=1

A=sorted(A)
words_freq_dict={}
for num in A:
    if num in words_freq_dict: 
        words_freq_dict[num] += 1
    else:                       
        words_freq_dict[num] = 1
        
print(words_freq_dict)
# Out:
# {6: 1, 7: 1, 27: 1, 54: 1, 76: 1, 83: 1, 97: 1, 115: 1, 133: 1, 140: 1, 155: 1, 162: 1, 163: 1, 189: 1, 192: 1, 195: 1, 196: 1, 201: 1, 205: 1, 226: 1, 228: 1, 259: 1, 265: 1, 266: 1, 271: 1, 275: 1, 281: 1, 290: 1, 301: 1, 344: 1, 367: 1, 368: 1, 370: 1, 378: 1, 393: 1, 411: 2, 418: 1, 433: 1, 434: 1, 438: 1, 456: 1, 462: 1, 474: 1, 480: 1, 494: 1, 496: 1, 512: 1, 519: 1, 526: 1, 529: 1, 535: 1, 559: 1, 562: 1, 572: 1, 578: 1, 580: 1, 596: 1, 614: 1, 621: 1, 624: 1, 629: 1, 655: 1, 662: 1, 663: 1, 668: 1, 670: 1, 675: 1, 682: 1, 699: 1, 701: 1, 702: 1, 704: 2, 711: 1, 716: 1, 724: 1, 748: 1, 758: 1, 784: 1, 789: 2, 797: 1, 799: 1, 803: 1, 805: 1, 822: 1, 828: 1, 832: 2, 841: 1, 844: 1, 851: 1, 855: 1, 859: 1, 862: 1, 863: 1, 892: 1, 904: 1, 927: 1, 928: 1, 934: 1, 942: 1, 954: 1, 962: 1, 966: 1, 967: 1, 996: 2, 1001: 1, 1011: 1, 1022: 1, 1023: 1, 1037: 1, 1044: 1, 1048: 1, 1053: 2, 1055: 1, 1058: 1, 1072: 1, 1088: 1, 1104: 1, 1108: 1, 1109: 1, 1113: 1, 1118: 1, 1137: 1, 1166: 1, 116
# ...

# %%
#练习3、对本任务中的语料.txt文件，抽取其5001-10000行存为test1.txt文件，写函数，可得到其与本任务中test.txt文件的共用字以及独用字（相关概念自行百度）。

# %%
with open(r'd:\temp\test.txt', 'w') as fh, open(r'd:\temp\test1.txt', 'w') as fw,open(r'd:\temp\语料.txt') as fr:
    line_number = 0
    for line in fr:             
        if line_number < 5000:
            fh.write(line)
            line_number +=1   
        elif line_number < 10000:
            fw.write(line)
            line_number +=1
        else:
            break
fh.close
fw.close
fr.close
            
def my():
    Agong=[]
    Adu=[]
    
    test=set(A)
    test1=set(B)
    for word1 in test1:
        if word1 in test1 and word1 in test:
            Agong.append(word1)
        else:
            Adu.append(word1)
    print('共用字为',Agong)
    print('独用字为',Adu)



f = open(r'd:\temp\test.txt')
f.seek(0)
for line in f:
    A = [word.split('/')[0] for word in line.split()]
f.close

f1 = open(r'd:\temp\test1.txt')
f1.seek(0)
for line in f1:
    B = [word1.split('/')[0] for word1 in line.split()]
f1.close

my()
# Out:
# 共用字为 []
# 独用字为 ['3', '当天', '日', '并', '当日', '。', '自', '活动', '8', '哀悼', '举行', '降半旗', '天', '，', '全国', '起', '法国']

# %%
#练习4、挑战性任务：统计本任务中的语料.txt文件，得到每一个词对应不同词性的频次，可表示为：{词:[['n',1000], ['v', 98]...],...}，即在dict对象中，key为词，value为列表，输出词频最高的50个条目。

# %%
from collections import Counter   
with open(r'd:\temp\语料.txt') as f:
    for line in f:
        t=[word.split('/')[0] for word in line.split()]
        v=[word.split('/') for word in line.split()]
    A = Counter(t)
    B=A.most_common(50)
    
C=dict(B)
print(C)
m=0
values=[]
while m<50:
    for word in v:
        if word[1]==C[m]:
            values.append(word[1])
    m+=1
        
    
print(C,values)
# Out:
# {'，': 2, '8': 1, '日': 1, '当天': 1, '法国': 1, '举行': 1, '全国': 1, '哀悼': 1, '活动': 1, '并': 1, '自': 1, '当日': 1, '起': 1, '降半旗': 1, '3': 1, '天': 1, '。': 1}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-343b95d161f6> in <module>()
#      13 while m<50:
#      14     for word in v:
# ---> 15         if word[1]==C[m]:
#      16             values.append(word[1])
#      17     m+=1
#
# KeyError: 0
