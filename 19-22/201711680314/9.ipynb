# %%
import random
list_a=[]
list_b=[]
for num in range(1,100001):
    list_a.append(num)
    list_b.append(num)
random.shuffle(list_b)

# %%
list_c=[]
for i in range(1,110001):
    list_c.append(i)
list_c=random.sample(list_c, k=1000)

# %%
list_d=[]
import time
start_time=time.time()
for i in range(1000):
    if list_c[i] in list_b:
        list_d.append(list_c[i])
end_time=time.time()
total_1=end_time - start_time
print(list_d)    
print(total_1)
# Out:
# [73410, 30027, 18993, 22052, 7031, 60097, 9258, 90025, 80041, 77912, 45722, 2177, 96073, 44437, 46823, 62301, 55, 4098, 28432, 42912, 94923, 79653, 29007, 28193, 57028, 29071, 5021, 20284, 51755, 66088, 77441, 59905, 56556, 32392, 26352, 5106, 45073, 68759, 1816, 5385, 47174, 33346, 85259, 98240, 1957, 58380, 95883, 93827, 46463, 83282, 66929, 64164, 49484, 14639, 93115, 73491, 88675, 34836, 64654, 89103, 76820, 4250, 50777, 43286, 53005, 45542, 69000, 76229, 93345, 84501, 13546, 90018, 86969, 51078, 3879, 59728, 51721, 71675, 4333, 86983, 32228, 12722, 26702, 65469, 54882, 89066, 23135, 93192, 61853, 18996, 37409, 49192, 26882, 88402, 19092, 77314, 80049, 1272, 97716, 6373, 81881, 25445, 43757, 49774, 43822, 82842, 92476, 82135, 59854, 36548, 77634, 43230, 17060, 55850, 6764, 95530, 52041, 10185, 2930, 59189, 97413, 51644, 40781, 91778, 67807, 43490, 68559, 49770, 12786, 34332, 68937, 15764, 30120, 71828, 64079, 3207, 99105, 90836, 53140, 55155, 35272, 15715, 41498, 32931, 86882, 77
# ...

# %%
list_e=[]
import time
start_time=time.time()
begin=list_a[0]
end=list_a[99999]
mid=(begin+end)//2
i=0
while i<1000:
    mid=(begin+end)//2
    if list_c[i]==list_a[mid]:
        list_e.append(list_c[i])
        i+=1
        end_time=time.time() 
    elif list_c[i]>list_a[mid]:
        mid+=1
        continue
    else:
        mid-=1
        continue
total_2=end_time - start_time
print(list_e)    
print(total_2)
