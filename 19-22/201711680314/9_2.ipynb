# %%
# 2、随机生成1万个整数，范围在0-10万之间，求其中每个整数出现的次数。并按照整数大小排序输出整数及出现次数
import random
from collections import Counter
x=[random.randint(0,100000) for i in range(1,10001)]
A=dict(Counter(x))
B=dict(sorted(A.items()))
B
# Out:
# {4: 1,
#  34: 1,
#  67: 2,
#  78: 1,
#  86: 2,
#  95: 1,
#  96: 1,
#  98: 1,
#  128: 1,
#  135: 1,
#  137: 1,
#  142: 1,
#  158: 1,
#  174: 1,
#  187: 1,
#  198: 1,
#  200: 1,
#  218: 1,
#  228: 1,
#  237: 1,
#  246: 1,
#  251: 1,
#  261: 1,
#  284: 1,
#  318: 1,
#  323: 1,
#  326: 1,
#  337: 1,
#  340: 1,
#  355: 1,
#  374: 1,
#  399: 1,
#  401: 1,
#  412: 1,
#  413: 1,
#  418: 1,
#  429: 1,
#  432: 1,
#  437: 2,
#  438: 1,
#  452: 1,
#  458: 1,
#  462: 1,
#  471: 1,
#  475: 1,
#  477: 2,
#  495: 1,
#  516: 1,
#  528: 1,
#  534: 1,
#  553: 1,
#  561: 1,
#  577: 2,
#  583: 1,
#  597: 1,
#  604: 1,
#  608: 1,
#  612: 1,
#  614: 1,
#  619: 1,
#  626: 1,
#  638: 1,
#  642: 1,
#  655: 1,
#  664: 1,
#  686: 1,
#  702: 1,
#  710: 1,
#  711: 1,
#  713: 1,
#  720: 1,
#  736: 1,
#  739: 1,
#  744: 1,
#  750: 1,
#  752: 1,
#  765: 1,
#  770: 1,
#  790: 1,
#  804: 1,
#  808: 2,
#  813: 1,
#  814: 2,
#  852: 1,
#  861: 1,
#  867: 1,
#  871: 1,
#  875: 1,
#  888: 1,
#  905: 1,
#  919: 1,
# ...

# %%
# 3、对本任务中的语料.txt文件，抽取其5001-10000行存为test1.txt文件，写函数，
# 可得到其与本任务中test.txt文件的共用字以及独用字（相关概念自行百度）。
with open(r'C:\temp\语料.txt') as r, open(r'c:\temp\test1.txt', 'w') as w,open(r'c:\temp\test.txt', 'w') as m:
    for i, line in enumerate(r):
        if i<5000:
            m.write(line)   
        elif 5000<i<10000:
            w.write(line)        
r.close()
with open(r'c:\temp\test.txt') as f1:
    for word in f1:
        test1=f1.read()
        words1 = {word.split('/')[0] for word in test1.split()}
with open(r'c:\temp\test1.txt') as f2:
    for word in f2:
        test2=f2.read()
        words2 = {word.split('/')[0] for word in test2.split()}
        
print('共用字是',words2&words1)
print('------------------------------------------------------------------------------------------------------------------------')
print('test独用字是',words1.difference(words2))
print('------------------------------------------------------------------------------------------------------------------------')
print('test1独用字是',words2.difference(words1))
# Out:
# 共用字是 {'', '样子', '摩擦', '绝', '受访者', '京剧院', '路边', '一列', '杜', '公园', '几乎', '售价', '找回', '每晚', '相似', '强烈', '迄今', '倒塌', '协定', '魏新', '早期', '一对', '下来', '脑袋', '第一期', '短信', '打成', '公章', '分成', '图书', '接地', '谦卑', '合并', '少数', '扑救', '发达国家', '轮动', '托举', '定制', '村民', '庵', '延迟', '危及', '罪魁祸首', '转化', '当代', '预告', '用于', '环境保护', '联动', '给予', '共筑', '弹性', '负', '前者', '环保法', '年代', '夕阳', '在线', '挑战', '五个', '卫视', '两轮', '光明', '采购', '像是', '美食', '本', '这边', '不多', '游', '指着', '得不到', '事迹', '落马', '这一', '炒作', '赶上', '双牛', '下级', '空间', '加重', '热闹非凡', '买车', '苗', '呈现出', '遏制', '晨报', '车库', '顺序', '声', '神奇', '总价', '假货', '南部', '神经', '全球', '时光', '原本', '水准', '走过', '波动', '把关', '反攻', '中奖者', '机械', '西城', '推广', '体力', '彩色', '交代', '落成', '统筹', '流入', '越来越', '政治权利', '交火', '两条', '资金来源', '最初', '戏剧', '历史性', '传到', '报考', '订阅', '细则', '不如', '庆', '复兴', '犯罪', '微创', '先进', '经济学', '弊端', '悦耳', '装置', '较大', '条例', '保护', '负责', '标志', '我国', '道理', '前途', '毫无保留', '一栏', '实力派', '物管', '根本', '生涯', '探秘', '合一', '院', '正统', 'A320', '笔记本', '潜在', '传人', '救援', '充实', '要素', '转移', '日期'
# ...

# %%
# 4、挑战性任务：统计本任务中的语料.txt文件，得到每一个词对应不同词性的频次，可表示为：{词:[['n',1000], ['v', 98]...],...}，
# 即在dict对象中，key为词，value为列表，输出词频最高的50个条目。def count_words_freq_dict(filename):
from collections import Counter

def count_words_freq_dict(filename):
    words_freq_dict = Counter()
    
    with open(filename) as f:
        for line in f:
            words_freq_dict.update([word.split('/')[1] for word in line.split()])
    return words_freq_dict

def main():
    filename = r'c:\temp\语料.txt'
    table = count_words_freq_dict(filename)
    print(table.most_common(50))
main()
# Out:
# [('n', 355241000), ('x', 289429000), ('v', 276903000), ('m', 108235000), ('d', 83539000), ('uj', 72560000), ('p', 61389000), ('r', 50769000), ('nr', 45650000), ('c', 43646000), ('a', 38347000), ('vn', 38105000), ('ns', 34994000), ('t', 26508000), ('f', 24652000), ('ul', 15381000), ('nz', 11971000), ('l', 11803000), ('b', 8768000), ('j', 7998000), ('i', 7943000), ('nt', 7507000), ('u', 7108000), ('eng', 6804000), ('q', 6196000), ('s', 5856000), ('nrt', 4742000), ('ad', 4279000), ('zg', 3552000), ('ng', 2679000), ('uz', 1675000), ('k', 1643000), ('uv', 1580000), ('z', 1492000), ('', 1469000), ('an', 1412000), ('y', 1382000), ('ug', 1158000), ('vg', 1121000), ('ud', 1104000), ('mq', 935000), ('nrfg', 712000), ('vd', 418000), ('g', 408000), ('h', 325000), ('ag', 294000), ('df', 243000), ('tg', 219000), ('rz', 168000), ('o', 145000)]
