# %% [markdown]
# ### 2、随机生成1万个整数，范围在0-10万之间，求其中每个整数出现的次数。并按照整数大小排序输出整数及出现次数。

# %%
import random
A=[]
V=[]
for i in range(1,100001):
    A.append(i)
    
for i in range(10000):
    v = random.choice(A)
    V.append(v) 
d = {k:V.count(k) for k in set(V)}
print([(k,d[k]) for k in sorted(d.keys())])
# Out:
# [(40, 1), (55, 1), (70, 1), (74, 1), (87, 1), (113, 1), (119, 1), (127, 1), (144, 1), (169, 1), (176, 1), (181, 1), (185, 1), (208, 2), (214, 1), (222, 1), (225, 1), (237, 1), (259, 1), (274, 1), (291, 1), (308, 1), (312, 1), (319, 1), (322, 1), (328, 1), (337, 1), (338, 1), (358, 1), (368, 1), (382, 1), (385, 1), (397, 1), (398, 1), (399, 1), (407, 1), (409, 1), (428, 1), (430, 1), (431, 1), (456, 1), (457, 1), (460, 1), (468, 2), (474, 1), (481, 1), (495, 1), (498, 1), (506, 1), (518, 1), (573, 1), (575, 1), (583, 1), (590, 2), (609, 1), (610, 1), (614, 1), (635, 1), (643, 1), (644, 1), (653, 1), (663, 1), (670, 1), (693, 1), (697, 1), (700, 1), (703, 1), (726, 1), (736, 1), (744, 1), (748, 1), (752, 1), (763, 1), (765, 1), (777, 1), (834, 1), (841, 1), (849, 1), (857, 1), (880, 1), (889, 1), (890, 1), (897, 1), (904, 1), (915, 1), (921, 1), (928, 1), (947, 1), (1000, 1), (1024, 1), (1027, 1), (1044, 1), (1050, 1), (1078, 1), (1105, 1), (1126, 1), (1128, 1), (1146, 1), (1157, 1), (1169, 1), (1189, 1), (1192, 1), (1215, 1), (1222, 1), (1225, 1), (1233, 1), (1236, 1), (1247, 1), (1249, 1), (1253, 1), (1263, 1), (1276, 1), (1288, 1), (1290, 1), (1307, 1), (1315, 1), (1348, 1), (1352, 1), (1390, 1), (1391, 1), (1415, 1), (1427, 1), (1449, 1), (1461, 1), (1466, 1), (1473, 1), (1488, 1), (1494, 1), (1511, 1), (1522, 1), (1524, 1), (1535, 1), (1553, 1), (1565, 1), (1582, 1), (1608, 1), (1647, 1), (1654, 1), (1655, 1), (1676, 1), (1677, 1), (1688, 1), (1720, 1), (1745, 1), (1750, 1), (1752, 1), (1756, 1), (1762, 1), (1770, 1), (1778, 1), (1783, 1), (1789, 1), (1808, 1), (1815, 1), (1820, 1), (1824, 1), (1839, 1), (1848, 1), (1868, 2), (1871, 1), (1872, 1), (1884, 1), (1885, 1), (1890, 1), (1896, 2), (1900, 1), (1916, 1), (1930, 1), (1935, 1), (1937, 1), (1944, 1), (1969, 1), (1971, 2), (1977, 1), (2015, 1), (2016, 1), (2020, 1), (2033, 1), (2040, 1), (2060, 1), (2072, 1), (2078, 1), (2096, 1), (2101, 1), (2104, 1), (2114, 1), (2117, 1), (2133, 1), (2143, 1), (2148, 1), (2149, 1), (2151, 1), (2155, 1), (2166, 1), (2175, 1), (2180, 1), (2182, 1), (2194, 1), (2197, 1), (2201, 1), (2217, 1), (2248, 1), (2249, 1), (2258, 1), (2264, 1), (2267, 1), (2271, 1), (2280, 1), (2283, 1), (2286, 2), (2301, 1), (2302, 1), (2304, 1), (2305, 1), (2313, 1), (2321, 2), (2355, 1), (2357, 1), (2369, 1), (2376, 1), (2388, 1), (2391, 1), (2397, 1), (2400, 2), (2413, 1), (2416, 1), (2418, 1), (2426, 1), (2427, 1), (2429, 1), (2435, 1), (2437, 1), (2439, 1), (2449, 1), (2450, 1), (2456, 2), (2460, 1), (2464, 1), (2467, 1), (2486, 1), (2487, 1), (2517, 1), (2533, 1), (2542, 1), (2543, 1), (2545, 1), (2549, 1), (2555, 1), (2563, 1), (2584, 1), (2601, 1), (2633, 2), (2635, 2), (2652, 1), (2656, 1), (2667, 1), (2677, 1), (2694, 1), (2698, 1), (2713, 1), (2721, 1), (2730, 1), (2754, 1), (2782, 1), (2791, 1), (2816, 1), (2818, 1), (2831, 1), (2836, 1), (2866, 1), (2884, 1), (2886, 1), (2889, 1), (2898, 1), (2907, 1), (2967, 1), (2982, 1), (2985, 1), (2992, 1), (3002, 1), (3013, 2), (3016, 1), (3022, 1), (3035, 2), (3039, 1), (3077, 1), (3081, 2), (3084, 1), (3085, 2), (3086, 1), (3090, 1), (3094, 1), (3107, 1), (3108, 1), (3125, 1), (3130, 1), (3136, 1), (3141, 1), (3151, 1), (3157, 1), (3166, 1), (3177, 1), (3183, 1), (3190, 1), (3198, 1), (3215, 1), (3219, 1), (3221, 1), (3242, 1), (3255, 1), (3260, 1), (3282, 1), (3286, 1), (3291, 1), (3300, 1), (3302, 1), (3326, 1), (3345, 1), (3357, 1), (3368, 1), (3378, 1), (3382, 2), (3392, 1), (3404, 1), (3417, 1), (3419, 1), (3437, 1), (3448, 1), (3465, 1), (3467, 1), (3487, 1), (3493, 1), (3500, 1), (3512, 1), (3517, 1), (3519, 1), (3522, 1), (3538, 1), (3540, 1), (3542, 1), (3549, 1), (3550, 1), (3556, 1), (3561, 1), (3567, 1), (3571, 1), (3572, 1), (3573, 1), (3578, 2), (3600, 1), (3619, 1), (3628, 1), (3645, 1), (3652, 1), (3653, 1), (3659, 1), (3662, 1), (3668, 1), (3670, 2), (3672, 1), (3675, 1), (3678, 1), (3685, 1), (3687, 1), (3694, 1), (3719, 1), (3728, 1), (3729, 1), (3754, 1), (3761, 1), (3765, 1), (3777, 1),  ...

# %% [markdown]
# ### 3、对本任务中的语料.txt文件，抽取其5001-10000行存为test1.txt文件，写函数，可得到其与本任务中test.txt文件的共用字以及独用字（相关概念自行百度）。

# %%
def maa():
    with open(r'd:\temp\test.txt', 'w') as fw, open(r'd:\temp\语料.txt') as fr:
        line_number = 0
        for line in fr:
            if line_number < 5001:
                fw.write(line)
                line_number += 1
            else:
                break
    with open(r'd:\temp\test.txt', 'w') as f:
        text = f.read()
    words = [word.split('/')[0] for word in text.split()]
    with open(r'd:\temp\test1.txt', 'w') as fw1, open(r'd:\temp\语料.txt') as fr:
        line_number = 0
        for line in fr:
            if line_number > 5000 and line_number < 10001:
                fw1.write(line)
                line_number += 1
            else:
                break
    with open(r'd:\temp\test1.txt', 'w') as f1:
        text1 = f1.read()
    words1 = [word.split('/')[0] for word in text1.split()]
    A=[]
    B=[]
    for i in words1:
        if i in words:
            A.append(i)        
        else:
            B.append(i)
    print('共用字',A)
    print('独用字',B)
print(maa())
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-23-4af4c3bc248e> in <module>()
#      31     print('共用字',A)
#      32     print('独用字',B)
# ---> 33 print(maa())
#
# <ipython-input-23-4af4c3bc248e> in maa()
#       9                 break
#      10     with open(r'd:\temp\test.txt', 'w') as f:
# ---> 11         text = f.read()
#      12     words = [word.split('/')[0] for word in text.split()]
#      13     with open(r'd:\temp\test1.txt', 'w') as fw1, open(r'd:\temp\语料.txt') as fr:
#
# UnsupportedOperation: not readable

# %% [markdown]
# ### 4、挑战性任务：统计本任务中的语料.txt文件，得到每一个词对应不同词性的频次，可表示为：{词:[['n',1000], ['v', 98]...],...}，即在dict对象中，key为词，value为列表，输出词频最高的50个条目。

# %%
from collections import Counter

def count_words_freq_dict(filename):
    words_freq_dict = Counter()
    
    with open(filename) as f:
        for line in f:
            words_freq_dict.update([word.split('/')[0] for word in line.split()])
    return words_freq_dict

def main():
    filename = r'd:\temp\语料.txt'
    table = count_words_freq_dict(filename)
    print(table.most_common(50))

if __name__ == '__main__':
    main()
# Out:
# [('，', 27285), ('的', 15590), ('。', 11646), ('、', 5262), ('“', 3951), ('”', 3937), ('在', 3689), ('了', 3284), ('是', 3011), ('和', 2049), ('年', 1846), ('有', 1546), ('也', 1518), ('：', 1290), ('《', 1252), ('》', 1252), ('将', 1248), ('人', 1151), ('为', 1097), ('中', 1051), ('月', 1024), ('不', 990), ('都', 978), ('他', 973), ('就', 961), ('等', 954), ('对', 942), ('这', 927), ('与', 900), ('上', 887), ('北京', 875), ('我', 875), ('日', 858), ('被', 854), ('记者', 841), ('中国', 788), ('（', 784), ('）', 782), ('到', 765), ('1', 713), ('说', 706), ('一个', 700), ('但', 686), ('后', 669), ('会', 661), ('还', 633), ('从', 628), ('；', 622), ('2014', 611), ('我们', 608)]
