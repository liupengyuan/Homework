# %%
import random

def game_over():
    print('''
    
    ***alright game over***
    
    ''')

def show_team():
    print('''
    
    $$$made by 胡爽 $$$
    
    ''')

def show_instruction():
    print('''
    
    ***成语接龙***
    
    ''')

def menu():
    print('''=====游戏菜单=====
                1. 游戏说明
                2. 开始游戏
                3. 退出游戏
                4. 制作团队
             =====游戏菜单=====''')
def guess_game():
    scord1=0
    scord2=0
    fh=open(r'c:\temp\成语大全.txt')
    text=fh.read()
    idioms=text.split('\n')
    word1=random.choice(idioms)
    print(word1)
    while scord2>=0:
        word2=input()
        if word1==word2:
            scord2+=10
        else:
            game_over()
            break
        print('电脑的分数是',scord1)
        print('你的分数是',scord1)
        idiomss=[]
        for idiom in idioms:
            if idiom[o]==idiom2[-1]:
                idiomss.append(idiom)
        if len(idiomss)==0:
            game_over()
            break
        else:
            word1=random.choice(idiomss)
            scord1+=10
            print(word1)
            print('电脑的分数是',scord1,'你的分数是',scord1)
        print('电脑的分数是',scord1,'你的分数是',scord1)

def main():
    while True:
        menu()
        choice = int(input('请输入你的选择'))
        if choice == 1:
            show_instruction()
        elif choice == 2:
            guess_game()
        elif choice == 3:
            game_over()
            break
        else:
            show_team()


if __name__ == '__main__':
    main()
# Out:
# =====游戏菜单=====
#                 1. 游戏说明
#                 2. 开始游戏
#                 3. 退出游戏
#                 4. 制作团队
#              =====游戏菜单=====
# 请输入你的选择1
#
#
#     ***成语接龙***
#
#
# =====游戏菜单=====
#                 1. 游戏说明
#                 2. 开始游戏
#                 3. 退出游戏
#                 4. 制作团队
#              =====游戏菜单=====
# 请输入你的选择4
#
#
#     $$$made by 胡爽 $$$
#
#
# =====游戏菜单=====
#                 1. 游戏说明
#                 2. 开始游戏
#                 3. 退出游戏
#                 4. 制作团队
#              =====游戏菜单=====
# 请输入你的选择2
# 阳春白雪
# 雪中送炭
#
#
#     ***alright game over***
#
#
# =====游戏菜单=====
#                 1. 游戏说明
#                 2. 开始游戏
#                 3. 退出游戏
#                 4. 制作团队
#              =====游戏菜单=====
# 请输入你的选择3
#
#
#     ***alright game over***
