# %% [markdown]
# ### 1、（10 分）写函数，有两个形式参数: 符号和行数，可打印多行字符图形。如
# ### 主程序给定：‘*’，5, 调用该函数，可打印相应行数的如下图形。

# %%
def tuxing(line,n):
    for i in range(1,n+1):
        print(' '*(2*n-i*2)+(line[0]+' ')*i+(line[0])*n+' '+(line[0]+' ')*i)
line='*'
tuxing(line,5)
# Out:
#         * ***** *
#       * * ***** * *
#     * * * ***** * * *
#   * * * * ***** * * * *
# * * * * * ***** * * * * *

# %% [markdown]
# ### 2、（10 分）Ackermann 函数定义如下，请实现该函数，并计算 A(3,4)。

# %%
def Ackermann(m,n):
    if m==0:
        return n+1
    elif m>0 and n==0:
        return Ackermann(m-1,1)
    elif m>0 and n>0:
        return Ackermann(m-1,Ackermann(m,n-1))
    else:
        return
print(Ackermann(3,4))
# Out:
# 125

# %% [markdown]
# ### 3.某小学一年级期末考试，请你编程随机出 n 道四则运算题目，每题只有两个
# ### 数字和一个运算符号，数字均为 a 到 b 之间的整数， 整数是随机的， 加减乘
# ### 除也是随机的，要保证每个题目的结果必须是正整数。

# %% [markdown]
# ### （a）（15 分）打印所有题目，每行一道题（给定参数 n=15, a=3, b= 25）。

# %%
import random 
def timu(n,a,b):
    i=0
    while i<n:
        A=[]
        B=[]
        C=['+','-','*','/']
        for x in range(a,b):
            B.append(x)
        for j in range(2):
            j=random.choice(B)
            A.append(j)
        v=random.choice(C)
        print('题目：',A[0],v,A[1],'=') 
        i+=1    
n=15
a=3
b=25
timu(n,a,b)
# Out:
# 题目： 11 * 22 =
# 题目： 15 * 17 =
# 题目： 15 / 20 =
# 题目： 6 - 17 =
# 题目： 22 * 3 =
# 题目： 3 * 18 =
# 题目： 7 + 17 =
# 题目： 18 * 16 =
# 题目： 14 - 7 =
# 题目： 14 + 7 =
# 题目： 6 + 23 =
# 题目： 15 + 24 =
# 题目： 5 - 21 =
# 题目： 15 * 15 =
# 题目： 18 - 23 =

# %% [markdown]
# ### （b）（10 分）用户键盘输入答案，答对一道加减法题目得 5 分，答对一道乘
# ### 除法题目得 10 分，答错不得分，程序自动计算并输出最终得分。限定用户一次
# ### 输入所有答案，逗号分隔，示意如下：12,34,22,....21

# %%
import random 
def timu(n,a,b):
    i=0
    while i<n:
        A=[]
        B=[]
        C=['+','-','*','/']
        D=[]
        for x in range(a,b):
            B.append(x)
        for a in range(2):
            j=random.choice(B)
            A.append(j)
        v=random.choice(C)
        d=A[0]+A[1]
        D.append(d)
        print('题目：',A[0],v,A[1],'=') 
        i+=1
def game(n):
    player=0
    Total=0
    answers=[]
    for i in range(n):
        answer=int(input('请输入答案'))
        answers.append(answer)
    for j in range(1,n):
        if answers[j]==D[j]:
            if v=='+' or v=='-':
                player+=5
            elif v=='*' or v=='/':
                player+=10
        Total+=player
    print(Total)
print(timu(15,3,25))
game(15)
# Out:
# 题目： 16 + 16 =
# 题目： 6 * 14 =
# 题目： 3 - 21 =
# 题目： 2 + 6 =
# 题目： 12 - 7 =
# 题目： 15 + 21 =
# 题目： 18 / 8 =
# 题目： 2 - 16 =
# 题目： 23 - 11 =
# 题目： 17 + 11 =
# 题目： 6 * 3 =
# 题目： 9 + 8 =
# 题目： 14 + 10 =
# 题目： 4 + 1 =
# 题目： 9 + 11 =
# None
# 请输入答案32,12,34,4,45,56,32,3,45,54,6,7,87,45,23
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-fed335141cfd> in <module>()
#      33     print(Total)
#      34 print(timu(15,3,25))
# ---> 35 game(15)
#
# <ipython-input-2-fed335141cfd> in game(n)
#      22     answers=[]
#      23     for i in range(n):
# ---> 24         answer=int(input('请输入答案'))
#      25         answers.append(answer)
#      26     for j in range(1,n):
#
# ValueError: invalid literal for int() with base 10: '32,12,34,4,45,56,32,3,45,54,6,7,87,45,23'

# %% [markdown]
# ### （c）（15 分）答题机器人，可以接受从键盘输入的 n 道四则运算题目（题目要
# ### 求与前类似，用户来出题），用户首先输入题目个数 n，然后用户每输入一个题
# ### 目，机器人将自动运算得出结果。n 道题输入完毕后，根据（b）中的分数规则，
# ### 计算总得分输出。令 n=10,四则运算都有，用户输入的题目格式示例为：5*14=

# %%
import random
def end():
    print('游戏结束')
    print('你的分数：%d'%player)
    print('电脑得分：%d'%computer)
    if player >computer :
        print('你赢了')
    elif player<computer:
        print('你输了')
    else:
        print('平局')
player=0
computer=0

# %% [markdown]
# ### 4.（a）（10 分）写程序，读入成语文件，并提取出所有四字成语，形成集合 A。
# ### （由于成语文件编码为 utf-8 因此：
# ### 用 with open (filename, encoding = 'utf-8') as f: 来打开文件，其中
# ### filename 是路径及文件全名。）

# %%
with open(r'd:\temp\成语大全(含成语解释)_utf8.txt','r',endcoding='gbk') as fh:
    text = fh.read()
start = 0
end = 0

idioms = []
while end < len(text):
    if text[end] == ' ':
        idioms.append(text[start:end])
        start = end + 1
    end += 1
print(idioms)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-4225ba9e9448> in <module>()
# ----> 1 with open(r'd:\temp\成语大全(含成语解释)_utf8.txt','r',endcoding='gbk') as fh:
#       2     text = fh.read()
#       3 start = 0
#       4 end = 0
#       5
#
# TypeError: 'endcoding' is an invalid keyword argument for this function

# %% [markdown]
# ### （b）（10 分）统计 A 中所有成语在语料库文件中出现的频次。输出频次最高
# ### 的 20 个成语及其频次。（如第一问没有做出，可用之前教程 8.md 中的成语库）

# %%
fh = open(r'd:\temp\成语.txt')
text = fh.read()
fh.close()
text = text.replace('、', '')
idioms = text.split('\n')
word_freq_pairs=[]
for word in idioms:
        number = text.count(word)
        word_freq_pairs.append([word, number])
print(word_freq_pairs[:20])
# Out:
# [['行尸走肉', 1], ['金蝉脱壳', 1], ['百里挑一', 1], ['金玉满堂', 1], ['背水一战', 1], ['霸王别姬', 1], ['天上人间', 1], ['不吐不快', 1], ['海阔天空', 1], ['情非得已', 1], ['满腹经纶', 1], ['兵临城下', 1], ['春暖花开', 1], ['插翅难逃', 1], ['黄道吉日', 1], ['天下无双', 1], ['偷天换日', 1], ['两小无猜', 1], ['卧虎藏龙', 1], ['珠光宝气', 1]]

# %% [markdown]
# ### （c）（5 分）统计语料库得到每个词类的词的总频次（如 ns 算一类，v 算一类..）
# ### 并输出到屏幕。

# %%
def count_words_freq(filename):
    word_freq_pairs = []
    
    with open(filename) as f:
        text = f.read()
        
    words = [word.split('/')[1] for word in text.split()]
    for word in words:
        for item in word_freq_pairs:
            if word == item[0]:
                item[1] += 1
                break
        else:
            word_freq_pairs.append([word, 1])
            
    return word_freq_pairs

#测试用

filename = r'd:\temp\test_re_gbk (1).txt'
table = count_words_freq(filename)
print(table)
# Out:
# [['nrfg', 133], ['l', 2561], ['p', 13234], ['n', 76628], ['m', 25920], ['v', 59686], ['x', 63637], ['t', 6063], ['nz', 2603], ['vn', 7722], ['i', 1729], ['d', 18225], ['ns', 8153], ['c', 9321], ['nr', 10531], ['nrt', 995], ['j', 1707], ['uj', 15590], ['', 384], ['vg', 239], ['eng', 1616], ['tg', 64], ['a', 8249], ['r', 10942], ['ug', 238], ['ud', 205], ['ul', 3284], ['nt', 1723], ['k', 371], ['ad', 932], ['f', 5197], ['u', 1580], ['b', 1743], ['vd', 92], ['an', 302], ['s', 1281], ['uv', 344], ['zg', 754], ['q', 1339], ['uz', 408], ['z', 322], ['ng', 574], ['h', 90], ['e', 31], ['y', 308], ['mq', 219], ['o', 40], ['rz', 36], ['ag', 75], ['dg', 7], ['g', 76], ['df', 55], ['vq', 6], ['rr', 5], ['rg', 8], ['vi', 6], ['yg', 6]]

# %% [markdown]
# ### （d）（5 分）统计语料库得到所有词类为 nr 的词（不重复），并输出到屏幕。

# %%
word_freq_pairs = []
with open(r'd:\temp\test_re_gbk (1).txt') as f:
    text = f.read()
words = [word.split('/') for word in text.split()]
for word in words:
    if word[1]=='nr':
        word_freq_pairs.append(word[0])
A=[]
for i in word_freq_pairs:
    if i not in A:
        A.append(i)
print(A)
# Out:
# ['张家口', '蔡', '呼格', '祝福', '宝贵', '马航', '钟声', '从严治党', '利剑', '蓝图', '呼唤', '阳光', '谢谢', '孙春兰', '饶阳', '蔡名照', '李从军', '白克力', '博乐', '李克强', '小微', '公正', '延长线', '王歧丰', '金融城', '大屏幕', '迎新年', '杨扬', '叶乔波', '申雪', '赵宏博', '张虹', '李妮娜', '吴', '贾鹏', '周', '高峰', '西红门', '紫芳园', '芳', '久敬庄', '霍营', '续航', '银行卡', '安全门', '宣武门', '亦庄', '昌平', '曹晶瑞', '张璐', '王巍', '申请人', '王萍', '大伟', '奥赛', '特长生', '金', '养老金', '马迭尔', '肖丹', '石景山', '贝斯', '玛', '黑森林', '梅高信', '博野县', '康园', '嘉', '冰宝罗', '熊', '宝罗熊', '冰淇淋', '宫', '邹乐', '石军', '宣传部', '卡', '张', '张树坡', '幼儿园', '施暴', '玉', '玉桥', '李女士', '支支吾吾', '姜', '刘女士', '杨先生', '杜绝', '贝乐康', '铁瑾', '马先生', '清仓', '塞满', '丁先生', '安静', '金刚', '小金刚', '顾客', '刘', '老先生', '寻思', '刘老', '老祖宗', '张嘴', '闫', '门脸儿', '宝贝', '红太阳', '闫老', '小兄弟', '马老', '玉石', '陈佳', '毛巾', '黎', '樊一婧', '明华嘉', '冯广聚', '陈佳兴', '冯', '魏', '郭', '恩元居', '辛', '北京小吃', '辛振江', '冯老', '冯博', '钱振波', '马国义', '高达', '阳光板', '雪山', '黄志', '高潮', '唐明生', '嘉实', '昨天早上', '安抚', '刘悦伦', '陈菲', '查明', '陆冠峰', '腾飞', '文明', '李', '尚爱云', '贾立君', '于嘉', '尔博沃', '桑迪', '班邦', '斯提', '幸存者', '雷达', '庄', '田云', 
# ...

# %% [markdown]
# ### （e）（5 分）统计语料库及 A，得到词（成语）表及字表，打印语料库词表中
# ### 所有词的长度之和/语料库字表长度；打印 A 的所有词的长度之和/A 的字表长
# ### 度。（如第一问没有做出，可用之前教程 8.md 中的成语库）

# %%
word_freq_pairs = []
with open(r'd:\temp\test_re_gbk (1).txt') as f:
    text = f.read()
words = [word.split('/')[0] for word in text.split()]
print(len(words))

def get_ch_table(line):
    ch_table = []
    for ch in line:
        if ch not in ch_table:
            ch_table.append(ch)
    return ch_table
fh = open(r'd:\temp\idioms.txt')
text = fh.read()
A_table = get_ch_table(text.replace('\n', ''))

print(len(A_table))
# Out:
# 367589
# 1250

# %% [markdown]
# ### （f）（5 分）挑战性开放式题目。新型接龙，方式为：一个成语，接一个二字
# ### 词，接一个成语...例如：千钧一发 发生 生生不息 息影 影只形单 单飞 飞珠溅
# ### 玉 玉石 石破天惊...。成语在 A 中，二字词由统计语料库词表中得到。要求键盘
# ### 输入一个成语，计算机能给出接龙序列（不产生回路），思考并实现一种使该序
# ### 列尽可能长（无需确实是最长序列）的方法。成语以万马奔腾为例。（如第一问
# ### 没有做出，可用之前教程 8.md 中的成语库）

# %%
import random
def end():
    print('游戏结束')
    print('你的分数：%d'%player)
    print('电脑得分：%d'%computer)
    if player >computer :
        print('你赢了')
    elif player<computer:
        print('你输了')
    else:
        print('平局')
player=0
computer=0

fh=open(r'd:\temp\成语.txt')
text=fh.read()
text=text.replace('、','')
idioms=text.split('\n')
word_freq_pairs = []
with open(r'd:\temp\test_re_gbk (1).txt') as f:
    text = f.read()
words = [word.split('/')[0] for word in text.split()]
Idioms=idioms+words
idioms_2=[]
fh.close()
idiom=random.choice(Idioms)
print(idiom)

while True:
    answer=input('请输入一个成语进行接龙：')
    if answer in idioms and answer[0]==idiom[-1]:
        player+=10

        for idiom in idioms:
            if answer[-1]==idiom[0]:
                print('计算机接龙：',idiom)
                computer+=10
                break
            else:
                idioms_2.append(idiom)
        if len(idioms_2)==len(idioms):
            player+=10
            end()
            break
    else:
        computer+=10
        end()
        break
# Out:
# 网站
# 请输入一个成语进行接龙：站台
# 游戏结束
# 你的分数：0
# 电脑得分：10
# 你输了
