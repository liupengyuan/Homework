# %%
#顺序查找算法
def order():
    start_time = time.time()
    for number1 in C:
        i=0
        while i<len(B):
            number2=B[i]
            if number1==number2:
                print('整数:',number1,'整数所在位置:',i+1)
            i+=1
    end_time = time.time()
    total1=end_time-start_time
    print('顺序法所用时间:',total1)

#二分查找算法
def bi_search():
    start_time = time.time()
    for number1 in C:
        a=bisect.bisect_left(A,number1)
        if number1==A[0]:
            print('整数:',number1,'整数所在位置:',1)
        else:
            if 0<a<len(A):
                print('整数:',number1,'整数所在位置:',a+1)
    end_time = time.time()
    total2=end_time-start_time
    print('二分法所用时间:',total2)

#主程序
import random,copy,time,bisect
A=[]
for i in range(100000):
    A.append(i)
B=A.copy()
random.shuffle(B)
C=[]
for i in range(1000):
    n=random.randint(1,110000)
    C.append(n)
order()
print('''     --------------------------分界线--------------------------------

     ----------------------------------------------------------------

     ----------------------------------------------------------------''')
bi_search()
# Out:
# 整数: 7189 整数所在位置: 27322
# 整数: 39347 整数所在位置: 41413
# 整数: 53125 整数所在位置: 84842
# 整数: 51796 整数所在位置: 96716
# 整数: 8702 整数所在位置: 41470
# 整数: 23426 整数所在位置: 97067
# 整数: 17431 整数所在位置: 71408
# 整数: 15700 整数所在位置: 74183
# 整数: 86067 整数所在位置: 25284
# 整数: 54013 整数所在位置: 8600
# 整数: 54889 整数所在位置: 2816
# 整数: 72306 整数所在位置: 27028
# 整数: 48245 整数所在位置: 35793
# 整数: 78013 整数所在位置: 56622
# 整数: 4650 整数所在位置: 13329
# 整数: 27905 整数所在位置: 7829
# 整数: 79411 整数所在位置: 21233
# 整数: 13361 整数所在位置: 41331
# 整数: 27069 整数所在位置: 72894
# 整数: 51324 整数所在位置: 95650
# 整数: 67085 整数所在位置: 59387
# 整数: 7045 整数所在位置: 65653
# 整数: 130 整数所在位置: 55647
# 整数: 96494 整数所在位置: 12205
# 整数: 49396 整数所在位置: 58846
# 整数: 61852 整数所在位置: 44924
# 整数: 43781 整数所在位置: 31587
# 整数: 11180 整数所在位置: 2388
# 整数: 96524 整数所在位置: 80502
# 整数: 90459 整数所在位置: 47959
# 整数: 24397 整数所在位置: 95485
# 整数: 67676 整数所在位置: 5236
# 整数: 50673 整数所在位置: 13150
# 整数: 26706 整数所在位置: 13806
# 整数: 63890 整数所在位置: 82785
# 整数: 50715 整数所在位置: 72223
# 整数: 5168 整数所在位置: 5781
# 整数: 81518 整数所在位置: 99858
# ...
