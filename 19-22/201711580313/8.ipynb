# %%
def win():
    print(
        '''
           ======恭喜你，你赢了=======
        
    
                ."".    ."",
                |  |   /  /
                |  |  /  /
                |  | /  /
                |  |/  ;-._ 
                }  ` _/  / ;
                |  /` ) /  /
                | /  /_/\_/\
                |/  /      |
                (  ' \ '-  |
                 \    `.  /
                  |      |
                  |      |
          
          ======恭喜你，你赢了=======
        '''
    )
def lose():
     print(
        '''
           ======YOU LOSE=======
        
    
                

                   .-"      "-.
                  /            \
                 |              |
                 |,  .-.  .-.  ,|
                 | )(__/  \__)( |
                 |/     /\     \|
       (@_       (_     ^^     _)
  _     ) \_______\__|IIIIII|__/__________________________
 (_)@8@8{}<________|-\IIIIII/-|___________________________>
        )_/        \          /
       (@           `--------`
       
       
       
          ======YOU LOSE=======
        '''
    )
def get_id_table():
    with open(file_name) as fh:
        text = fh.read()
        idioms = text.split('\n')
    return idioms
def play(ra_idiom):
    pl_idiom = input('请输入你的答案：')
    idioms = get_id_table()
    ra_score = 0
    pl_score = 0
    for idiom in idioms:
        if idiom == pl_idiom:
            pl_score += 10
            print('对了，你的当前分数是：',pl_score)
            for idiom in idioms:
                if idiom[0] ==pl_idiom[-1]:
                    ra_idiom = idiom
                    ra_score += 10
                    print(ra_idiom)
                    print('机器人当前分数是：',ra_score)
                    break
def main():
    
    
    idioms = get_id_table()
    import random
    ra_idiom = random.choice(idioms)
    print(ra_idiom)
    i = 1
    while i <= 10:
        play(ra_idiom)
    
        i  += 1

# %%
file_name= r'c:\temp\成语大全.txt'
main()
# Out:
# 所剩无几
# 请输入你的答案：几乎
# 请输入你的答案：七上八下
# 对了，你的当前分数是： 10
# 下笔成章
# 机器人当前分数是： 10
# 请输入你的答案：阿谀奉承
# 对了，你的当前分数是： 10
# 承上启下
# 机器人当前分数是： 10
# 请输入你的答案：下里巴人
# 对了，你的当前分数是： 10
# 人才辈出
# 机器人当前分数是： 10
