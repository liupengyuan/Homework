# %%
import random
def get_ch_table(line):
    ch_table = []
    for ch in line:
        if ch not in ch_table:
            ch_table.append(ch)
    return ch_table
fh = open(r'c:\temp\成语大全.txt')
text = fh.read()

chs = get_ch_table(text)

final = []

for i in range(10):
    ch = random.choice(chs)
    final.append(ch)
print(final)
    
fh = open(r'c:\temp\1.txt','w')
fh.writelines(final)
fh.close()

for i in range(20):
    ch = random.choice(chs)
    final.append(ch)
print(final)
    
fh = open(r'c:\temp\2.txt','w')
fh.writelines(final)
fh.close()

for i in range(30):
    ch = random.choice(chs)
    final.append(ch)
print(final)
    
fh = open(r'c:\temp\3.txt','w')
fh.writelines(final)
fh.close()

for i in range(40):
    ch = random.choice(chs)
    final.append(ch)
print(final)
    
fh = open(r'c:\temp\4.txt','w')
fh.writelines(final)
fh.close()

for i in range(50):
    ch = random.choice(chs)
    final.append(ch)
print(final)
    
fh = open(r'c:\temp\5.txt','w')
fh.writelines(final)
fh.close()

for i in range(60):
    ch = random.choice(chs)
    final.append(ch)
print(final)
    
fh = open(r'c:\temp\6.txt','w')
fh.writelines(final)
fh.close()

for i in range(70):
    ch = random.choice(chs)
    final.append(ch)
print(final)
    
fh = open(r'c:\temp\7.txt','w')
fh.writelines(final)
fh.close()

for i in range(80):
    ch = random.choice(chs)
    final.append(ch)
print(final)
    
fh = open(r'c:\temp\8.txt','w')
fh.writelines(final)
fh.close()

for i in range(90):
    ch = random.choice(chs)
    final.append(ch)
print(final)
    
fh = open(r'c:\temp\9.txt','w')
fh.writelines(final)
fh.close()

for i in range(100):
    ch = random.choice(chs)
    final.append(ch)
print(final)
    
fh = open(r'c:\temp\10.txt','w')
fh.writelines(final)
fh.close()
# Out:
# ['洋', '琅', '梦', '黄', '待', '虑', '咫', '蒙', '蛇', '机']
# ['洋', '琅', '梦', '黄', '待', '虑', '咫', '蒙', '蛇', '机', '连', '菲', '充', '墙', '参', '周', '容', '怡', '银', '幽', '福', '司', '聋', '幽', '拣', '患', '强', '五', '换', '而']
# ['洋', '琅', '梦', '黄', '待', '虑', '咫', '蒙', '蛇', '机', '连', '菲', '充', '墙', '参', '周', '容', '怡', '银', '幽', '福', '司', '聋', '幽', '拣', '患', '强', '五', '换', '而', '柳', '淘', '林', '劫', '目', '突', '饴', '燕', '鹰', '泽', '惺', '假', '边', '期', '猫', '奈', '狗', '戈', '张', '随', '火', '徙', '瀣', '恭', '兔', '惶', '斗', '破', '之', '凤']
# ['洋', '琅', '梦', '黄', '待', '虑', '咫', '蒙', '蛇', '机', '连', '菲', '充', '墙', '参', '周', '容', '怡', '银', '幽', '福', '司', '聋', '幽', '拣', '患', '强', '五', '换', '而', '柳', '淘', '林', '劫', '目', '突', '饴', '燕', '鹰', '泽', '惺', '假', '边', '期', '猫', '奈', '狗', '戈', '张', '随', '火', '徙', '瀣', '恭', '兔', '惶', '斗', '破', '之', '凤', '救', '贻', '置', '眉', '残', '容', '横', '益', '才', '猿', '滥', '温', '藉', '摸', '扑', '淘', '上', '大', '座', '重', '赵', '腾', '里', '肆', '逍', '椟', '寒', '兴', '到', '合', '因', '斯', '绑', '举', '睛', '淘', '祖', '起', '乱', '丹']
# ['洋', '琅', '梦', '黄', '待', '虑', '咫', '蒙', '蛇', '机', '连', '菲', '充', '墙', '参', '周', '容', '怡', '银', '幽', '福', '司', '聋', '幽', '拣', '患', '强', '五', '换', '而', '柳', '淘', '林', '劫', '目', '突', '饴', '燕', '鹰', '泽', '惺', '假', '边', '期', '猫', '奈', '狗', '戈', '张', '随', '火', '徙', '瀣', '恭', '兔', '惶', '斗', '破', '之', '凤', '救', '贻', '置', '眉', '残', '容', '横', '益', '才', '猿', '滥', '温', '藉', '摸', '扑', '淘', '上', '大', '座', '重', '赵', '腾', '里', '肆', '逍', '椟', '寒', '兴', '到', '合', '因', '斯', '绑', '举', '睛', '淘', '祖', '起', '乱', '丹', '翩', '之', '交', '救', '转', '古', '毓', '象', '竭', '争', '厉', '劝', '方', '裹', '安', '沓', '钟', '簪', '非', '帼', '奇', '果', '玉', '校', '锁', '窍', '篇', '十', '车', '泣', '实', '鸩', '西', '失', '用', '砥', '疲', '线', '奂', '富', '丹', '菲', '间', '忍', '驰', '司', '擎', '夫', '吐', '沁']
# ['洋', '琅', '梦', '黄', '待', '虑', '咫', '蒙', '蛇', '机', '连', '菲', '充', '墙', '参', '周', '容', '怡', '银', '幽', '福', '司', '聋', '幽', '拣', '患', '强', '五', '换', '而', '柳', '淘', '林', '劫', '目', '突', '饴', '燕', '鹰', '泽', '惺', '假', '边', '期', '猫', '奈', '狗', '戈', '张', '随', '火', '徙', '瀣', '恭', '兔', '惶', '斗', '破', '之', '凤', '救', '贻', '置', '眉', '残', '容', '横', '益', '才', '猿', '滥', '温', '藉', '摸', '扑', '淘', '上', '大', '座', '重', '赵', '腾', '里', '肆', '逍', '椟', '寒', '兴', '到', '合', '因', '斯', '绑', '举', '睛', '淘', '祖', '起', '乱', '丹', '翩', '之', '交', '救', '转', '古', '毓', '象', '竭', '争', '厉', '劝', '方', '裹', '安', '沓', '钟', '簪', '非', '帼', '奇', '果', '玉', '校', '锁', '窍', '篇', '十', '车', '泣', '实', '鸩', '西', '失', '用', '砥', '疲', '线', '奂', '富', '丹', '菲', '间', '忍', '驰', '司', '擎', '夫', '吐', '沁', '众', '果', '婚', '锤', '竹', '章', '巫', '余', '错', '强', '扫', '餐', '里', '凌', '扫', '乐', '裘', '捭', '怡', '静', '赴', '何', '借', '蓝', '意', '上', '盾', '的', '魏', '弥', '拣', '彰', '怙', '我', '往', '就', '隙', '与', '酸', '胆', '秦', '草', '实', '千', '如', '颐', '庸', '裘', '虹', '青', '塞', '效', '莫', '经', '禁', '温', '围', '抗', '冠', '琅']
# ['洋', '琅', '梦', '黄', '待', '虑', '咫', '蒙', '蛇', '机', '连', '菲', '充', '墙', '参', '周', '容', '怡', '银', '幽', '福', '司', '聋', '幽', '拣', '患', '强', '五', '换', '而', '柳', '淘', '林', '劫', '目', '突', '饴', '燕', '鹰', '泽', '惺', '假', '边', '期', '猫', '奈', '狗', '戈', '张', '随', '火', '徙', '瀣', '恭', '兔', '惶', '斗', '破', '之', '凤', '救', '贻', '置', '眉', '残', '容', '横', '益', '才', '猿', '滥', '温', '藉', '摸', '扑', '淘', '上', '大', '座', '重', '赵', '腾', '里', '肆', '逍', '椟', '寒', '兴', '到', '合', '因', '斯', '绑', '举', '睛', '淘', '祖', '起', '乱', '丹', '翩', '之', '交', '救', '转', '古', '毓', '象', '竭', '争', '厉', '劝', '方', '裹', '安', '沓', '钟', '簪', '非', '帼', '奇', '果', '玉', '校', '锁', '窍', '篇', '十', '车', '泣', '实', '鸩', '西', '失', '用', '砥', '疲', '线', '奂', '富', '丹', '菲', '间', '忍', '驰', '司', '擎', '夫', '吐', '沁', '众', '果', '婚', '锤', '竹', '章', '巫', '余', '错', '强', '扫', '餐', '里', '凌', '扫', '乐', '裘', '捭', '怡', '静', '赴', '何', '借', '蓝', '意', '上', '盾', '的', '魏', '弥', '拣', '彰', '怙', '我', '往', '就', '隙', '与', '酸', '胆', '秦', '草', '实', '千', '如', '颐', '庸', '裘', '虹', '青', '塞', '效', '莫', '经', '禁', '温', '围', '抗', '冠', '琅', '茂', '躬', '焚', '者', '雪', '任', '补', '轮', '复', '由', '滴', '家', '绌', '刀', '荡', '残', '得', '株', '豁', '监', '再', '捉', '完', '怒', '藉', '川', '草', '服', '忘', '帝', '濡', '衷', '离', '界', '滔', '驴', '若', '理', '绑', '隙', '齐', '叱', '妙', '猜', '锦', '夫', '肥', '军', '引', '冲', '羁', '五', '扮', '滴', '转', '诱', '霆', '砥', '芙', '请', '境', '李', '象', '丘', '手', '又', '矛', '枪', '尔', '难']
# ['洋', '琅', '梦', '黄', '待', '虑', '咫', '蒙', '蛇', '机', '连', '菲', '充', '墙', '参', '周', '容', '怡', '银', '幽', '福', '司', '聋', '幽', '拣', '患', '强', '五', '换', '而', '柳', '淘', '林', '劫', '目', '突', '饴', '燕', '鹰', '泽', '惺', '假', '边', '期', '猫', '奈', '狗', '戈', '张', '随', '火', '徙', '瀣', '恭', '兔', '惶', '斗', '破', '之', '凤', '救', '贻', '置', '眉', '残', '容', '横', '益', '才', '猿', '滥', '温', '藉', '摸', '扑', '淘', '上', '大', '座', '重', '赵', '腾', '里', '肆', '逍', '椟', '寒', '兴', '到', '合', '因', '斯', '绑', '举', '睛', '淘', '祖', '起', '乱', '丹', '翩', '之', '交', '救', '转', '古', '毓', '象', '竭', '争', '厉', '劝', '方', '裹', '安', '沓', '钟', '簪', '非', '帼', '奇', '果', '玉', '校', '锁', '窍', '篇', '十', '车', '泣', '实', '鸩', '西', '失', '用', '砥', '疲', '线', '奂', '富', '丹', '菲', '间', '忍', '驰', '司', '擎', '夫', '吐', '沁', '众', '果', '婚', '锤', '竹', '章', '巫', '余', '错', '强', '扫', '餐', '里', '凌', '扫', '乐', '裘', '捭', '怡', '静', '赴', '何', '借', '蓝', '意', '上', '盾', '的', '魏', '弥', '拣', '彰', '怙', '我', '往', '就', '隙', '与', '酸', '胆', '秦', '草', '实', '千', '如', '颐', '庸', '裘', '虹', '青', '塞', '效', '莫', '经', '禁', '温', '围', '抗', '冠', '琅', '茂', '躬', '焚', '者', '雪', '任', '补', '轮', '复', '由', '滴', '家', '绌', '刀', '荡', '残', '得', '株', '豁', '监', '再', '捉', '完', '怒', '藉', '川', '草', '服', '忘', '帝', '濡', '衷', '离', '界', '滔', '驴', '若', '理', '绑', '隙', '齐', '叱', '妙', '猜', '锦', '夫', '肥', '军', '引', '冲', '羁', '五', '扮', '滴', '转', '诱', '霆', '砥', '芙', '请', '境', '李', '象', '丘', '手', '又', '矛', '枪', '尔', '难', '明', '二', '应', '赴', '聋', '情', '改', '矛', '宾', '窈', '聊', '我', '觥', '运', '吁', '仁', '顺', '罗', '兄', '雪', '琅', '柔', '即', '极', '猿', '乐', '巫', '星', '占', '颐', '栗', '盲', '秋', '先', '通', '眉', '簇', '玩', '亡', '恢', '凤', '夏', '效', '寡', '见', '咫', '则', '名', '底', '骇', '映', '狮', '钓', '方', '千', '还', '不', '冲', '薪', '正', '充', '余', '皆', '名', '乱', '儒', '晕', '郑', '则', '徙', '蜃', '木', '抽', '铃', '锤', '恙', '玩', '聋', '坐', '宣']
# ['洋', '琅', '梦', '黄', '待', '虑', '咫', '蒙', '蛇', '机', '连', '菲', '充', '墙', '参', '周', '容', '怡', '银', '幽', '福', '司', '聋', '幽', '拣', '患', '强', '五', '换', '而', '柳', '淘', '林', '劫', '目', '突', '饴', '燕', '鹰', '泽', '惺', '假', '边', '期', '猫', '奈', '狗', '戈', '张', '随', '火', '徙', '瀣', '恭', '兔', '惶', '斗', '破', '之', '凤', '救', '贻', '置', '眉', '残', '容', '横', '益', '才', '猿', '滥', '温', '藉', '摸', '扑', '淘', '上', '大', '座', '重', '赵', '腾', '里', '肆', '逍', '椟', '寒', '兴', '到', '合', '因', '斯', '绑', '举', '睛', '淘', '祖', '起', '乱', '丹', '翩', '之', '交', '救', '转', '古', '毓', '象', '竭', '争', '厉', '劝', '方', '裹', '安', '沓', '钟', '簪', '非', '帼', '奇', '果', '玉', '校', '锁', '窍', '篇', '十', '车', '泣', '实', '鸩', '西', '失', '用', '砥', '疲', '线', '奂', '富', '丹', '菲', '间', '忍', '驰', '司', '擎', '夫', '吐', '沁', '众', '果', '婚', '锤', '竹', '章', '巫', '余', '错', '强', '扫', '餐', '里', '凌', '扫', '乐', '裘', '捭', '怡', '静', '赴', '何', '借', '蓝', '意', '上', '盾', '的', '魏', '弥', '拣', '彰', '怙', '我', '往', '就', '隙', '与', '酸', '胆', '秦', '草', '实', '千', '如', '颐', '庸', '裘', '虹', '青', '塞', '效', '莫', '经', '禁', '温', '围', '抗', '冠', '琅', '茂', '躬', '焚', '者', '雪', '任', '补', '轮', '复', '由', '滴', '家', '绌', '刀', '荡', '残', '得', '株', '豁', '监', '再', '捉', '完', '怒', '藉', '川', '草', '服', '忘', '帝', '濡', '衷', '离', '界', '滔', '驴', '若', '理', '绑', '隙', '齐', '叱', '妙', '猜', '锦', '夫', '肥', '军', '引', '冲', '羁', '五', '扮', '滴', '转', '诱', '霆', '砥', '芙', '请', '境', '李', '象', '丘', '手', '又', '矛', '枪', '尔', '难', '明', '二', '应', '赴', '聋', '情', '改', '矛', '宾', '窈', '聊', '我', '觥', '运', '吁', '仁', '顺', '罗', '兄', '雪', '琅', '柔', '即', '极', '猿', '乐', '巫', '星', '占', '颐', '栗', '盲', '秋', '先', '通', '眉', '簇', '玩', '亡', '恢', '凤', '夏', '效', '寡', '见', '咫', '则', '名', '底', '骇', '映', '狮', '钓', '方', '千', '还', '不', '冲', '薪', '正', '充', '余', '皆', '名', '乱', '儒', '晕', '郑', '则', '徙', '蜃', '木', '抽', '铃', '锤', '恙', '玩', '聋', '坐', '宣', '狐', '打', '措', '咫', '穷', '全', '夜', '蜃', '合', '、', '砥', '接', '穷', '插', '龙', '囊', '昙', '唇', '株', '东', '化', '冲', '位', '光', '猿', '魑', '倍', '交', '谈', '踽', '涛', '诱', '防', '燕', '大', '竭', '缺', '了', '恐', '罗', '挑', '恭', '射', '梨', '绸', '峰', '戛', '梨', '朝', '庭', '蛇', '抽', '吁', '看', '悚', '了', '尝', '二', '义', '暮', '壮', '室', '簪', '峰', '喘', '振', '缕', '怨', '陈', '炎', '贤', '下', '江', '蜀', '裹', '荣', '蒂', '颖', '山', '凰', '尾', '刀', '秀', '郎', '周', '暴', '烈', '洋', '怡', '境']
# ['洋', '琅', '梦', '黄', '待', '虑', '咫', '蒙', '蛇', '机', '连', '菲', '充', '墙', '参', '周', '容', '怡', '银', '幽', '福', '司', '聋', '幽', '拣', '患', '强', '五', '换', '而', '柳', '淘', '林', '劫', '目', '突', '饴', '燕', '鹰', '泽', '惺', '假', '边', '期', '猫', '奈', '狗', '戈', '张', '随', '火', '徙', '瀣', '恭', '兔', '惶', '斗', '破', '之', '凤', '救', '贻', '置', '眉', '残', '容', '横', '益', '才', '猿', '滥', '温', '藉', '摸', '扑', '淘', '上', '大', '座', '重', '赵', '腾', '里', '肆', '逍', '椟', '寒', '兴', '到', '合', '因', '斯', '绑', '举', '睛', '淘', '祖', '起', '乱', '丹', '翩', '之', '交', '救', '转', '古', '毓', '象', '竭', '争', '厉', '劝', '方', '裹', '安', '沓', '钟', '簪', '非', '帼', '奇', '果', '玉', '校', '锁', '窍', '篇', '十', '车', '泣', '实', '鸩', '西', '失', '用', '砥', '疲', '线', '奂', '富', '丹', '菲', '间', '忍', '驰', '司', '擎', '夫', '吐', '沁', '众', '果', '婚', '锤', '竹', '章', '巫', '余', '错', '强', '扫', '餐', '里', '凌', '扫', '乐', '裘', '捭', '怡', '静', '赴', '何', '借', '蓝', '意', '上', '盾', '的', '魏', '弥', '拣', '彰', '怙', '我', '往', '就', '隙', '与', '酸', '胆', '秦', '草', '实', '千', '如', '颐', '庸', '裘', '虹', '青', '塞', '效', '莫', '经', '禁', '温', '围', '抗', '冠', '琅', '茂', '躬', '焚', '者', '雪', '任', '补', '轮', '复', '由', '滴', '家', '绌', '刀', '荡', '残', '得', '株', '豁', '监', '再', '捉', '完', '怒', '藉', '川', '草', '服', '忘', '帝', '濡', '衷', '离', '界', '滔', '驴', '若', '理', '绑', '隙', '齐', '叱', '妙', '猜', '锦', '夫', '肥', '军', '引', '冲', '羁', '五', '扮', '滴', '转', '诱', '霆', '砥', '芙', '请', '境', '李', '象', '丘', '手', '又', '矛', '枪', '尔', '难', '明', '二', '应', '赴', '聋', '情', '改', '矛', '宾', '窈', '聊', '我', '觥', '运', '吁', '仁', '顺', '罗', '兄', '雪', '琅', '柔', '即', '极', '猿', '乐', '巫', '星', '占', '颐', '栗', '盲', '秋', '先', '通', '眉', '簇', '玩', '亡', '恢', '凤', '夏', '效', '寡', '见', '咫', '则', '名', '底', '骇', '映', '狮', '钓', '方', '千', '还', '不', '冲', '薪', '正', '充', '余', '皆', '名', '乱', '儒', '晕', '郑', '则', '徙', '蜃', '木', '抽', '铃', '锤', '恙', '玩', '聋', '坐', '宣', '狐', '打', '措', '咫', '穷', '全', '夜', '蜃', '合', '、', '砥', '接', '穷', '插', '龙', '囊', '昙', '唇', '株', '东', '化', '冲', '位', '光', '猿', '魑', '倍', '交', '谈', '踽', '涛', '诱', '防', '燕', '大', '竭', '缺', '了', '恐', '罗', '挑', '恭', '射', '梨', '绸', '峰', '戛', '梨', '朝', '庭', '蛇', '抽', '吁', '看', '悚', '了', '尝', '二', '义', '暮', '壮', '室', '簪', '峰', '喘', '振', '缕', '怨', '陈', '炎', '贤', '下', '江', '蜀', '裹', '荣', '蒂', '颖', '山', '凰', '尾', '刀', '秀', '郎', '周', '暴', '烈', '洋', '怡', '境', '谭', '厦', '仇', '攘', '逍', '机', '胡', '方', '盖', '山', '内', '中', '魅', '对', '妄', '惜', '柯', '于', '缭', '败', '独', '沽', '落', '鞠', '美', '兵', '取', '炎', '居', '夺', '穷', '救', '胡', '盾', '阳', '一', '鱼', '黄', '占', '漓', '忧', '状', '琳', '凌', '谈', '虹', '突', '谓', '臼', '恢', '殊', '忌', '壮', '粟', '改', '悲', '巢', '愚', '副', '碧', '貂', '狂', '建', '迁', '旷', '买', '起', '嗤', '烟', '纵', '邦', '眸', '还', '颜', '磨', '平', '忧', '迷', '荆', '刺', '犹', '萍', '擒', '角', '膺', '座', '枉', '左', '丽', '谢', '禽', '屋', '扑', '鸣', '愎', '场', '潜', '擒', '鞠', '宜']
