# %%
import random,time,bisect
A=[]
B=[]
C=[]
D=[]
E=[]
for i in range(1,100001):
    A.append(i)
B=A
random.shuffle(B)
for j in range(1000):
    a=random.randint(1,110001)
    C.append(a)

start_time1=time.time()
for k in B:
    if k in C:
        D.append(k)
end_time1=time.time()
B_time=end_time1-start_time1
print('在B中查找到的整数有：',D)
print('用顺序查找法在B中查找所用时间为：',B_time)
print('\n')
start_time2=time.time()
for k in C:
    if k <=100000:
        b=bisect.bisect_left(A,k)+1
        E.append(b)
end_time2=time.time()
A_time=end_time2-start_time2
print('在A中查找到的整数有：',E)
print('用二分查找法在A中查找所用时间为：',A_time)
# Out:
# 在B中查找到的整数有： [30496, 99800, 8770, 61044, 9895, 66013, 60978, 33179, 75694, 29922, 10518, 36460, 61729, 22540, 63037, 77197, 34176, 41721, 60119, 36318, 83230, 19636, 49579, 41799, 34918, 48177, 74716, 80416, 3998, 43877, 44533, 29497, 56188, 15795, 30966, 33073, 64176, 89791, 84809, 32228, 1097, 30438, 94123, 38515, 1794, 40818, 68220, 63936, 56097, 65824, 51818, 5046, 9722, 94225, 99481, 38521, 54266, 66065, 5108, 59636, 20492, 12078, 98201, 62845, 81711, 33070, 46861, 84801, 97505, 24788, 88096, 16944, 28168, 30500, 8250, 43262, 17064, 29765, 94620, 19232, 42713, 31319, 94117, 96102, 36964, 55838, 280, 51086, 57506, 45499, 79024, 50258, 34689, 4945, 89101, 32287, 38854, 89732, 3420, 97132, 37605, 28182, 43166, 14036, 12465, 29063, 72827, 24471, 63906, 40582, 52845, 52068, 72423, 9678, 7358, 26898, 53225, 40536, 8273, 68469, 25386, 32321, 37794, 14146, 64297, 75932, 79102, 31219, 35407, 14522, 12505, 88527, 14909, 33012, 73070, 96447, 39602, 4448, 24196, 41324, 31780, 23167, 17925, 5
# ...
