# %%
def get_ch_table(line):
    ch_table = []
    for ch in line:
        if ch not in ch_table:
            ch_table.append(ch)
    return ch_table
def new(n):
    import random
    idiom =[]
    fh = open(r'C:\temp\成语大全.txt')
    text = fh.read()
    chs = get_ch_table(text.replace('\n', ''))

    guess_ch_table = [ch for ch in idiom]
    while len(guess_ch_table) < 10*n:
        ch = random.choice(chs)
        if ch not in guess_ch_table:
            guess_ch_table.append(ch)
        fh = open(r'C:\temp\n.txt', 'w')
        fh.writelines(guess_ch_table)
        fh.close()
    print(guess_ch_table)
#zhuchengxu
for i in range(1,11):
    new(i)
# Out:
# ['毋', '莫', '错', '刀', '动', '秦', '穿', '嗤', '说', '假']
# ['网', '万', '虫', '起', '奈', '麟', '若', '危', '养', '囊', '作', '俊', '事', '取', '此', '马', '建', '沉', '公', '的']
# ['尺', '紫', '花', '面', '颖', '吹', '柴', '帝', '讳', '忧', '救', '制', '幽', '逑', '翩', '绸', '移', '塞', '程', '朝', '丁', '躬', '庭', '情', '道', '亭', '禽', '孑', '孟', '蝇']
# ['全', '亢', '栗', '弟', '西', '荼', '雨', '班', '诚', '叹', '良', '簇', '有', '窈', '涛', '杜', '瘁', '求', '刀', '辣', '缘', '志', '蔚', '默', '瀣', '诸', '鹰', '历', '比', '噤', '寡', '章', '结', '梦', '未', '危', '悸', '美', '七', '侃']
# ['刚', '饰', '借', '眦', '爱', '兄', '不', '天', '长', '丝', '纷', '惶', '襟', '锁', '斗', '铃', '悸', '觑', '田', '戚', '岳', '渝', '命', '映', '弥', '今', '临', '鹄', '恐', '去', '异', '趋', '落', '唇', '翁', '贤', '遂', '接', '捭', '骜', '蛙', '嗤', '瀣', '愤', '乱', '班', '占', '亲', '杀', '鸡']
# ['画', '皆', '趋', '障', '落', '弄', '拔', '期', '甚', '远', '虑', '安', '业', '经', '营', '舟', '惶', '乎', '眩', '服', '和', '夫', '才', '结', '欣', '力', '奔', '沆', '风', '癖', '境', '返', '枯', '瘁', '呈', '照', '请', '暮', '识', '奇', '恐', '指', '滴', '韦', '渝', '擎', '烂', '默', '篇', '躬', '迹', '龙', '萍', '登', '于', '叶', '始', '续', '婚', '笔']
# ['鸡', '持', '魍', '罪', '百', '帼', '载', '孜', '魉', '蜀', '兵', '左', '虚', '失', '炼', '三', '了', '苗', '阻', '愤', '殄', '随', '草', '端', '豪', '诺', '叶', '驴', '锁', '滥', '诱', '关', '教', '成', '动', '鲋', '迷', '萍', '法', '丹', '、', '讽', '月', '知', '身', '邪', '张', '邦', '韬', '茕', '怒', '愎', '舌', '栩', '恃', '龙', '水', '荫', '锱', '化', '庖', '飞', '尝', '轻', '毓', '棋', '帷', '女', '逢', '兢']
# ['兽', '罗', '狗', '逃', '昔', '加', '蛛', '末', '财', '娇', '头', '贵', '举', '纷', '较', '壮', '儒', '副', '匕', '青', '呈', '火', '牝', '枉', '燎', '惮', '赤', '择', '手', '绸', '睚', '临', '静', '称', '合', '炙', '两', '蜃', '马', '雄', '麟', '话', '开', '敬', '亦', '簇', '黔', '工', '默', '蛙', '历', '千', '玑', '著', '座', '雪', '东', '乌', '弄', '烂', '荡', '疵', '空', '续', '霆', '赴', '逑', '尾', '襟', '令', '豹', '水', '地', '冕', '钓', '薄', '鲤', '返', '木', '对']
# ['竹', '帆', '侃', '蛇', '淋', '映', '点', '拔', '愎', '端', '翼', '驯', '荏', '春', '之', '物', '到', '琴', '张', '雀', '全', '避', '猴', '动', '栗', '称', '按', '惑', '杞', '经', '青', '挑', '机', '饴', '其', '补', '衰', '众', '威', '娇', '拣', '胆', '择', '殄', '微', '座', '群', '登', '城', '声', '扮', '惯', '行', '干', '的', '改', '尘', '昔', '邦', '亭', '袖', '念', '蜀', '锱', '汗', '尸', '年', '置', '力', '对', '瀣', '接', '乘', '营', '友', '前', '邪', '夺', '公', '己', '凉', '宾', '绿', '轻', '尽', '以', '怒', '曾', '教', '沐']
# ['暴', '头', '工', '鹿', '八', '末', '餐', '梅', '预', '通', '业', '咤', '安', '兵', '抛', '坤', '川', '黩', '远', '旷', '怒', '息', '厚', '多', '肘', '猴', '耳', '腕', '荼', '悚', '新', '喝', '迹', '誉', '恃', '萍', '虑', '背', '眈', '禽', '杀', '尾', '恙', '晷', '运', '烂', '毋', '猿', '移', '说', '亦', '暗', '道', '画', '吐', '泣', '口', '庖', '其', '花', '彩', '仓', '鸠', '厦', '戛', '一', '请', '尤', '投', '铃', '帷', '虚', '殚', '乱', '掠', '甘', '日', '涂', '抽', '笑', '逑', '买', '才', '兢', '扮', '死', '涯', '对', '赶', '驹', '使', '众', '舞', '长', '鸟', '韦', '恨', '忠', '入', '珠']
