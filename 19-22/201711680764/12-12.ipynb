# %%
def get_ch_table(line):
    ch_table = []
    for ch in line:
        if ch not in ch_table:
            ch_table.append(ch)
    return ch_table

# 主程序
fh = open(r'c:\temp\idioms.txt')
text = fh.read()
chs = get_ch_table(text.replace('\n', ''))



import random

def sb(m):
    line=''
    k=[]

    for m in range(m*10): 
        id=random.choice(chs)
        line=line+id
        k.append(id)
    
    print(line)

    ido=line.split('\n')
    

    fh = open(r'c:\temp\1.txt', 'w')
    fh.writelines(ido)
    fh.close()
sb(1)

def sb(m):
    line=''
    k=[]

    for m in range(m*10): 
        id=random.choice(chs)
        line=line+id
        k.append(id)
    
    print(line)

    ido=line.split('\n')
   

    fh = open(r'c:\temp\2.txt', 'w')
    fh.writelines(ido)
    fh.close()
sb(2)

def sb(m):
    line=''
    k=[]

    for m in range(m*10): 
        id=random.choice(chs)
        line=line+id
        k.append(id)
    
    print(line)

    ido=line.split('\n')
 

    fh = open(r'c:\temp\3.txt', 'w')
    fh.writelines(ido)
    fh.close()
sb(3)

def sb(m):
    line=''
    k=[]

    for m in range(m*10): 
        id=random.choice(chs)
        line=line+id
        k.append(id)
    
    print(line)

    ido=line.split('\n')

    fh = open(r'c:\temp\4.txt', 'w')
    fh.writelines(ido)
    fh.close()
sb(4)

def sb(m):
    line=''
    k=[]

    for m in range(m*10): 
        id=random.choice(chs)
        line=line+id
        k.append(id)
    
    print(line)

    ido=line.split('\n')

    fh = open(r'c:\temp\5.txt', 'w')
    fh.writelines(ido)
    fh.close()
sb(5)


def sb(m):
    line=''
    k=[]

    for m in range(m*10): 
        id=random.choice(chs)
        line=line+id
        k.append(id)
    
    print(line)
    ido=line.split('\n')

    

    fh = open(r'c:\temp\6.txt', 'w')
    fh.writelines(ido)
    fh.close()
sb(6)

def sb(m):
    line=''
    k=[]

    for m in range(m*10): 
        id=random.choice(chs)
        line=line+id
        k.append(id)
    
    print(line)
    
    ido=line.split('\n')

    fh = open(r'c:\temp\7.txt', 'w')
    fh.writelines(ido)
    fh.close()
sb(7)

def sb(m):
    line=''
    k=[]

    for m in range(m*10): 
        id=random.choice(chs)
        line=line+id
        k.append(id)
    
    print(line)

    ido=line.split('\n')
   

    fh = open(r'c:\temp\8.txt', 'w')
    fh.writelines(ido)
    fh.close()
sb(8)

def sb(m):
    line=''
    k=[]

    for m in range(m*10): 
        id=random.choice(chs)
        line=line+id
        k.append(id)
    
    print(line)

    ido=line.split('\n')
    

    fh = open(r'c:\temp\9.txt', 'w')
    fh.writelines(ido)
    fh.close()
sb(9)

def sb(m):
    line=''
    k=[]

    for m in range(m*10): 
        id=random.choice(chs)
        line=line+id
        k.append(id)
    
    print(line)

    ido=line.split('\n')
    

    fh = open(r'c:\temp\10.txt', 'w')
    fh.writelines(ido)
    fh.close()
sb(10)
# Out:
# 助七立宜言捭井乌缚郸
# 忠取墨秒疲司幽沙禁上公虹随次薄齿圆奈怡久
# 胜间藏之乾穿衣肆桃平兽旁秒残补亭悚履雅觑故圆菲位苟琴是底皆陷
# 沙喝衷窍焚占惯烈恐虹忍优退好从聋狭吼忾窈革吐画血温阋宜乘蓝嚎观辟美懈濡状臼胜琴韵
# 滥豹蛛丘暖矢用患影难后吹久愿所鲤丧书鹄棋聋规泪娲新法疵丝守秽挑戛砖牛摸辟盗兴美娇重称阳为黔迹莫泣刺翼
# 海阿进腹越尘攘秽厚釜温死越越甘投功相喻士卑落欺眦障者夫恨窕患伦落而匕犀司劫惑边当柴殚哭监茧釜始意固凤骜期自尤鼻素割坐咤钟
# 粉继仪迹视炎苛衣韬歧座木擒怨己明良闻怒岂鸣满矫彰眉业七维惊韬羁魏名兄妻将癖腾枯荆卧忠沆角天盘诸冠四虎蒂缘儆菲接仆飘锦司糊破福也潭其燕肓学善投
# 随冰外逝坤诱敏占朋鼎孤暖变假喜倒边数红秣钟恢营财来转矛恨鹤抽涯沐监男誉荦能逍迹羁亢运年接化求迹恶糊掌禁躇必营蛇绸晴的鳞强拔金源双怒待淘猫晕联穿已青今围孑帷化缪热
# 黔爱肓历染睛先负缝鹊著唳置仪才星大钓诚忍堂理止步假岸讳遥孤极殄放货壳豁璞肆荼斗归恭对叱兽残雪惭玑乌桀赴价耻于攘丝鹰殚斩者鹊性饴岂交居厉比强丘燎笔多纵辣虫烟境座锋儒子胆如柯次癖糊豹络
# 化鲤怪灯魉带淫仰郎坐怪程宠魑栋外是仁朵清瞥暮怡借君朋内言路衣魅窍掌知若笑蛾尘富流摸立琴程瞻吁后亭乘喘络脾鸠尉卷心争眸乘能恢措纶儆弥镳间泪辣雁脱倒关衷贵达打双益麟视缭酒厦晕简韦当玩桀树帝赴后涛小其吐此西
