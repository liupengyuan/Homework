# %%
def ac(m,n):
    for j in range(1,n+1):
        print(' '*(10-j)+m*j+' '+m*5+' '+m*j)
    print()
    return 


print(ac("*",5))
# Out:
#          * ***** *
#         ** ***** **
#        *** ***** ***
#       **** ***** ****
#      ***** ***** *****
#
# None

# %%
def A(m,n):
    if m==0:
        return n+1
    if m>0 and n==0:
        return A(m-1,1)
    if m>0 and n>0:
        return A(m-1,A(m,n-1))
print(A(3,4))
# Out:
# 125

# %%
#3(1)
import random
for i in range(0,15):
    a=random.randint(3,25)
    b=random.randint(3,25)
    c=['+','-','*','/']
    d=random.choice(c)
    m='{},{},{}'.format(a,d,b)
    if c=='-':
        if a-b>0:
            print(a,d,b)
    else:
        print(a,d,b)
# Out:
# 18 * 25
# 4 - 19
# 13 / 14
# 6 + 11
# 6 * 15
# 4 * 3
# 22 / 25
# 4 + 9
# 10 * 20
# 17 / 13
# 23 - 20
# 4 + 22
# 24 + 15
# 16 * 14
# 25 / 16

# %%
 #3(2)
import random
h=[]
k=[]
q=0
for i in range(0,5):
    a=random.randint(3,5)
    b=random.randint(3,5)
    c=('+','-','*','/')
    d=random.choice(c)
    m='{},{},{}'.format(a,d,b)
    s=0
    if c=='-' and a-b>0:
        k=[a-b,"-"]
        print(a,d,b)
        
            
    if c=="+":
        k=[a+b,"+"]
        print(a,d,b)
        
        
    if c=='*':
        k=[a*b,"*"]
        print(a,d,b)
        q=q+1
        
    if c=='/':
        k=[a/b,"/"]
        print(a,d,b)
        q=q+1
    h.append(k)
               
m=str(input('the answer is'))
liu=list(m)
for i in len(liu):
    if h[i][0]==liu[i]:
        s=s+5
print(s+5*q)

# %%
#3(3)
import random
s=0
for i in range(0,10):
    k=input('entering format is like this:5*2=')
    g=int(input('加法,减法,除法,乘法请输入1,2,3,4'))
    l=list(k)
    a=int(l[0])
    c=int(l[2])
    print(a,b,c,'=')
    y=random.randint(0,10000)
    print('the answer is :',y)
    if g==1:
        h=a+c
        if y==h:
            s=s+5
            
    if g==2 and a-c>0:
        if y==a-c:
            s=s+5
    if g==4:
        h=a*c
        if y==h:
            s=s+10
    if g==3:
        h=a/c
        if y==h:
            s=s+10
print(s)
# Out:
# entering format is like this:5*2=6+9
# the answer is : 7584
# 0

# %%
#4(1)
with open (r'D:\Temp\成语大全(含成语解释)_utf8.txt',encoding = 'utf-8') as f:
    b=f.read()
    C=[]
    for line in b:
        for m in line:
            k=m[1:5]
            C.append(k)
    print(C)
    
    
#4(2)
with open (r'C:\Users\Administrator\Desktop\test_re_gbk (5).txt',encoding = 'utf-8') as fh:
    j=fh.read()
    k={}
    for item in C:
        if item in k:
            k[item]+=1
        else:
            k[item]=1
    print(k)
    for r in range(20):    
        for key,value in k.items():
            print([key,value])
# Out:
# ['', '', '', '', '', '', '', '', '', '']

# %%
#4(3)
with open (r'D:\Temp\1.txt') as fh:
    b=fh.read()

    
with open(r'd:\temp\1.txt') as f:
    t=[]
    l={}
    for line in f:
        k=[word.split('/')for word in line.split()]
        print(k)
    for m in k:
        c=m[1]
        t.append(c)
    for h in t:
        if h not in l:
            l[h]=1
        if h in l:
            l[h]+=1
    print(l)
# Out:
# [['习近平', 'nrfg'], ['新年贺词', 'l'], ['为', 'p'], ['人民', 'n'], ['点', 'm'], ['赞', 'v']]
# [['发表', 'v'], ['二', 'm'], ['〇', 'x'], ['一', 'm'], ['五年', 't'], ['新年贺词', 'l'], ['提出', 'v'], ['开弓', 'nz'], ['没有', 'v'], ['回头', 'v'], ['箭', 'n'], ['改革', 'vn'], ['关头', 'n'], ['勇者胜', 'i']]
# [['新年好', 'l']]
# ...
