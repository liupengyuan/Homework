# %%
#随机生成1万个整数，范围在0-10万之间，求其中每个整数出现的次数。并按照整数大小排序输出整数及出现次数。

# %%
import random
q=[]
for i in range(10000):
    q.append(random.randint(0,100000))

dict={}
for o in q:
    if o not in dict:
        dict[o]=1
    else:
        dict[o]+=1

for key in sorted(dict.keys()):
    print(key, dict[key])
# Out:
# 1 1
# 3 1
# 6 1
# 16 1
# 34 1
# 45 1
# 56 1
# 64 1
# 69 1
# 72 1
# 92 1
# 110 1
# 126 1
# 134 1
# 140 1
# 146 1
# 155 1
# 158 2
# 163 1
# 164 1
# 182 1
# 207 1
# 214 1
# 219 1
# 222 1
# 232 1
# 246 1
# 250 1
# 263 1
# 274 1
# 276 1
# 306 1
# 321 1
# 323 1
# 342 2
# 346 1
# 349 1
# 353 1
# 362 1
# 366 1
# 373 1
# 413 1
# 416 1
# 420 1
# 423 1
# 437 1
# 438 1
# 492 1
# 494 1
# 497 1
# 511 1
# 513 1
# 526 1
# 532 1
# 534 1
# 556 1
# 566 1
# 595 1
# 623 1
# 630 1
# 640 1
# 653 1
# 663 1
# 668 1
# 686 1
# 689 1
# 710 1
# 748 1
# 755 1
# 778 1
# 789 1
# 790 1
# 811 1
# 822 1
# 828 1
# 837 1
# 838 1
# 844 1
# 854 1
# 868 1
# 902 1
# 904 1
# 905 1
# 908 1
# 914 1
# 917 1
# 921 1
# 923 1
# 927 1
# 936 1
# 937 1
# 938 1
# 958 1
# 996 1
# 1007 1
# 1033 2
# 1040 1
# 1042 1
# 1074 1
# 1076 1
# 1082 1
# 1083 1
# 1092 1
# 1135 1
# 1137 1
# 1142 1
# 1162 1
# 1170 1
# 1173 1
# 1175 1
# 1180 1
# 1190 1
# 1194 1
# 1195 1
# 1198 1
# 1224 1
# 1240 1
# 1258 1
# 1259 1
# 1260 1
# 1272 1
# 1273 1
# 1285 1
# ...

# %%
#对本任务中的语料.txt文件，抽取其5001-10000行存为test1.txt文件，写函数，可得到其与本任务中test.txt文件的共用字以及独用字（相关概念自行百度）。

# %%
with open(r'C:\Users\t.txt') as f:
    fh=open(r'C:\Users\text.txt', 'w')
    fh.writelines(f.readlines()[1:5000])
    fh=open(r'C:\Users\text.txt')
    text=fh.read()
with open(r'C:\Users\t.txt') as f:
    fh1 = open(r'C:\Users\text1.txt', 'w')
    fh1.writelines(f.readlines()[5001:100000])
    fh1=open(r'C:\Users\text1.txt')
    text1=fh1.read()


fh.close
fh1.close

text = text.replace('、', '')
text1 = text1.replace('、', '')
s=set(text)
s1=set(text1)
i=s1.intersection(s)
l=list(i)
print('共用字',l)
i1=s1.difference(s)
l1=list(i1)
print('独用字',l1)
# Out:
# 共用字 ['卷', '制', '酪', '撰', '氧', '奠', '症', '昔', '翅', '堤', '疏', '秃', '爬', '豫', '珠', '思', '盗', '竺', '晶', '沿', '教', '庸', '句', '弗', 'o', '驳', '慰', '婚', '裤', '系', '屠', '昊', '负', '扬', '衷', '股', '振', '省', '蓝', '院', '短', '侣', '就', '煦', '库', '呕', '？', 'B', '失', '运', '澎', '拯', '俯', '寰', '嗨', '胁', '鸣', '胡', '兄', '径', '琛', '关', '拨', '腕', '窃', '记', '演', '勉', '氨', '筋', '映', '逅', '价', '版', '澡', '盔', '集', '袭', '凋', '辫', '轰', '杰', '乡', '贾', '厨', '乒', '哨', '词', '暖', '梅', '史', '培', '荧', '焚', '蛙', '翟', '绿', '对', '给', '多', '熊', '翔', '熠', '迈', '柯', '伴', '盼', '帆', '侥', '盈', '式', '8', '纵', '互', '℃', '放', '撮', '喘', '好', '橙', '辗', '摸', '拾', '所', '圈', '凯', '书', '牺', '沐', 'N', '拂', '境', '焦', '粘', '邮', '夸', '房', '裸', '故', '锣', '何', '俐', '棍', '淫', '鹈', '容', '来', '“', '称', '崭', '嫁', '萌', '懊', '叶', '赚', '铃', '鹅', '纶', '益', '告', '休', '已', '隔', '岗', '硬', '凸', '澳', '许', '串', '茫', '畴', '蔽', '班', '_', '享', '截', 'l', '额', '狼', '甄', '生', '俭', '赶', '们', '袱', '牧', '床', '并', '什', '口', '骑', '弹', '亢', '牲', '麻', '掀', '寸', '金', '蠢'
# ...

# %%
from collections import Counter
with open(r'C:\Users\t.txt') as f:
    text = f.read()
    f.close
    words = [word.split('/')[0] for word in text.split()]
key=sorted(dict(Counter(words)).items(),key=lambda item:item[1])
L50=key[(len(key)-51):-1]
print(L50)
list1=[]
for o in L50:
    list1.append(o[0])
    

w=[w.split('/') for w in text.split()]
list2=[]
for i in w:
    if i[1] not in list2:
        list2.append(i[1])
print(list2)

h=[h for h in text.split()]
a=dict(Counter(h)).items()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-cc444815eeb9> in <module>()
#       4     f.close
#       5     words = [word.split('/')[0] for word in text.split()]
# ----> 6 key=sorted(dict(Counter(words)).items(),key=lambda item:item[1])
#       7 L50=key[(len(key)-51):-1]
#       8 print(L50)
#
# TypeError: 'dict' object is not callable
