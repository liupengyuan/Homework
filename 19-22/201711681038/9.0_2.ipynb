# %%
#随机生成1万个整数，范围在0-10万之间，求其中每个整数出现的次数。并按照整数大小排序输出整数及出现次数。
import random
a=[random.randint(1,100001) for i  in range (10000)]
b=[]
c={}
for num in a :
    if num%10==0:
        b.append(num)
i=1
for x in b :
    if x in c: 
        c[x] += 1
    else: 
        c[x] = 1
        
print(sorted(c.items(),key=lambda  item:item[1]))
# Out:
# [(5160, 1), (82590, 1), (9310, 1), (15480, 1), (27130, 1), (33100, 1), (69460, 1), (76680, 1), (29830, 1), (18080, 1), (55770, 1), (89560, 1), (17790, 1), (51060, 1), (52530, 1), (41200, 1), (89670, 1), (9520, 1), (72930, 1), (14850, 1), (72810, 1), (69440, 1), (830, 1), (62770, 1), (8520, 1), (59310, 1), (65800, 1), (81830, 1), (29550, 1), (78290, 1), (81670, 1), (44540, 1), (65940, 1), (97990, 1), (65440, 1), (80, 1), (64140, 1), (42430, 1), (35450, 1), (27380, 1), (93100, 1), (20240, 1), (41280, 1), (77940, 1), (80030, 1), (55730, 1), (15030, 1), (30060, 1), (1480, 1), (72940, 1), (95140, 1), (53090, 1), (38020, 1), (27400, 1), (39290, 1), (35480, 1), (22440, 1), (64380, 1), (81380, 1), (63800, 1), (49140, 1), (30130, 1), (4850, 1), (86180, 1), (40140, 1), (95220, 1), (41430, 1), (16560, 1), (47160, 1), (60670, 1), (8580, 1), (65870, 1), (87730, 1), (88160, 1), (31310, 1), (44750, 1), (29970, 1), (16620, 1), (35140, 1), (59230, 1), (36210, 1), (42770, 1), (60560, 1), (35150, 1), (
# ...

# %%
#、对本任务中的语料.txt文件，抽取其5001-10000行存为test1.txt文件，
#写函数，可得到其与本任务中test.txt文件的共用字以及独用字（相关概念自行百度）。
with open(r'c:\temp\test1.txt', 'w') as fw, open(r'c:\temp\语料.txt') as fr:
    line_number = 0
    for line in fr:
        if line_number < 5001:
            line_number += 1
        elif 5000 <line_number < 10001 :
            fw.write(line)
            line_number += 1

def get_ch_table(line):
    ch_table = []
    for ch in line:
        if ch not in ch_table:
            ch_table.append(ch)
    return ch_table

def zi(a,b):
    gong=[]
    du1=[]
    du2=[]
    for x in b:
        if x in a:
            gong.append(x)
        else:
            du2.append(x)
    for y in a:
        if a not in gong:
            du1.append(y)
    print('共用字是： ',gong)
    print('语料的独用字是： ',du1)
    print('test1的独用字是： ',du2)

f1 = open(r'c:\temp\语料.txt')
text = f1.read()
a= get_ch_table(text.replace('\n', ''))
f2 = open(r'c:\temp\test1.txt')
text = f2.read()
b= get_ch_table(text.replace('\n', ''))

zi(a,b)
# Out:
# 共用字是：  ['1', '2', '/', 'm', ' ', '岁', '移', '民', 'n', '美', '国', 's', '工', '龄', '7', '年', '刘', '文', '健', 'r', '3', '，', 'x', '时', 't', '随', 'd', '父', '母', '从', 'p', '中', '至', '已', '当', '警', '察', 'v', '据', '信', '是', '纽', '约', '局', '第', '一', '名', '值', '勤', 'a', '遇', '害', '的', 'u', 'j', '华', '裔', '。', '因', '要', 'c', '等', '待', '亲', '属', '赶', '来', '他', '葬', '礼', '经', '推', '迟', '举', '行', '家', '独', '子', '在', '上', 'f', '说', '：', '“', '你', '最', '棒', '儿', '…', '我', '们', '以', '为', '傲', '永', '远', '爱', '”', '前', '刚', '结', '婚', '两', '个', '月', '遗', '孀', '（', '图', '）', '4', '日', '表', '示', '精', '神', '伴', '侣', '英', '雄', '将', '心', 'i', '■', '现', '场', '插', '曲', '市', '长', '致', '辞', '背', '对', '抗', '议', 'z', '德', '布', '拉', '西', '奥', '悼', '词', '数', '百', '转', '身', '发', '支', '持', '种', '族', '歧', '视', 'l', '和', '滥', '用', '暴', '力', '言', '论', '与', '方', '关', '系', '紧', '张', '公', '职', '人', '员', '殉', '怎', '么', '做', '？', '阿', '根', '廷', '全', '齐', '鸣', '笛', '0', '首', '都', '宜', '诺', '斯', '艾', '利', '处', '档', '案', '仓', '库', 
# ...

# %%
#挑战性任务：统计本任务中的语料.txt文件，得到每一个词对应不同词性的频次，可表示为：{词:[['n',1000], ['v', 98]...],...}，
#即在dict对象中，key为词，value为列表，输出词频最高的50个条目。
filename = r'c:\temp\语料.txt'

word1 = set()
with open(filename) as f:
    for line in f:
        word1 |= {word.split('/')[0] for word in line.split()}

word2=[]
with open(filename) as f:
    for line in f:
        word2 += [word.split('/') for word in line.split()] 

import random
word50={}
i=1
for word in word1 :
    if word in word50: 
        word50[word] += 1
    else: 
        word50[word] = 1
print(sorted(word50.items(),key=lambda  item:item[1],reverse=True)[:50])
word11=sorted(word50.items(),key=lambda  item:item[1],reverse=True)[:50]

list1=[]
list2={}
list=[]
for a in word50:
    for b in word1:
        n=word11.index(b)
        list1.append(word2[n][1])
    for item in list1:
        if item in list2:
            list2[item] +=1
        else:
            list2[item] =1
    sorted(list2.items(),key=lambda  item:item[1],reverse=True)
    list.append(llist2)

total=[]
for word in word50:
    x=[]
    m=word50(word)
    append.x(word)
    append.x(list[m])
    append.total(x)
print(total)

#啊啊啊，不知道怎么改好了，感觉有很多问题但是不知道怎么改对。
# Out:
# [('', 1), ('眉弓', 1), ('咪', 1), ('GDI', 1), ('真实性', 1), ('齐涨', 1), ('咱', 1), ('富成', 1), ('致使', 1), ('来函', 1), ('小小的', 1), ('大奖', 1), ('难保', 1), ('疲态', 1), ('干', 1), ('边地', 1), ('280', 1), ('vip', 1), ('瘴气', 1), ('首映式', 1), ('哈伯', 1), ('变差', 1), ('会场', 1), ('巡演', 1), ('无檐', 1), ('诟病', 1), ('删除', 1), ('学子', 1), ('亚麻酸', 1), ('中风', 1), ('瓦尔斯', 1), ('工作', 1), ('A330', 1), ('肃清', 1), ('付', 1), ('6931', 1), ('庙', 1), ('鱼龙混杂', 1), ('嗯', 1), ('何事', 1), ('阿基诺', 1), ('崇文门', 1), ('攻势', 1), ('常有', 1), ('请愿', 1), ('现实', 1), ('之来', 1), ('敬爱', 1), ('玛格丽特', 1), ('飞跃', 1)]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-24be29c1bd21> in <module>()
#      29 for a in word50:
#      30     for b in word1:
# ---> 31         n=word11.index(b)
#      32         list1.append(word2[n][1])
#      33     for item in list1:
#
# ValueError: '' is not in list
