# %%
import random

fh = open(r'c:\temp\成语大全.txt')
text = fh.read()
fh.close()

text = text.replace('、', '')
idioms = text.split('\n')

correct_idioms=[]
fh = open(r'c:\temp\idioms_correct.txt', 'w')
for idiom in idioms:
    correct_idioms.append(idiom+'\n')
fh.writelines(correct_idioms)
fh.close()

def welcome():
    print(
        '''
           ======欢迎来到猜数游戏=======
        
                     /  \     ,    ,
           _._     _ |oo| _  / \__/ \
    
          _||||   ((/ () \))   /   \
    
          |||||/|  ( ==== )    |oo|    
           \____/  _`\  /'_    /   \
    
           /   /.-' /\<>/\ `\.( () )_._      
           |    `  /  \/  \  /`'--'////)
            \__,-'`|  |.  |\/ |/\/\|"\"` 
                   |  |.  | \___/\___/  
                   |  |.  |   |    |
          
          ======欢迎来到猜数游戏=======
        '''
    )


def win():
    print(
        '''
           ======恭喜你，你赢了=======
        
    
                ."".    ."",
                |  |   /  /
                |  |  /  /
                |  | /  /
                |  |/  ;-._ 
                }  ` _/  / ;
                |  /` ) /  /
                | /  /_/\_/\
                |/  /      |
                (  ' \ '-  |
                 \    `.  /
                  |      |
                  |      |
          
          ======恭喜你，你赢了=======
        '''
    )
    
def lose():
    print(
        '''
           ======YOU LOSE=======
        
    
                

                   .-"      "-.
                  /            \
                 |              |
                 |,  .-.  .-.  ,|
                 | )(__/  \__)( |
                 |/     /\     \|
       (@_       (_     ^^     _)
  _     ) \_______\__|IIIIII|__/__________________________
 (_)@8@8{}<________|-\IIIIII/-|___________________________>
        )_/        \          /
       (@           `--------`
       
       
       
          ======YOU LOSE=======
        '''
    )

def game_over():
    print(
        '''
           ======GAME OVER=======
        
             _________ 
            / ======= \ 
           / __________\ 
          | ___________ | 
          | | -       | | 
          | |         | | 
          | |_________| |________________ 
          \=____________/                ) 
          / """"""""""" \               / 
         / ::::::::::::: \          =D-' 
        (_________________) 

       
          ======GAME OVER=======
        '''
    )    

def show_team():
    print('最最聪明的张菁')

def show_instruction():
    print('成语接龙，就是要求你猜的成语的第一个字和上一个成语的最后一个字相同')

def menu():
    print('''=====游戏菜单=====
                1. 游戏说明
                2. 开始游戏
                3. 退出游戏
                4. 制作团队
             =====游戏菜单=====''')
             

    
def game():
    b=1
    timu=str(input('请输入一个成语： '))
    a = list(timu)  
    idioms = text.split()
    for idiom in idioms:
        new=list(idiom)
        if new[0]==a[3]:
            print('计算机找到了',idiom)
            break
    else :
        print('计算机没有找到可以接龙的成语啦！')
        win()
    b=int(input('是否要继续游戏？ 是请输入1，否请输入2： '))
    if b==1:
        while b<2:
            timu=str(input('请输入一个成语： '))
            a = list(timu)  
            if a[0]==new[3]:
                for idiom in idioms:
                    new=list(idiom)
                    if new[0]==a[3]:
                        print('计算机找到了',idiom)
                        break
                else :
                    print('计算机没有找到可以接龙的成语啦！')
                    win()
                    break
                b=int(input('是否要继续游戏？ 是请输入1，否请输入2： '))
                if b==1:
                    b=1
                else:
                    lose()
            else:
                lose()
                print('你输入的成语不符合接龙规则！！！')
                break
           
            
    else:
        lose()

def main():
    while True:
        menu()
        choice = int(input('请输入你的选择'))
        if choice == 1:
            show_instruction()
        elif choice == 2:
            game()
        elif choice == 3:
            game_over()
            break
        else:
            show_team()

#游戏失败的情况：
#1.自己放弃
#2.输入了不符合游戏规则的成语

#主程序
main()
# Out:
# =====游戏菜单=====
#                 1. 游戏说明
#                 2. 开始游戏
#                 3. 退出游戏
#                 4. 制作团队
#              =====游戏菜单=====
# 请输入你的选择2
# 请输入一个成语： 心如止水
# 计算机找到了 水木清华
# 是否要继续游戏？ 是请输入1，否请输入2： 1
# 请输入一个成语： 家庭和睦
#
#            ======YOU LOSE=======
#
#
#
#
#                    .-"      "-.
#                   /                             |              |
#                  |,  .-.  .-.  ,|
#                  | )(__/  \__)( |
#                  |/     /\     \|
#        (@_       (_     ^^     _)
#   _     ) \_______\__|IIIIII|__/__________________________
#  (_)@8@8{}<________|-\IIIIII/-|___________________________>
#         )_/        \          /
#        (@           `--------`
#
#
#
#           ======YOU LOSE=======
#
# 你输入的成语不符合接龙规则！！！
# =====游戏菜单=====
#                 1. 游戏说明
#                 2. 开始游戏
#                 3. 退出游戏
#                 4. 制作团队
#              =====游戏菜单=====
# 请输入你的选择3
#
#            ======GAME OVER=======
#
# ...
