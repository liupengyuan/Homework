# %%
fh = open(r'c:\temp\idioms.txt')
text = fh.read()
fh.close()

text = text.replace('、', '')
idioms = text.split('\n')


fh = open(r'c:\temp\idioms_correct.txt', 'w')
fh.writelines(idioms)
fh.close()

fh = open(r'c:\temp\idioms_correct.txt', 'w')
idioms = [idiom + '\n' for idiom in idioms]
fh.writelines(idioms)
fh.close()

fh = open(r'c:\temp\idioms_correct.txt', 'w')
fh.write('\n'.join(idioms))
fh.close()

def get_ch_table(line):
    ch_table = []
    for ch in line:
        if ch not in ch_table:
            ch_table.append(ch)
    return ch_table

# 主程序
fh = open(r'd:\temp\idioms_correct.txt')
text = fh.read()
chs = get_ch_table(text.replace('\n', ''))

import random
idioms = text.split()
l=[]
def shu(m):
    print(m,':')
    for i in range(m):
        idiom = random.choice(chs)
        l.append(idiom)
        print(idiom,end='')
    print( )

l=[]
m=10    
shu(m)
fh = open(r'c:\temp\1.txt', 'w')
fh.write('\n'.join(l))
fh.close()

m=20    
shu(m)
fh = open(r'c:\temp\2.txt', 'w')
fh.write('\n'.join(l))
fh.close()

m=30    
shu(m)
fh = open(r'c:\temp\3.txt', 'w')
fh.write('\n'.join(l))
fh.close()
    
m=40    
shu(m)
fh = open(r'c:\temp\4.txt', 'w')
fh.write('\n'.join(l))
fh.close()
    
m=50    
shu(m)
fh = open(r'c:\temp\5.txt', 'w')
fh.write('\n'.join(l))
fh.close()
    
m=60    
shu(m)
fh = open(r'c:\temp\6.txt', 'w')
fh.write('\n'.join(l))
fh.close()
    
#表示不知道怎么通过循环来改文件名
# Out:
# 10 :
# 沉砖缝壁货燎肥枯覆淋
# 20 :
# 惊齿耳胜固去闺躬迹股渝象奂青阋虑报厉墙刀
# 30 :
# 篇穿讽吹穴迟仆玑锱乐窟前荏中豹陷心漫杜礼虹壁大炎赴角喜孟蝉源
# 40 :
# 镜犬让喘望皇班鹄观单尔禽堂巷了罗针宝黔助翅裘湖河宾紫夏照亢市怒飘秋膏禁梅苍朵簪达
# 50 :
# 帆亭喝深杏血飞宜没鲋以玑族枉才苦补克涯猫后间肝蹴陇坐起粉掠猿甚盘集朵任苛苗浮星染诨前乐孟牢可阻卑死马
# 60 :
# 狭驯黔安价瓜蒂绌鹤化甚盖所较婚北乐川始杞班期提蛙逝衷壮叹掣夜乱劝路趋人孤锲亢族娲次枉入故分可能必瞻忘魏帘披字群悚投文邯永
