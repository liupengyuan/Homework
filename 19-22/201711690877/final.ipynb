# %%
def tixing(symbol,n):
    symbol2 = symbol+' '
    for i in range(1,n+1):
        print(' '*(n-i)*2+i*symbol2+n*symbol+' '+i*symbol2)
        
tixing('*',5)
# Out:
#         * ***** *
#       * * ***** * *
#     * * * ***** * * *
#   * * * * ***** * * * *
# * * * * * ***** * * * * *

# %%
def ackermann(m,n):
    if m == 0:
        result = n+1
    elif m > 0 and n == 0:
        m ,n = m-1,1
        return m,n,
    elif m > 0 and n > 0:
        m,n = m-1,ackermann(m,n-1)
        
        return m,n
    
print(ackermann(3,4))
# Out:
# (2, (2, (2, (2, (2, 1)))))

# %%
import random
def que(a,b,n):
    for i in range(1,n+1):
         num_1 = random.randint(a,b)
         num_2 = random.randint(a,b)
         yunsuans = ['+','-','/','*']
         yunsuan = yunsuans[random.randint(0,3)]
        
         if yunsuan =='/':
                if num_1% num_2==0:
                    print(str(num_1)+yunsuan+str(num_2)+'=')
         else:
             print(str(num_1)+yunsuan+str(num_2)+'=')
             
que(3,25,15)
# Out:
# 13-11=
# 13*7=
# 21*20=
# 25+12=
# 19+3=
# 14-21=
# 4*8=
# 19+22=
# 21/3=
# 15*5=
# 14+18=
# 10*3=

# %%
p_ans = int(input('请输入您的答案，用逗号隔开：'))
score = 0
for i in range (0,15):
    if p_ans[i] = c_ans[i]:
        if yunsuan in ['+','-']:
            score +=5
        elif yunsuan in ['*','/']:
            score += 10
    else:
        score += 0
print(score)

# %%
def jisuan(n):
    while i<n:
        q = input()
        a =  
    for i in range (0,n+1):
        if p_ans[i] = c_ans[i]:
            if yunsuan in ['+','-']:
                score +=5
            elif yunsuan in ['*','/']:
                score += 10
        else:
            score += 0
    print(score)
jisuan(10)

# %%
def ord_freq_pairs():
    with open (r'C:\Users\Administrator\Downloads\成语大全(含成语解释)_utf8.txt',encoding = 'utf-8') as f:
    
        A = {line[:5] for line in f }
    word_table = []    
    with open (r'C:\Users\Administrator\Downloads\test_re_gbk.txt') as f_2:
        text = f_2.read()

    for idiom in A:
        num = text.count(idiom)
        word_table.append([idiom,num])
        return word_freq_pairs

print(sord_freq_pairs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-7fa7a8efc49a> in <module>()
#      12         return word_freq_pairs
#      13
# ---> 14 print(sord_freq_pairs)
#
# NameError: name 'sord_freq_pairs' is not defined

# %%
def get_word_table():
    word_table = []
    with open (r'C:\Users\Administrator\Downloads\test_re_gbk.txt') as f_3:
        text = f_3.read()
    words = [word.split('/')[0] for word in text.split()]
    for word in words:
        if word not in word_table:
            word_table.append(word)
        elif word in
    return word_table


print(get_word_table())
# Out:
# ['习近平', '新年贺词', '为', '人民', '点', '赞', '发表', '二', '〇', '一', '五年', '提出', '开弓', '没有', '回头', '箭', '改革', '关头', '勇者胜', '新年好', '“', '5', '、', '4', '3', '2', '1', '，', '新年快乐', '！', '”', '今天', '零时', '奥林匹克', '中心区', '主会场', '梦想', '辉映', '冰雪', '北京', '同心', '欢聚', '诚邀', '五环', '2015', '年', '新年', '倒计时', '活动', '举行', '。', '与此同时', '延庆', '八达岭长城', '分会场', '和', '张家口', '崇礼', '同步', '联动', '汇聚', '起', '三地', '万众', '对', '申办', '2022', '冬奥会', '的', '热情', '期待', '首席', '摄影记者', '蔡', '代征', '', '摄', 'A02', '版', '·', '要闻', '时事', 'A03', '新闻', '公积金', '贷款', '上限', '今', '起调', '至', '120', '万', 'A06', '呼格', '吉勒', '图', '父母', '获', '赔偿', '206', '万元', 'A11', '国内新闻', '一年', '大', '涨', '千点', 'A股', '完美', '收官', 'A15', '经济', '我们', '各级', '干部', '也', '是', '蛮', '拼', '国家', '主席', '●', '向', '南水北调', '40', '移民', '致敬', '我', '要', '伟大', '时间', '过', '得', '真快', '2014', '就要', '过去', '了', '正在', '走来', '在', '这', '辞旧迎新', '时刻', '全国', '各族人民', '香港特别行政区', '同胞', '澳门特别行政区', '台湾同胞', '海外侨胞', '世界', '各国', '各', '地区', '朋友', '们', '致以', '祝福', '令人难忘', '锐意', '推进改革', '啃下', '不少', '硬
# ...

# %%
def get_ch_table(line):
    ch_table = []
    for ch in line:
        if ch not in ch_table:
            ch_table.append(ch)
    return ch_table



fh = open (r'C:\Users\Administrator\Downloads\test_re_gbk.txt')
text = fh.read()
chs = get_ch_table(text.replace('n',''))
print(len(chs),chs)
# Out:
# 4040 ['习', '近', '平', '/', 'r', 'f', 'g', ' ', '新', '年', '贺', '词', 'l', '为', 'p', '人', '民', '点', 'm', '赞', 'v', '\n', '发', '表', '二', '〇', 'x', '一', '五', 't', '提', '出', '开', '弓', 'z', '没', '有', '回', '头', '箭', '改', '革', '关', '勇', '者', '胜', 'i', '好', '“', '5', '、', '4', '3', '2', '1', '，', '快', '乐', '！', '”', '今', '天', '零', '时', 'd', '奥', '林', '匹', '克', '中', '心', '区', 's', '主', '会', '场', '梦', '想', '辉', '映', '冰', '雪', '北', '京', '同', '欢', '聚', '诚', '邀', '环', '0', '倒', '计', '活', '动', '举', '行', '。', '与', '此', 'c', '延', '庆', '八', '达', '岭', '长', '城', '分', '和', '张', '家', '口', '崇', '礼', '步', '联', '汇', '起', '三', '地', 'j', '万', '众', '对', '申', '办', '冬', '的', 'u', '热', '情', '期', '待', '首', '席', '摄', '影', '记', '蔡', '代', '征', 'A', 'e', '版', '·', '要', '闻', '事', '公', '积', '金', '贷', '款', '上', '限', '调', '至', '6', '呼', '格', '吉', '勒', '图', '父', '母', '获', '赔', '偿', '元', '国', '内', '大', 'a', '涨', '千', '股', '完', '美', '收', '官', '经', '济', '我', '们', '各', '级', '干', '部', '也', '是', '蛮', '拼', '●', '向', '南', '水', '移', '
# ...
