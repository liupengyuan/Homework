# %%
fh = open(r'd:\idioms.txt')

text = fh.read()

fh.close()
text = text.replace('、', '')
idioms=text.split('\n')
chs=[]
for idiom in idioms:
    for ch in idiom:
        chs.append(ch)
import random
fh = open(r'd:\idioms.txt')
text = fh.read()
chs=get_ch_table(text.replace('\n',''))
all1=''
for i in range(10):
    ch=random.choice(chs)
    all1=all1+ch
print(all1)
list=[all1]
fh=open(r'd:\text1.txt','w')
fh.writelines(list)
all2=''
for i in range(20):
    ch=random.choice(chs)
    all2=all2+ch
print(all2)
list=[all2]
fh=open(r'd:\text2.txt','w')
fh.writelines(list)
all3=''
for i in range(30):
    ch=random.choice(chs)
    all3=all3+ch
print(all3)
list=[all3]
fh=open(r'd:\text3.txt','w')
fh.writelines(list)
all4=''
for i in range(40):
    ch=random.choice(chs)
    all4=all4+ch
print(all4)
list=[all4]
fh=open(r'd:\text4.txt','w')
fh.writelines(list)
all5=''
for i in range(50):
    ch=random.choice(chs)
    all5=all5+ch
print(all5)
list=[all5]
fh=open(r'd:\text5.txt','w')
fh.writelines(list)
all6=''
for i in range(60):
    ch=random.choice(chs)
    all6=all6+ch
print(all6)
list=[all6]
fh=open(r'd:\text6.txt','w')
fh.writelines(list)
all7=''
for i in range(70):
    ch=random.choice(chs)
    all7=all7+ch
print(all7)
list=[all7]
fh=open(r'd:\text7.txt','w')
fh.writelines(list)
all8=''
for i in range(80):
    ch=random.choice(chs)
    all8=all8+ch
print(all8)
list=[all8]
fh=open(r'd:\text8.txt','w')
fh.writelines(list)
all9=''
for i in range(90):
    ch=random.choice(chs)
    all9=all9+ch
print(all9)
list=[all9]
fh=open(r'd:\text9.txt','w')
fh.writelines(list)
all10=''
for i in range(100):
    ch=random.choice(chs)
    all10=all10+ch
print(all10)
list=[all10]
fh=open(r'd:\text10.txt','w')
fh.writelines(list)
# Out:
# 完算差往贯露通汗至完
# 度翁禹围七墨郑皆流禽粟从讽奔炼钟砖兴漫巢
# 立真禹屋全接三顾光桀笑木抗狂手泪藕空饴堂善久柴算喝盲离凰辱塞
# 夜庭不奈亡返荼窈长恒缭逐从己赵完敌话角膏引俱夜寒尘柳昙乎睛遂庸苒梅独建怙沙圆岳聋
# 身弥友怀矢己贼滔烈完沉想枝懈婚、图集龙欲偷妻休事友寡措紫次谢的振童名尽骄循薪主烂插捭干凉计囊过在有奇
# 湖巴人木踌南锤回图指请树冕辙僵处擒滔石喝物充规缭魏腋洋喻烈丘城幽浪江当贵击豁蛙丧瓜缺斗鲤羁振殄沉将逢射株沧境仪晕嗤智羊奔
# 入李炙时悚眦清名来见填滴以逐熙磨茂猫豪从呈纸画焚旗拔之角取暴乌柔亡吉胆椟迫缕话巷城辟快悲见曲丝改钧深安报华抽解愎巫深渴欲业公即肥同字今风帼极
# 睚壁贤文貉襟尺捭膺愤徙钓簇绎勇照过割晨意耳主簇邪犀禽鲋瞻颠桃星地清魅餐劫萤约狭边怀四荏气针按斑杨尤驹攘女窍船肓狱喘虹诺兄市吐座戛逍实黔期今箭瓜矫循预所声是犀栋针
# 扫王辟鹰到室续奇娇玉振皆蹴愤醉绎夭骥著念愤遥骑钓赵索冲眈残幽镳猜较魅周汗能井犯今法座楼因匕皆情钧靡辱缕翅讳愎夺由汹轻蓝即答熙干戚默难朋字服皆踏随抛庖影公铢世杯数阿说图鼓肘恶源绘巢血
# 恭亡武盘酸别鼻暖忌犯韵阔璧豁阵预君暖鸿脾世秣梁朋两诣营月童闺臼精帝劝雨殚吁末绎货鹤制湖抛貉尽举魏银湖鼓恢绎幄帼炙擒萤提张望数玉壳栗刚惊代市取漫腕觥继胡汗数盗醉瘁愿义离换贼举雀辙八晨绑腾玩颐悚吐渔戛抽餐
