# %%
#1
def f(n,m):
    for i in range(m):
        print((m-i)*' '+n*(i+1)+' '+n*5+' '+(i+1)*n+''*(i+1))
       
f(n,m)
n='*'
m=5
# Out:
#      * ***** *
#     ** ***** **
#    *** ***** ***
#   **** ***** ****
#  ***** ***** *****

# %%
#2
m=int(input())
n=int(input())

def A(m,n):
    
    if m==0:
        a=n+1
    
        
    if m>0 and n>0:
        a=m+n+1
    return a
A(m,n)
# Out:
# 3
# 4
# 8

# %%
#3
#(a)
n=15
a=3
b=25

import random
for i in range(n):
    x=random.randint(a,b+1)
    z=random.randint(a,b+1)
    y=random.choice(['+','-','*','/'])
    if x>z :
        print(x,y,z)
    if x<z:
        print(z,y,x)
# Out:
# 25 - 22
# 12 * 8
# 14 - 6
# 11 * 4
# 6 + 3
# 16 + 3
# 12 * 7
# 26 - 22
# 24 / 7
# 9 - 6
# 15 * 10
# 24 - 8
# 15 / 5
# 16 / 9

# %%
#(b)
questions=[25 - 22,12 * 8,14 - 6,11 * 4,6 + 3,16 + 3,12 * 7,26 - 22,24 / 7,9 - 6,15 * 10,24 - 8,15 / 5,16/9]

# %%
answer=input()
answers=answer.split()
answers_n=list(answer)
# Out:
# 3,96,8,44,9,19,84,4,3,3,150,16,3,2

# %%
score=0
for i in range(len(answers_n)):
    for j in range(len(questions)):
        if list[i]==questions[j] and y=='+' or '-'  :
            score+=5
        if list[i]==questions[j] and y=='*' or '/':
            score+=10
print(score)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-a2238a1bfbe4> in <module>()
#       2 for i in range(len(answers_n)):
#       3     for j in range(len(questions)):
# ----> 4         if list[i]==questions[j] and y=='+' or '-'  :
#       5             score+=5
#       6         if list[i]==questions[j] and y=='*' or '/':
#
# TypeError: 'type' object is not subscriptable

# %%
#(c)
n=int(input())
i=0
score_c=0
while i<n:
    m=input()
    i+=1
# Out:
# 10
# 5*14=
# 2+9=
# 29+8=
# 6-2=
# 2*5=
# 4*9=
# 2+4=
# 1+7=
# 8/2=
# 6/3=

# %%
#4
#(a)
A=set()
def get_word_table(filename):
    word_table=[]
    with open(filename,encoding='utf-8') as f:
        text=f.read()

    words = [word.split('/')[0] for word in text.split()]
    for word in words:
        if word not in word_table:
            word_table.append(word)
    return word_table

#测试用

filename =r'C:\Users\admin\Desktop\idiom.txt'
table = get_word_table(filename)
print(table[:100])

# %%
filename = r'C:\Users\admin\Desktop\idioms_correct.txt'
A= set()
with open(filename) as f:
    for line in f:
        A|= {word.split('/')[0] for word in line.split()}

print(A)
# Out:
# {'三教九流', '一飞冲天', '嗤之以鼻', '干将莫邪', '邯郸学步', '自相矛盾', '得陇望蜀', '摸金校尉', '背水一战', '称心如意', '无动于衷', '不法之徒', '风声鹤唳', '乘风破浪', '面面相觑', '不言而喻', '紫气东来', '骇人听闻', '不可名状', '时来运转', '龙虎风云', '惊弓之鸟', '道貌岸然', '有恃无恐', '随心所欲', '颠倒乾坤', '不绝如缕', '杞人忧天', '安步当车', '妙手空空', '天下无敌', '魑魅魍魉', '美人计', '金童玉女', '四面楚歌', '虚与委蛇', '开门见山', '望其项背', '飞蛾扑火', '弄假成真', '空穴来风', '一叶障目', '朝秦暮楚', '难兄难弟', '山雨欲来风满楼', '斗转星移', '纷至沓来', '优柔寡断', '按图索骥', '钟鸣鼎食', '赤子之心', '随波逐流', '倾国倾城', '乐不思蜀', '无地自容', '肆无忌惮', '万里长城', '不一而足', '情不自禁', '踽踽独行', '人山人海', '江郎才尽', '望尘莫及', '天长地久', '一路顺风', '金玉满堂', '血战到底', '叱咤风云', '海市蜃楼', '水木清华', '暴殄天物', '矫枉过正', '礼仪之邦', '文不加点', '耳濡目染', '时过境迁', '穷兵黩武', '熙熙攘攘', '岂有此理', '肝胆相照', '多多益善', '鸠占鹊巢', '奇货可居', '劫后余生', '丧心病狂', '草船借箭', '兢兢业业', '日日夜夜', '鹤唳华亭', '汗牛充栋', '三从四德', '大浪淘沙', '断袖之癖', '干柴烈火', '张灯结彩', '三人成虎', '居安思危', '千锤百炼', '脱颖而出', '盘古开天地', '五子登科', '数典忘祖', '天罗地网', '卧虎藏龙', '花花公子', '杯弓蛇影', '画地为牢', '人面桃花', '来历不明', '好好先生', '中流砥柱', '惊涛骇浪', '鹤立鸡群', '囊萤映雪', '难得糊涂', '谈笑风生', '可见一斑', '浮生若梦', '沽名钓誉', '莫衷一是', '全力以赴', '差强人意', '壮士断腕', '无忧无虑', '平
# ...

# %%
for i, word in enumerate(A):
    print(word)
# Out:
# 三教九流
# 一飞冲天
# 嗤之以鼻
# 干将莫邪
# 邯郸学步
# 自相矛盾
# 得陇望蜀
# 摸金校尉
# 背水一战
# 称心如意
# 无动于衷
# 不法之徒
# 风声鹤唳
# 乘风破浪
# 面面相觑
# 不言而喻
# 紫气东来
# 骇人听闻
# 不可名状
# 时来运转
# 龙虎风云
# 惊弓之鸟
# 道貌岸然
# 有恃无恐
# 随心所欲
# 颠倒乾坤
# 不绝如缕
# 杞人忧天
# 安步当车
# 妙手空空
# 天下无敌
# 魑魅魍魉
# 美人计
# 金童玉女
# 四面楚歌
# 虚与委蛇
# 开门见山
# 望其项背
# 飞蛾扑火
# 弄假成真
# 空穴来风
# 一叶障目
# 朝秦暮楚
# 难兄难弟
# 山雨欲来风满楼
# 斗转星移
# 纷至沓来
# 优柔寡断
# 按图索骥
# 钟鸣鼎食
# 赤子之心
# 随波逐流
# 倾国倾城
# 乐不思蜀
# 无地自容
# 肆无忌惮
# 万里长城
# 不一而足
# 情不自禁
# 踽踽独行
# 人山人海
# 江郎才尽
# 望尘莫及
# 天长地久
# 一路顺风
# 金玉满堂
# 血战到底
# 叱咤风云
# 海市蜃楼
# 水木清华
# 暴殄天物
# 矫枉过正
# 礼仪之邦
# 文不加点
# 耳濡目染
# 时过境迁
# 穷兵黩武
# 熙熙攘攘
# 岂有此理
# 肝胆相照
# 多多益善
# 鸠占鹊巢
# 奇货可居
# 劫后余生
# 丧心病狂
# 草船借箭
# 兢兢业业
# 日日夜夜
# 鹤唳华亭
# 汗牛充栋
# 三从四德
# 大浪淘沙
# 断袖之癖
# 干柴烈火
# 张灯结彩
# 三人成虎
# 居安思危
# 千锤百炼
# 脱颖而出
# 盘古开天地
# 五子登科
# 数典忘祖
# 天罗地网
# 卧虎藏龙
# 花花公子
# 杯弓蛇影
# 画地为牢
# 人面桃花
# 来历不明
# 好好先生
# 中流砥柱
# 惊涛骇浪
# 鹤立鸡群
# 囊萤映雪
# 难得糊涂
# 谈笑风生
# 可见一斑
# 浮生若梦
# 沽名钓誉
# 莫衷一是
# 全力以赴
# 差强人意
# 壮士断腕
# 无忧无虑
# 平步青云
# 众矢之的
# 玩世不恭
# 毛骨悚然
# 纵横捭阖
# 不落窠臼
# 昙花一现
# 形影不离
# 不可一世
# 欢天喜地
# 不惑之年
# 人生如梦
# 甚嚣尘上
# 过犹不及
# 粉墨登场
# 岁寒三友
# 原来如此
# 掌上明珠
# ...

# %%
#(b)
def count_words_freq_dict(filename):
    words_freq_dict = {}
    
    with open(filename) as f:
        for line in f:
            words = [word.split('/')[0] for word in line.split()]
            for word in words:
                if word in words_freq_dict: 
                    words_freq_dict[word] += 1
                else:                       
                    words_freq_dict[word] = 1
                    
    return words_freq_dict



filename =  r'C:\Users\admin\Desktop\idioms_correct.txt'
table = count_words_freq_dict(filename)

for i, item in enumerate(table):
    print(item, table[item])
# Out:
# 行尸走肉 1
# 金蝉脱壳 1
# 百里挑一 1
# 金玉满堂 1
# 背水一战 1
# 霸王别姬 1
# 天上人间 1
# 不吐不快 1
# 海阔天空 1
# 情非得已 1
# 满腹经纶 1
# 兵临城下 1
# 春暖花开 1
# 插翅难逃 1
# 黄道吉日 1
# 天下无双 1
# 偷天换日 1
# 两小无猜 1
# 卧虎藏龙 1
# 珠光宝气 1
# 簪缨世族 1
# 花花公子 1
# 绘声绘影 1
# 国色天香 1
# 相亲相爱 1
# 八仙过海 1
# 金玉良缘 1
# 掌上明珠 1
# 皆大欢喜 1
# 逍遥法外 1
# 生财有道 1
# 极乐世界 1
# 情不自禁 1
# 愚公移山 1
# 魑魅魍魉 1
# 龙生九子 1
# 精卫填海 1
# 海市蜃楼 1
# 高山流水 1
# 擎天柱 1
# 卧薪尝胆 1
# 壮志凌云 1
# 金枝玉叶 1
# 四海一家 1
# 穿针引线 1
# 无忧无虑 1
# 无地自容 1
# 三位一体 1
# 落叶归根 1
# 相见恨晚 1
# 惊天动地 1
# 滔滔不绝 1
# 相濡以沫 1
# 长生不死 1
# 原来如此 1
# 女娲补天 1
# 三皇五帝 1
# 万箭穿心 1
# 水木清华 1
# 窈窕淑女 1
# 破釜沉舟 1
# 天涯海角 1
# 牛郎织女 1
# 倾国倾城 1
# 飘飘欲仙 1
# 福星高照 1
# 妄自菲薄 1
# 永无止境 1
# 学富五车 1
# 饮食男女 1
# 英雄豪杰 1
# 国士无双 1
# 塞翁失马 1
# 万家灯火 1
# 石破天惊 1
# 精忠报国 1
# 养生之道 1
# 覆雨翻云 1
# 六道轮回 1
# 鹰击长空 1
# 日日夜夜 1
# 厚德载物 1
# 亡羊补牢 1
# 万里长城 1
# 黄金时代 1
# 出生入死 1
# 一路顺风 1
# 随遇而安 1
# 千军万马 1
# 郑人买履 1
# 棋逢对手 1
# 叶公好龙 1
# 后会无期 1
# 守株待兔 1
# 凤凰于飞 1
# 一生一世 1
# 花好月圆 1
# 世外桃源 1
# 韬光养晦 1
# 画蛇添足 1
# 青梅竹马 1
# 风花雪月 1
# 滥竽充数 1
# 没完没了 1
# 总而言之 1
# 欣欣向荣 1
# 时光荏苒 1
# 差强人意 1
# 好好先生 1
# 空城计 1
# 无懈可击 1
# ...
