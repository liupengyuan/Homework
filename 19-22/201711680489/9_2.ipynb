# %%
print('2、随机生成1万个整数，范围在0-10万之间，求其中每个整数出现的次数。并按照整数大小排序输出整数及出现次数。')
# Out:
# 2、随机生成1万个整数，范围在0-10万之间，求其中每个整数出现的次数。并按照整数大小排序输出整数及出现次数。

# %%
import random
from collections import Counter
list=[]
for i in range(10000):
    m=random.randint(0,100001)
    list.append(m)
    
def count_words_freq_dict(item):
    words_freq_dict = Counter()
    
    
    words_freq_dict.update(list)
    return words_freq_dict

    
count_words_freq_dict(list)
# Out:
# Counter({73935: 1,
#          34223: 1,
#          8876: 2,
#          1256: 1,
#          16793: 1,
#          50025: 2,
#          19693: 1,
#          2971: 1,
#          95421: 1,
#          9131: 1,
#          21921: 1,
#          88623: 1,
#          32761: 2,
#          71945: 1,
#          44836: 1,
#          11659: 1,
#          3272: 1,
#          86106: 1,
#          27870: 1,
#          28770: 1,
#          7651: 1,
#          5574: 1,
#          29352: 2,
#          1504: 1,
#          71235: 1,
#          13063: 1,
#          97966: 1,
#          82570: 1,
#          20814: 1,
#          40353: 1,
#          64747: 1,
#          99914: 1,
#          4532: 1,
#          39857: 1,
#          17056: 2,
#          54711: 1,
#          94629: 1,
#          61229: 1,
#          73057: 1,
#          96089: 1,
#          22609: 1,
#          85002: 1,
#          30330: 1,
#          37530: 2,
#          89986: 1,
#          35901: 1,
#          55276: 1,
#          42922: 1,
# ...

# %%
print('3、对本任务中的语料.txt文件，抽取其5001-10000行存为test1.txt文件，写函数，可得到其与本任务中test.txt文件的共用字以及独用字（相关概念自行百度）。')
# Out:
# 3、对本任务中的语料.txt文件，抽取其5001-10000行存为test1.txt文件，写函数，可得到其与本任务中test.txt文件的共用字以及独用字（相关概念自行百度）。

# %%
with open(r'd:\temp\test1.txt', 'w') as fw, open(r'd:\temp\语料.txt') as fr:
    line_number = 0
    for line in fr:
        if line_number<=5000:
            line_number+=1
        elif 5000 <  line_number < 10001:
            fw.write(line)
            line_number += 1
        else:
            break

# %%
print('4、挑战性任务：统计本任务中的语料.txt文件，得到每一个词对应不同词性的频次，可表示为：{词:[['n',1000], ['v', 98]...],...}，即在dict对象中，key为词，value为列表，输出词频最高的50个条目。')
# Out:
#   File "<ipython-input-6-32c2ab06be53>", line 1
#     print('4、挑战性任务：统计本任务中的语料.txt文件，得到每一个词对应不同词性的频次，可表示为：{词:[['n',1000], ['v', 98]...],...}，即在dict对象中，key为词，value为列表，输出词频最高的50个条目。')
#                                                               ^
# SyntaxError: invalid syntax

# %%
from collections import Counter

def count_words_freq_dict(filename):
    words_freq_dict = Counter()
    
    with open(filename) as f:
        for line in f:
            words_freq_dict.update([word.split('/')[0] for word in line.split()])
    return words_freq_dict
file=r'd:\temp\语料.txt'
table=count_words_freq_dict(file)
print(table.most_common(50))
# Out:
# [('，', 1120), ('的', 893), ('。', 514), ('、', 300), ('和', 235), ('在', 232), ('了', 164), ('是', 154), ('一', 122), ('中国', 101), ('与', 83), ('“', 81), ('有', 79), ('”', 77), ('为', 75), ('说', 73), ('我', 70), ('发展', 65), ('南非', 65), ('我们', 60), ('经济', 59), ('两', 59), ('人民', 58), ('中', 58), ('新', 57), ('上', 56), ('他', 55), ('（', 54), ('）', 54), ('要', 52), ('关系', 51), ('不', 50), ('：', 49), ('建设', 47), ('工作', 47), ('将', 47), ('到', 47), ('国', 47), ('记者', 45), ('等', 44), ('国家', 42), ('合作', 42), ('向', 41), ('年', 41), ('这', 40), ('着', 40), ('问题', 37), ('以', 36), ('也', 36), ('对', 35)]
