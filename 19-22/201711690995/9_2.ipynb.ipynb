# %%
#4、挑战性任务：统计本任务中的语料.txt文件，得到每一个词对应不同词性的频次，
#可表示为：{词:[('n',1000), ('v', 98)...],...}，即在dict对象中，key为词，value为列表，输出词频最高的50个条目。
def count_words_freq(filename):
    '''
    给定文本文件，建立词表并同时统计词频
    '''
    word_freq_pairs = []
    
    with open(filename) as f:
        text = f.read()
        
    words = [word.split('/')[0] for word in text.split()]
    for word in words:
        for item in word_freq_pairs:
            if word == item[0]:
                item[1] += 1
                break
        else:
            word_freq_pairs.append([word, 1])
            
    return word_freq_pairs

#测试用

filename = r'C:\temp\test.txt'
table = count_words_freq(filename)
print(table[:])
# Out:
# [['习近平', 10], ['新年贺词', 9], ['为', 489], ['人民', 40], ['点', 123], ['赞', 22], ['发表', 21], ['二', 27], ['〇', 2], ['一', 209], ['五年', 18], ['提出', 47], ['开弓', 2], ['没有', 246], ['回头', 3], ['箭', 2], ['改革', 69], ['关头', 3], ['勇者胜', 3], ['新年好', 1], ['“', 1817], ['5', 209], ['、', 2332], ['4', 174], ['3', 207], ['2', 193], ['1', 324], ['，', 12789], ['新年快乐', 5], ['！', 238], ['”', 1812], ['今天', 88], ['零时', 6], ['奥林匹克', 9], ['中心区', 6], ['主会场', 5], ['梦想', 17], ['辉映', 1], ['冰雪', 22], ['北京', 368], ['同心', 1], ['欢聚', 3], ['诚邀', 3], ['五环', 3], ['2015', 168], ['年', 897], ['新年', 88], ['倒计时', 11], ['活动', 151], ['举行', 34], ['。', 5364], ['与此同时', 9], ['延庆', 8], ['八达岭长城', 7], ['分会场', 5], ['和', 946], ['张家口', 10], ['崇礼', 5], ['同步', 7], ['联动', 2], ['汇聚', 4], ['起', 91], ['三地', 1], ['万众', 1], ['对', 447], ['申办', 39], ['2022', 16], ['冬奥会', 20], ['的', 7451], ['热情', 7], ['期待', 25], ['首席', 15], ['摄影记者', 10], ['蔡', 6], ['代征', 5], ['', 226], ['摄', 41], ['A02', 2], ['版', 46], ['·', 217], ['要闻', 4], ['时事', 4], ['A03', 2], ['新闻',
# ...

# %%
#3、对本任务中的语料.txt文件，抽取其5001-10000行存为test1.txt文件，写函数，
#可得到其与本任务中test.txt文件的共用字以及独用字（相关概念自行百度）。


with open(r'C:\temp\test.txt', 'w') as fw, open(r'C:\temp\语料.txt') as fr:
    line_number = 0
    for line in fr:
        if line_number < 5000:
            fw.write(line)
            line_number += 1
        else:
            break
 

def get_word_table(filename):
    '''
    给定文本文件，统计其词表
    '''
    word_table = []
    with open(filename) as f:
        text = f.read()
    words = [word.split('/')[0] for word in text.split()]
    for word in words:
        if word not in word_table:
            word_table.append(word)
    return word_table

#测试用

filename = r'C:\temp\test.txt'
table_1 = get_word_table(filename)
print(table_1[:])
filename = r'C:\temp\语料.txt'
table_2 = get_word_table(filename)
print(table_2[:])



def fx():
    C=[]
    D=[]
    for i in range(len(table_1)):
        if table_1[i] in table_2:
            C.append(table_1[i])
        else:
            D.append(table_2[i])
        return C,D
fx()
# Out:
# ['习近平', '新年贺词', '为', '人民', '点', '赞', '发表', '二', '〇', '一', '五年', '提出', '开弓', '没有', '回头', '箭', '改革', '关头', '勇者胜', '新年好', '“', '5', '、', '4', '3', '2', '1', '，', '新年快乐', '！', '”', '今天', '零时', '奥林匹克', '中心区', '主会场', '梦想', '辉映', '冰雪', '北京', '同心', '欢聚', '诚邀', '五环', '2015', '年', '新年', '倒计时', '活动', '举行', '。', '与此同时', '延庆', '八达岭长城', '分会场', '和', '张家口', '崇礼', '同步', '联动', '汇聚', '起', '三地', '万众', '对', '申办', '2022', '冬奥会', '的', '热情', '期待', '首席', '摄影记者', '蔡', '代征', '', '摄', 'A02', '版', '·', '要闻', '时事', 'A03', '新闻', '公积金', '贷款', '上限', '今', '起调', '至', '120', '万', 'A06', '呼格', '吉勒', '图', '父母', '获', '赔偿', '206', '万元', 'A11', '国内新闻', '一年', '大', '涨', '千点', 'A股', '完美', '收官', 'A15', '经济', '我们', '各级', '干部', '也', '是', '蛮', '拼', '国家', '主席', '●', '向', '南水北调', '40', '移民', '致敬', '我', '要', '伟大', '时间', '过', '得', '真快', '2014', '就要', '过去', '了', '正在', '走来', '在', '这', '辞旧迎新', '时刻', '全国', '各族人民', '香港特别行政区', '同胞', '澳门特别行政区', '台湾同胞', '海外侨胞', '世界', '各国', '各', '地区', '朋友', '们', '致以', '祝福', '令人难忘', '锐意', '推进改革', '啃下', '不少', '硬
# ...

# %%
#2、随机生成1万个整数，范围在0-10万之间，求其中每个整数出现的次数。并按照整数大小排序输出整数及出现次数。


import random
A = [random.randint(0,100001) for i in range(10000)] 

import collections
A.sort()
#print(A,len(A))
B = collections.Counter(A)
for C in B:
    print (C,B[C])
# Out:
# 2 1
# 3 1
# 9 1
# 12 1
# 15 1
# 33 1
# 35 1
# 44 2
# 45 1
# 67 1
# 73 1
# 74 1
# 87 1
# 108 1
# 112 1
# 119 1
# 129 1
# 130 1
# 132 1
# 141 1
# 144 1
# 149 1
# 172 1
# 189 1
# 196 1
# 200 1
# 218 1
# 228 1
# 253 1
# 267 1
# 280 1
# 293 1
# 296 2
# 300 1
# 316 1
# 331 1
# 334 1
# 341 1
# 353 1
# 372 1
# 397 1
# 398 1
# 410 1
# 427 1
# 428 1
# 431 2
# 435 2
# 437 1
# 440 1
# 449 1
# 457 1
# 468 1
# 483 1
# 484 1
# 486 1
# 488 1
# 507 1
# 511 1
# 516 1
# 540 1
# 541 1
# 555 1
# 568 1
# 588 1
# 590 1
# 597 1
# 601 1
# 655 1
# 670 1
# 671 1
# 677 1
# 693 1
# 718 1
# 724 1
# 731 1
# 752 1
# 754 1
# 764 1
# 769 1
# 775 1
# 777 1
# 784 1
# 824 1
# 845 1
# 850 1
# 873 1
# 875 1
# 887 1
# 888 1
# 893 1
# 902 1
# 934 1
# 940 1
# 953 1
# 974 1
# 978 1
# 984 1
# 996 1
# 1006 1
# 1020 1
# 1022 1
# 1030 1
# 1035 1
# 1037 2
# 1067 1
# 1070 1
# 1072 1
# 1078 1
# 1088 1
# 1098 1
# 1111 1
# 1145 1
# 1151 1
# 1188 1
# 1191 1
# 1202 1
# 1203 1
# 1216 1
# 1222 1
# 1228 1
# 1236 1
# 1237 1
# 1247 1
# ...
