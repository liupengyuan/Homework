# %%
#1 仿照求$ \sum_{i=1}^mi + \sum_{i=1}^ni  + \sum_{i=1}^ki$的完整代码，写程序，可求m!+n!+k!
def my_mul(n):
    i=0
    mul=1
    while i<n:
        i=i+1
        mul=mul*i
    return(mul)
m=int(input('请输入第一个整数，以回车键结束。'))
n=int(input('请输入第二个整数，以回车键结束。'))
k=int(input('请输入第三个整数，以回车键结束。'))

print('m!+n!+k!=：',my_mul(m)+my_mul(n)+my_mul(k))
# Out:
# 请输入第一个整数，以回车键结束。7
# 请输入第二个整数，以回车键结束。9
# 请输入第三个整数，以回车键结束。5678
# m!+n!+k!=： ...

# %%
#1 仿照求$ \sum_{i=1}^mi + \sum_{i=1}^ni  + \sum_{i=1}^ki$的完整代码，写程序，可求m!+n!+k!
def my_mul(n):
    i=0
    mul=1
    while i<n:
        i=i+1
        mul=mul*i
    return(mul)
m=int(input('请输入第一个整数，以回车键结束。'))
n=int(input('请输入第二个整数，以回车键结束。'))
k=int(input('请输入第三个整数，以回车键结束。'))

print('m!+n!+k!=：',my_mul(m)+my_mul(n)+my_mul(k))
# Out:
# 请输入第一个整数，以回车键结束。34
# 请输入第二个整数，以回车键结束。5
# 请输入第三个整数，以回车键结束。2
# m!+n!+k!=： 295232799039604140847618609643520000122

# %%
# 写函数可返回1 - 1/3 + 1/5 - 1/7...的前n项的和。在主程序中，分别令n=1000及100000，打印4倍该函数的和。
def my_sum(n):
    
    i=1
    total=1
    while j<n:
        i==i+1
        total==total+[(-1)**(i-1)]/(2i-1)
        
    return(total)

# 主程序
n=100
print('4倍该函数的和为:',4*my_sum(n))
# Out:
#   File "<ipython-input-3-94c5869d29f0>", line 8
#     total==total+[(-1)**(i-1)]/(2i-1)
#                                  ^
# SyntaxError: invalid syntax

# %%
#3(1): 将task3中的练习1及练习4改写为函数，并进行调用。
# 练习1：写程序，可由键盘读入用户姓名例如M，让用户输入出生的月份和日期，判断用户星座，假设用户是金牛座，则输出，M,你是非常有个性的金牛座！。
def fx():
    if (m==1 and 20<=n<=31) or(m==2 and 1<=n<=18):
        Q=(',你是追求独一无二的水瓶座！')
    elif (m==2 and 19<=n<=30) or(m==3 and 1<=n<=20):
        Q=(',你是多重矛盾的双鱼座！')
    elif (m==3 and 21<=n<=31) or(m==4 and 1<=n<=19):
        Q=(',你是爱冒险的白羊座！')
    elif (m==4 and 20<=n<=30) or(m==5 and 1<=n<=20):
        Q=(',你是保守型的金牛座！')
    elif (m==5 and 21<=n<=31) or(m==6 and 1<=n<=20):
        Q=(',你是喜欢变化的双子座！')
    elif (m==6 and 21<=n<=30) or(m==7 and 1<=n<=22):
        Q=(',你是充满爱心的巨蟹座！')
    elif (m==7 and 23<=n<=31) or(m==8 and 1<=n<=22):
        Q=(',你是阳光自信的狮子座！')
    elif (m==8 and 23<=n<=31) or(m==9 and 1<=n<=22):
        Q=(',你是追求完美的处女座！')
    elif (m==9 and 23<=n<=30) or(m==10 and 1<=n<=21):
        Q=(',你是亲切善良的天秤座！')                                       
    elif (m==10 and 22<=n<=31) or(m==11 and 1<=n<=21):
        Q=('你是神秘的天蝎座！')
    elif (m==11 and 22<=n<=30) or(m==12 and 1<=n<=21):
        Q=(',你是诚实乐观的射手座！')
    elif (m==12 and 22<=n<=31) or(m==1 and 1<=n<=19):
        Q=(',你是最有耐心的摩羯座！')
    return Q

# 主程序
M=input('请输入你的名字，以回车键结束。')
m=int(input('请输入你的出生月份，以回车键结束。'))
n=int(input('请输入你的出生日期，以回车键结束。'))
print(M ,fx())
# Out:
# 请输入你的名字，以回车键结束。轰轰
# 请输入你的出生月份，以回车键结束。12
# 请输入你的出生日期，以回车键结束。17
# 轰轰 ,你是诚实乐观的射手座！

# %%
#3(2): 将task3中的练习1及练习4改写为函数，并进行调用。
# 练习3：写程序，能够根据北京雾霾PM2.5数值给出对应的防护建议。如当PM2.5数值大于500，则应该打开空气净化器，戴防雾霾口罩等。
def fx():
    if 0<=M<=50:
        Q=('难得的好天气，赶快出去玩吧(*￣▽￣*)ブ')
    elif 50<=M<=100:
        Q=('空气质量不错哦，多出去走走。')
    elif 100<=M<=150:
        Q=('有些轻度污染，外出还是没问题的。')
    elif 150<=M<=200:
        Q=('中度污染，出门记得戴口罩。')
    elif 200<=M<=300:
        Q=('重度污染预警，请尽量减少外出次数。')
    elif M>=300:
        Q=('空气严重污染，为了您的身体健康，建议打开空气净化器，尽量不要外出！')
    return Q
M=int(input('请输入北京雾霾PM2.5数值，以回车键结束。'))
print( fx())
# Out:
# 请输入北京雾霾PM2.5数值，以回车键结束。187
# 中度污染，出门记得戴口罩。

# %%
# 挑战性练习：写程序，可以求从整数m到整数n累加的和，间隔为k，求和部分需用函数实现，主程序中由用户输入m，n，k调用函数验证正确性。
def my_sum():
    i = m
    total = i
    while m<=i<=n:
        i = i+k
        total = total+i
    return total

# 主程序
m=int(input('请输入第一个整数，以回车键结束。'))
n=int(input('请输入第二个整数，要求它比第一个输入的整数小，以回车键结束。'))
k=int(input('请输入第三个整数，要求其比输入的前两个数值之差要小，以回车键结束。'))
print(my_sum())
# Out:
# 请输入第一个整数，以回车键结束。27
# 请输入第二个整数，要求它比第一个输入的整数小，以回车键结束。190
# 请输入第三个整数，要求其比输入的前两个数值之差要小，以回车键结束。4
# 4578
