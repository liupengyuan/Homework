# %%
#随机生成1万个整数，范围在0-10万之间，求其中每个整数出现的次数。并按照整数大小排序输出整数及出现次数
import random
from collections import Counter

list=[]
for i in range(10001):
    a=random.randint(0,100001)
    list.append(a)
list.sort()

def number_count_dict(list):
    count_dict=Counter()
    count_dict.update([num for num in list])
    return count_dict

number_count_dict(list)
# Out:
# Counter({26: 1,
#          29: 2,
#          48: 1,
#          50: 1,
#          86: 1,
#          91: 1,
#          108: 1,
#          115: 1,
#          120: 1,
#          126: 1,
#          128: 1,
#          131: 1,
#          143: 1,
#          164: 1,
#          186: 1,
#          197: 1,
#          200: 2,
#          206: 1,
#          207: 1,
#          237: 1,
#          253: 1,
#          255: 1,
#          259: 1,
#          271: 1,
#          272: 1,
#          284: 1,
#          320: 1,
#          332: 1,
#          334: 1,
#          341: 1,
#          351: 1,
#          383: 1,
#          390: 1,
#          410: 1,
#          414: 1,
#          418: 1,
#          426: 1,
#          428: 1,
#          438: 1,
#          440: 1,
#          441: 1,
#          443: 1,
#          444: 1,
#          447: 1,
#          474: 1,
#          487: 1,
#          522: 1,
#          530: 1,
#          531: 1,
#          547: 1,
#          548: 1,
#          555: 1,
# ...

# %%
#对本任务中的语料.txt文件，抽取其5001-10000行存为test1.txt文件，写函数，可得到其与本任务中test.txt文件的共用字以及独用字（相关概念自行百度）。
with open(r'd:\temp\test1.txt', 'w') as fw, open(r'd:\temp\语料.txt') as fr:
    line_number = 0
    for line in fr:
        if line_number < 5000:
            line_number += 1
        else:
            fw.write(line)

with open(r'd:\temp\test.txt') as a:
    text = a.read()
words = {word.split('/')[0] for word in text.split()}

with open(r'd:\temp\test1.txt') as f:
    text1 = f.read()
words1= {word.split('/')[0] for word in text1.split()}
print('共用字为:',words.intersection(words1))

public1=words.difference(words1)
public2=words1.difference(words)
public=public1|public2
print('独用字为:',public)
# Out:
# 共用字为: {'', '视点', '决定', '粗暴', '冬虫夏草', '负面', '载客', '团体赛', '违规行为', '苏州', '值得一提的是', '烧伤', '图', '院校', '花椒', '试用', '质朴', '总理', '动荡', '常常', '钻', '时报', '迎战', '多达', '负', '回顾', '城市', '讨薪', '情商', '张扬', '骨骼', '承保', '本届', '失去', '门头沟区', '64', '常态', '多个', '若干', '上浮', '第二', '干', '升级', '最怕', '竞争', '一种', '全球', '总决赛', '起步', '责备', '晨报讯', '和平', '普惠', '爱车', '按规定', '两年', '正道', '对冲', '上攻', '竟', '难度', '新春', '不会', '带', '获得', '117', '收受', '选手', '盈利', '万辆', '５', '周年', '利空', '干旱', '源头', '上台', '正好', '卫视', '事件', '萝卜', '规制', '5.4', '耗时', '援引', '枯', '电子展', '幅度', '红双喜', '新闻', '保利剧院', '打开门', '大桥', '75', '五年', '115', '剑桥', '追逐', '改革方案', '2017', '喝完', '尤其', '剧场', '撰文', '上万名', '走', '这么', '美的', '黄晓宇', '收据', '评为', '本周一', '无处', '学费', '出道', '平台', '协办', '职业联赛', '安康', '力度', '平均年龄', '宣传部', '延续', '联合', '在短期内', '制作', '一家人', '二度', '助理', '经常', '假设', '教材', '导演组', '北路', '毕业', '唱段', '世纪末', '钢琴', '广场', '前方', '用户', '赶赴现场', '第二名', '增高', '骨病', '地平线', '积极参与', '196', '实名', '影响', '回升', '郑', '67', '考试成绩', '改制', '等等', '回', '锅', '奖励', '四名', '文献
# ...

# %%
#挑战性任务：统计本任务中的语料.txt文件，得到每一个词对应不同词性的频次，可表示为：{词:[('n',1000), ('v', 98)...],...}，即在dict对象中，key为词，value为列表，输出词频最高的50个条目。
def count_words_freq_dict(filename):
    words_freq_dict = Counter()
    with open(filename) as f:
        for line in f:
            words_freq_dict.update({word for word in line.split()})
    return words_freq_dict
def main():
    filename = r'd:\temp\语料.txt'
    table = count_words_freq_dict(filename)
    print(table.most_common(50))

if __name__ == '__main__':
    main()
# Out:
# [('，/x', 4856), ('。/x', 4778), ('的/uj', 4355), ('在/p', 2434), ('“/x', 2360), ('”/x', 2354), ('、/x', 2113), ('了/ul', 1974), ('是/v', 1838), ('和/c', 1469), ('年/m', 1225), ('：/x', 1216), ('有/v', 1174), ('也/d', 1163), ('将/d', 924), ('为/p', 868), ('人/n', 843), ('中/f', 836), ('都/d', 786), ('记者/n', 779), ('等/u', 778), ('这/r', 769), ('就/d', 758), ('不/d', 755), ('月/m', 753), ('》/x', 748), ('《/x', 748), ('对/p', 746), ('与/p', 733), ('上/f', 715), ('被/p', 698), ('北京/ns', 679), ('（/x', 667), ('）/x', 667), ('日/m', 648), ('到/v', 645), ('他/r', 599), ('但/c', 598), ('说/v', 595), ('中国/ns', 567), ('从/p', 566), ('后/f', 553), ('一个/m', 546), ('还/d', 537), ('并/c', 522), ('而/c', 520), ('会/v', 516), ('2014/m', 505), ('1/m', 489), ('以/p', 470)]
