# %%
n=input('请输入一个图形：')
m=int(input('请输入一个数：'))
for i in range(m):
    print(' '*(m-i) + n*(i+1) +n*m + n *i)
# Out:
# 请输入一个图形：*
# 请输入一个数：5
#      ******
#     ********
#    **********
#   ************
#  **************

# %%
def A(m,n):
    if m==0:
        return n+1
    elif m>0 and n==0:
        return A(m-1,1)
    elif m>0 and n>0:
        return A(m-1,A(m,n-1))
A(3,4)
# Out:
# 125

# %%
import random
a=int(input('请输入一个数字作为下限：'))
b=int(input('请输入一个数字作为上限：'))
n=int(input('请输入题目道数：'))
#（a）
list1=[]
total=0
for i in range(n):
    list=['+','-','*','/']
    c=random.randint(a,b+1)
    d=random.randint(a,b+1)
    e=random.choice(list)
    if e==list[0]:
        f=c+d
    elif e==list[1]:
        f=c-d
    elif e==list[2]:
        f=c*d
    elif e==list[3]:
        f=c/d
    list1.append(f)
    print(c,e,d,'=')

#(b)
daan=input('请输入你的答案：')
total+=5
print('总分为：',total)

#（c）
# Out:
# 请输入一个数字作为下限：1
# 请输入一个数字作为上限：10
# 请输入题目道数：3
# 10 - 8 =
# 6 * 2 =
# 11 - 5 =
# 请输入你的答案：2,11,3
# 总分为： 5

# %%
with open(r'd:\temp\成语大全(含成语解释)_utf8.txt',encoding='utf-8') as f:
    A=set()
    for line in f:
        A.add(line[1:5])
print(A)
# Out:
# {'', '兼人之勇', '尺短寸长', '大处着眼', '虱多不痒', '胸无大志', '披荆斩棘', '非分之念', '多愁多病', '神清气爽', '教无常师', '倚财仗势', '芙蓉并蒂', '鹤长凫短', '遁入空门', '不修边幅', '白日衣绣', '南棹北辕', '伯仲之间', '贿货公行', '乐天知命', '见性成佛', '飞声腾实', '赃贿狼籍', '坏植散群', '仪态万千', '沉默寡言', '二话不说', '养家糊口', '流星赶月', '国富民丰', '啜菽饮水', '挠喉捩嗓', '两雄不并', '心服首肯', '韩信将兵', '橛守成规', '九江八河', '誓日指天', '丝来线去', '珠沉玉碎', '分路扬镳', '同工异曲', '以噎废飡', '无能为役', '宁死不辱', '犬马之养', '擢筋割骨', '朱盘玉敦', '风驰云走', '脱白挂绿', '漏尽更阑', '长才短驭', '礼先壹饭', '尽美尽善', '雁素鱼笺', '土豪劣绅', '大工告成', '心到神知', '血战到底', '井臼亲操', '双栖双宿', '不着疼热', '争权夺利', '豪干暴取', '舌锋如火', '千仓万箱', '巢毁卵破', '七支八搭', '翻江搅海', '倚门傍户', '一言半辞', '鹤发童颜', '以为后图', '闲言碎语', '挥沐吐餐', '断头将军', '呼之即来', '贪生畏死', '火龙黼黻', '度日如岁', '以半击倍', '千姿万态', '孝子慈孙', '长虑顾后', '南征北战', '悼心疾首', '才短思涩', '神区鬼奥', '一手一足', '自始自终', '下学上达', '不知起倒', '饮冰茹檗', '想望风采', '落花无言', '满脸春风', '一般无二', '以冠补履', '棋高一着', '挑三嫌四', '穷凶极恶', '不屈不挠', '贪官污吏', '神枢鬼藏', '行不逾方', '子子孙孙', '听天由命', '隐天蔽日', '反风灭火', '挂冠求去', '志坚行苦', '死标白缠', '声色货利', '吹网欲满', '哗众取宠', '纨绔子弟', '十病九痛', '季布一诺', '裸裎袒裼', '褚小杯大', '狼前虎后', '沉吟不语', '黄口孺子', '颠颠倒倒', '
# ...

# %%
from collections import Counter

def count_words_freq_dict(list):
    words_freq_dict = Counter()
    words_freq_dict.update(idiom2 for idiom2 in list )
    return words_freq_dict
table=count_words_freq_dict(A)
print((table.most_common(50))
)
# Out:
# [('', 1), ('兼人之勇', 1), ('尺短寸长', 1), ('大处着眼', 1), ('虱多不痒', 1), ('胸无大志', 1), ('披荆斩棘', 1), ('非分之念', 1), ('多愁多病', 1), ('神清气爽', 1), ('教无常师', 1), ('倚财仗势', 1), ('芙蓉并蒂', 1), ('鹤长凫短', 1), ('遁入空门', 1), ('不修边幅', 1), ('白日衣绣', 1), ('南棹北辕', 1), ('伯仲之间', 1), ('贿货公行', 1), ('乐天知命', 1), ('见性成佛', 1), ('飞声腾实', 1), ('赃贿狼籍', 1), ('坏植散群', 1), ('仪态万千', 1), ('沉默寡言', 1), ('二话不说', 1), ('养家糊口', 1), ('流星赶月', 1), ('国富民丰', 1), ('啜菽饮水', 1), ('挠喉捩嗓', 1), ('两雄不并', 1), ('心服首肯', 1), ('韩信将兵', 1), ('橛守成规', 1), ('九江八河', 1), ('誓日指天', 1), ('丝来线去', 1), ('珠沉玉碎', 1), ('分路扬镳', 1), ('同工异曲', 1), ('以噎废飡', 1), ('无能为役', 1), ('宁死不辱', 1), ('犬马之养', 1), ('擢筋割骨', 1), ('朱盘玉敦', 1), ('风驰云走', 1)]

# %%
def count_cixing(filename):
    words_freq_dict = Counter()
    
    with open(filename) as f:
        for line in f:
            words_freq_dict.update([word.split('/')[1] for word in line.split()])
    return words_freq_dict
h=(count_cixing(r'd:\temp\语料库.txt'))
print(h)
# Out:
# Counter({'n': 76628, 'x': 63637, 'v': 59686, 'm': 25920, 'd': 18225, 'uj': 15590, 'p': 13234, 'r': 10942, 'nr': 10531, 'c': 9321, 'a': 8249, 'ns': 8153, 'vn': 7722, 't': 6063, 'f': 5197, 'ul': 3284, 'nz': 2603, 'l': 2561, 'b': 1743, 'i': 1729, 'nt': 1723, 'j': 1707, 'eng': 1616, 'u': 1580, 'q': 1339, 's': 1281, 'nrt': 995, 'ad': 932, 'zg': 754, 'ng': 574, 'uz': 408, '': 384, 'k': 371, 'uv': 344, 'z': 322, 'y': 308, 'an': 302, 'vg': 239, 'ug': 238, 'mq': 219, 'ud': 205, 'nrfg': 133, 'vd': 92, 'h': 90, 'g': 76, 'ag': 75, 'tg': 64, 'df': 55, 'o': 40, 'rz': 36, 'e': 31, 'rg': 8, 'dg': 7, 'vq': 6, 'vi': 6, 'yg': 6, 'rr': 5})

# %%
print(h['nr'])
# Out:
# 10531

# %%
B=list[A]
C=[]
C.append(aaa for aaa in idiom for idiom in B)
print(C)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-d09edc76c717> in <module>()
# ----> 1 B=list[A]
#       2 C=[]
#       3 C.append(aaa for aaa in idiom for idiom in B)
#       4 print(C)
#
# TypeError: list indices must be integers or slices, not set
