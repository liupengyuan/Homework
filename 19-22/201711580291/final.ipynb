# %%
m=str(input('请输入一个符号'))
n=int(input('请输入打印行数'))

def lwl():
    a=0
    for i in range(n+1):
        a+=1
        print(' '*(n-a)+m*a+m*n+m*a)
        if a==n:
            break
lwl()
# Out:
# 请输入一个符号*
# 请输入打印行数5
#     *******
#    *********
#   ***********
#  *************
# ***************

# %%
def lwl(m,n):

    m=int(input('请输入第一个数字'))
    n=int(input('请输入第二个数字'))
    while m==0:
        A=n+1
    elif m>0 and n==0:
        m=m-1
        n=1
    elif m>0 and n>0:
        m=m-1
        while m>0 and n-1==0:
            m=m-1
            n=2
        elif m==0:
            A=n+1
lwl(3,4)
# Out:
#   File "<ipython-input-29-2f641b08d1a6>", line 7
#     elif m>0 and n==0:
#        ^
# SyntaxError: invalid syntax

# %%
n=int(input('请输入题目个数'))
a=int(input('请输入数字下限'))
b=int(input('请输入数字上限'))

from random import randint
import random
s=0
lwl=[]
numbers=[randint(a,b) for i in range(20)]
for i in numbers:
    for j in numbers:
        if i-j>0 or i%j==0:
            if s<n:
                s+=1
                h=random.randint(1,5)
                if h==1:
                    h='+'
                elif h==2:
                    h='-'
                elif h==3:
                    h='*'
                else:
                    h='/'
                lwl.append([i,h,j])
            else:
                break
        print(lwl)
#（2）
for i in lwl:
    g=int(input('请输入你的答案'))
    
#(3)
n=int(input('请输入题目个数'))
a=int(input('请输入一个数字'))
b=int(input('请输入另一个数字'))
h=random.randint(1,5)
    if h==1:
        h='+'
    elif h==2:
        h='-'
    elif h==3:
        h='*'
    else:
        h='/'
# Out:
#   File "<ipython-input-40-2cab1672ae79>", line 37
#     if h==1:
#     ^
# IndentationError: unexpected indent

# %%
#4
#(1)
filename = r'D:\temp\idioms.txt
with open(filename) as f:
    f=f.read() 
    A= set()

    for line in f:
        A |= {idiom.split('/')[0] for idiom in line.split()}
#(2)
def count_idioms_freq(filename):
    idiom_freq_pairs = []
    
    with open(filename) as f:
        text = f.read()
        
    idioms = [idiom.split('/')[0] for idiom in text.split()]
    for idiom in idioms:
        for item in idiom_freq_pairs:
            if idiom == item[0]:
                item[1] += 1
                break
        else:
            idiom_freq_pairs.append([idiom, 1])
            
    return idiom_freq_pairs


count_idioms_freq(filename)

idiom_freq_pairs[1].sort()
for i in range(21):
    print(idiom_freq_pairs)
    
#(3)  
for line in f:
idioms = [idiom.split('/')[0] for idiom in line.split()]
    for idiom in idioms:
        for item in idiom_freq_pairs:
            if idiom == item[0]:
                item[1] += 1
                break
            else:
                idiom_freq_pairs.append([idiom, 1])
        print(idiom_freq_pairs)
#(4)
def count_idioms_freq_dict(filename):
    idiom_freq_dict = {}
    
    with open(filename) as f:
        for line in f:
            idiom = [idiom.split('/')[0] for idiom in line.split()]
            for idiom in idioms:
                if idiom in idiom_freq_dict: 
                    idioms_freq_dict[idiom] += 1
                else:       
                    idiom_freq_dict[idiom] = 1
                    
    return idioms_freq_dict
count_idioms_freq_dict(filename)
#(5)
with open(filename) as f:
    f=f.read()
    a=0
    for word in f:
        a+=1
    print(a)
#(6)
def lwl(n):
    with open(filename) as m:
        for i in set(m.readlines()):
            if n==i.strip():
                return True
            return False
fh = open(r'd:\temp\idioms.txt')
text = fh.read()
text=text.replace('、','')
text=text.split()

import random
idiom1=random.choice(text)
def idiom():
   
    idiom1=random.choice(text)
    print(idiom1)
    a=str(input('请输入你要接的成(词）语:'))
    if idiom1[-1]==a[0]:
        for idiom in text:
            if idiom[0]==a[-1]:
                print(idiom)
                a=str(input('请输入你要接的成(词）语:'))
        if lwl(a)==False :
            break
                
         
    else:
        break
         
idiom()
# Out:
#   File "<ipython-input-38-945ca148302f>", line 3
#     filename = r'D:\temp\idioms.txt
#                                    ^
# SyntaxError: EOL while scanning string literal
