# %%
#2、随机生成1万个整数，范围在0-10万之间，求其中每个整数出现的次数。并按照整数大小排序输出整数及出现次数
from random import randint
m=[randint(0,100000) for i in range(10000)]

def count_nums_freq_dict():
    nums_freq_dict = {}
    for num in m:
        if num in nums_freq_dict: 
            nums_freq_dict[num] += 1
        else:                       
            nums_freq_dict[num] = 1
                    
    print(nums_freq_dict) 
    n=sorted(m)
    nums_freq_redict = {}
    for num in n:
        if num in nums_freq_redict: 
            nums_freq_redict[num] += 1
        else:                       
            nums_freq_redict[num] = 1
    print(nums_freq_redict)
count_nums_freq_dict()
# Out:
# {41452: 1, 83404: 1, 67704: 1, 16256: 1, 8996: 1, 61976: 1, 16213: 1, 20469: 1, 88427: 1, 20710: 1, 26317: 2, 12064: 1, 75421: 1, 81722: 1, 53026: 1, 16302: 1, 85211: 1, 79024: 1, 75703: 1, 49336: 1, 96380: 1, 41678: 1, 69373: 1, 22671: 1, 72381: 1, 44294: 1, 80689: 2, 4188: 1, 44053: 1, 34585: 1, 72703: 1, 94577: 1, 55157: 1, 4913: 1, 12631: 1, 92386: 1, 19344: 1, 6509: 1, 61143: 2, 70277: 2, 25574: 1, 67209: 1, 70794: 2, 3627: 1, 1179: 1, 84650: 2, 24486: 1, 64375: 2, 40502: 1, 53432: 1, 95054: 1, 93082: 1, 93314: 1, 75326: 1, 75299: 1, 47854: 1, 73355: 1, 69508: 1, 94190: 1, 51600: 1, 60804: 1, 68882: 1, 65093: 1, 72721: 1, 32723: 1, 22709: 1, 25994: 1, 54609: 1, 96513: 1, 47034: 1, 52347: 1, 63863: 2, 6028: 1, 36074: 1, 91607: 1, 9496: 1, 1497: 1, 81682: 1, 43486: 1, 39753: 1, 95008: 1, 1182: 1, 44297: 1, 48063: 1, 48746: 2, 33367: 1, 60881: 2, 14477: 1, 19841: 1, 42190: 1, 86323: 1, 86856: 1, 15994: 1, 34252: 1, 97211: 1, 3857: 1, 8781: 1, 94660: 1, 61779: 1, 75613: 1, 80086: 1,
# ...

# %%
#、对本任务中的语料.txt文件，抽取其5001-10000行存为test1.txt文件，写函数，可得到其与本任务中test.txt文件的共用字以及独用字（相关概念自行百度）

with open(r'd:\temp\test1.txt', 'w') as fw, open(r'd:\temp\语料.txt') as fr:
    line_number = 0
    for line in fr:
        if 5000<line_number <10000:
            fw.write(line)
            line_number += 1
        else:
            break
def

# %%
#4、挑战性任务：统计本任务中的语料.txt文件，得到每一个词对应不同词性的频次
#，可表示为：{词:[['n',1000], ['v', 98]...],...}，即在dict对象中，key为词，value为列表，
#输出词频最高的50个条目。

def count_words_freq():
    word_freq_pairs = []
    with open(r'd:\temp\语料.txt') as f:
        text = f.read()
    for word in text:
        number = text.count(word)
        word_freq_pairs.append([word, number])
    print(word_freq_pairs)
count_words_freq()
