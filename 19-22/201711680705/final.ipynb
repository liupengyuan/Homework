# %%
#1
def picture():
    for i in range(0,len(line)) :
        print(' '*2*(len(line)-i),(line[0]+' ')*(i+1),line[0]*len(line),(line[0]+' ')*(i+1),end='')
        print()
line=input('输入符号s')*r
r=int(input('输入行数r'))
picture()
# Out:
# 输入符号s*
# 输入行数r5
#            *  ***** *
#          * *  ***** * *
#        * * *  ***** * * *
#      * * * *  ***** * * * *
#    * * * * *  ***** * * * * *

# %%
#2
def ackermann(m,n):
    if m==n:
        return n+1
    elif m>0 and n==0:
        return ackermann(m-1,1)
    elif m>0 and n>0:
        return ackermann(m-1,ackermann(m,n-1))

ackermann(3,4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-846f1e014746> in <module>()
#       9 m=3
#      10 n=4
# ---> 11 ackermann(3,4)
#      12
#
# <ipython-input-15-846f1e014746> in ackermann(m, n)
#       6         return ackermann(m-1,1)
#       7     elif m>0 and n>0:
# ----> 8         return ackermann(m-1,ackermann(m,n-1))
#       9 m=3
#      10 n=4
#
# <ipython-input-15-846f1e014746> in ackermann(m, n)
#       6         return ackermann(m-1,1)
#       7     elif m>0 and n>0:
# ----> 8         return ackermann(m-1,ackermann(m,n-1))
#       9 m=3
#      10 n=4
#
# <ipython-input-15-846f1e014746> in ackermann(m, n)
#       5     elif m>0 and n==0:
#       6         return ackermann(m-1,1)
# ----> 7     elif m>0 and n>0:
#       8         return ackermann(m-1,ackermann(m,n-1))
#       9 m=3
#
# ...

# %%
#3(a)
import random
def question_jiajian(n,a,b):
    value1=random.randint(a,b)
    value2=random.randint(a,b)
    question_jiajian=[]
    question_jiajian.append([value1,'+',value2])
    if a>b:
        question_jiajian.append([value1,'-',value2]) 
    
def question_chengchu(n,a,b):
    value1=random.randint(a,b)
    value2=random.randint(a,b)
    question_chengchu=[]
    question_chengchu.append([value1,'*',value2])
    if a%b==0:
        question_chengchu.append([value1,'/',value2]) 
            
        
question_jiajian(15,3,25)  
question_chengchu(15,3,25)
print(question_jiajian(15,3,25)[:7] ,question_chengchu(15,3,25)[:8] )
# Out:
#   File "<ipython-input-38-d331aa499f26>", line 15
#     question_chengchu.append([value1,'*',value2])
#                     ^
# SyntaxError: invalid syntax

# %%
#3(b)
def grades():
    grade=0
    if answer_jiajian True:
        grade+=5
    if answer_chengchu True:
        grade+=10
def answers():
    answers=input()

# %%
#3(c)
n=int(input('输入题目个数n'))

# %%
#4(a)
def chengyu(filename):
    
    with open(filename,encoding='utf-8') as f:
        A={}
        for line in f:
            words = [word.split('  ')[0] for word in line.split()]
            for word in words:
                A['word']
    return A      
filename = r'c:\temp\成语大全(含成语解释)_utf8.txt'
print(chengyu(filename))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-58c8becaf5dc> in <module>()
#      10     return A
#      11 filename = r'c:\temp\成语大全(含成语解释)_utf8.txt'
# ---> 12 print(chengyu(filename))
#
# <ipython-input-11-58c8becaf5dc> in chengyu(filename)
#       7             words = [word.split('  ')[0] for word in line.split()]
#       8             for word in words:
# ----> 9                 A['word']
#      10     return A
#      11 filename = r'c:\temp\成语大全(含成语解释)_utf8.txt'
#
# KeyError: 'word'

# %%
#4(b)
def count_words_freq_dict(filename):
    words_freq_dict = {}
    
    with open(r'C:\temp\test_re_gbk.txt') as f1, open(r'c:\temp\idioms.txt') as f2:
        for line in f2:
            words = [word.split('/')[0] for word in line.split()]
            for word in words:
                if word in f1: #如果词典中有键为word，则该word的value+1
                    words_freq_dict[word] += 1
                
    return words_freq_dict

#测试用

filename = r'c:\temp\test_re_gbk.txt'
table = count_words_freq_dict(filename)
print(table)
# Out:
# {}

# %%
#4(c)
def count_words_freq_dict(filename):
    words_freq_dict = {}
    
    with open(filename) as f:
        for line in f:
            words = [word.split('/')[1] for word in line.split()]
            for word in words:
                if word in words_freq_dict: #如果词典中有键为word，则该word的value+1
                    words_freq_dict[word] += 1
                else:                       #否则，词典中加入键word，其value为1
                    words_freq_dict[word] = 1
                    
    return words_freq_dict

#测试用

filename = r'c:\temp\test_re_gbk.txt'
table = count_words_freq_dict(filename)

for i, item in enumerate(table):
    print(item, table[item])
# Out:
# nrfg 133
# l 2561
# p 13234
# n 76628
# m 25920
# v 59686
# x 63637
# t 6063
# nz 2603
# vn 7722
# i 1729
# d 18225
# ns 8153
# c 9321
# nr 10531
# nrt 995
# j 1707
# uj 15590
#  384
# vg 239
# eng 1616
# tg 64
# a 8249
# r 10942
# ug 238
# ud 205
# ul 3284
# nt 1723
# k 371
# ad 932
# f 5197
# u 1580
# b 1743
# vd 92
# an 302
# s 1281
# uv 344
# zg 754
# q 1339
# uz 408
# z 322
# ng 574
# h 90
# e 31
# y 308
# mq 219
# o 40
# rz 36
# ag 75
# dg 7
# g 76
# df 55
# vq 6
# rr 5
# rg 8
# vi 6
# yg 6

# %%
#4(d)
def count_words_freq_dict(filename):
    
    list=[]
    number=0
    with open(filename) as f:
        for line in f:
            words = [[word.split('/')[0],word.split('/')[1]] for word in line.split()]
            for word in words:
                if word[1] =='nr':
                    if word[0] not in list: 
                        list.append(word[0])
                        number+=1
                        
                    
               
                
                    
    return list,number

#测试用

filename = r'c:\temp\test_re_gbk.txt'
table = count_words_freq_dict(filename)

print(count_words_freq_dict(filename))
# Out:
# (['张家口', '蔡', '呼格', '祝福', '宝贵', '马航', '钟声', '从严治党', '利剑', '蓝图', '呼唤', '阳光', '谢谢', '孙春兰', '饶阳', '蔡名照', '李从军', '白克力', '博乐', '李克强', '小微', '公正', '延长线', '王歧丰', '金融城', '大屏幕', '迎新年', '杨扬', '叶乔波', '申雪', '赵宏博', '张虹', '李妮娜', '吴', '贾鹏', '周', '高峰', '西红门', '紫芳园', '芳', '久敬庄', '霍营', '续航', '银行卡', '安全门', '宣武门', '亦庄', '昌平', '曹晶瑞', '张璐', '王巍', '申请人', '王萍', '大伟', '奥赛', '特长生', '金', '养老金', '马迭尔', '肖丹', '石景山', '贝斯', '玛', '黑森林', '梅高信', '博野县', '康园', '嘉', '冰宝罗', '熊', '宝罗熊', '冰淇淋', '宫', '邹乐', '石军', '宣传部', '卡', '张', '张树坡', '幼儿园', '施暴', '玉', '玉桥', '李女士', '支支吾吾', '姜', '刘女士', '杨先生', '杜绝', '贝乐康', '铁瑾', '马先生', '清仓', '塞满', '丁先生', '安静', '金刚', '小金刚', '顾客', '刘', '老先生', '寻思', '刘老', '老祖宗', '张嘴', '闫', '门脸儿', '宝贝', '红太阳', '闫老', '小兄弟', '马老', '玉石', '陈佳', '毛巾', '黎', '樊一婧', '明华嘉', '冯广聚', '陈佳兴', '冯', '魏', '郭', '恩元居', '辛', '北京小吃', '辛振江', '冯老', '冯博', '钱振波', '马国义', '高达', '阳光板', '雪山', '黄志', '高潮', '唐明生', '嘉实', '昨天早上', '安抚', '刘悦伦', '陈菲', '查明', '陆冠峰', '腾飞', '文明', '李', '尚爱云', '贾立君', '于嘉', '尔博沃', '桑迪', '班邦', '斯提', '幸存者', '雷达', '庄', '田云',
# ...

# %%
#4(e)
from collections import Counter

def count_words_freq_dict(filename1):
    words_freq_dict = Counter()
    number=0
    
    
    with open(filename1) as f1:
        for line in f1:
            words_freq_dict.update([word.split('/')[0] for word in line.split()])
            words = [word.split('/')[0] for word in line.split()]
            for word in words:
                number+=1
    return words_freq_dict


def count_words_freq_dict(filename2):
    words_freq_dict = Counter()
    number=0
    
    
        
    with open(filename2) as f2:
        for line in f2:
            words_freq_dict.update([word.split('/')[0] for word in line.split()])
            words = [word.split('/')[0] for word in line.split()]
            for word in words:
                number+=1
    return words_freq_dict
    

def main():
    filename1 = r'c:\temp\idioms.txt'
    filename2 = r'c:\temp\test_re_gbk.txt'
    
    table1 = count_words_freq_dict(filename1)
    table2 = count_words_freq_dict(filename2)
    print('成语库词表',table1)
    print('语料库词表',table2)
    print('成语库词表长度'，number1)
    print('语料库词表长度'，number2)

if __name__ == '__main__':
    main()
# Out:
# 成语库词表 Counter()
# ...

# %%
#4(f)
def game():
    fh=open(r'C:\temp\idioms.txt')
    text=fh.read()
    fh.close()
    idioms=text.split('\n')
    hum=0 
    com=0 
    i=1
    a=random.choice(idioms)
    print(a)
    memory = set()
    memory.add(a)
    while i>0:
        b=input('输入要接的成语，回车结束：')
    
        if b.strip() == '':
            break
        if b == False:
            print("游戏结束！该成语不存在")
            break
        if b in memory:
            print("游戏结束！该成语已被使用过")  
            break
        if b[0]==a[3]:
            hum=hum+10
            memory.add(b)
            for a in idioms:
                if a == False:
                    print("游戏结束！该成语不存在")
                    break
                if a[0]==b[3]:
                    print(a)
                    com=com+10
                    break
                
        
            i=i+1
        else:
            
        
          
    if hum>com:
        win()  
    if hum==com:
        deuce()
    else:
        lose()

def main():
    while True:
        menu()
        choice = int(input('请输入你的选择'))
        if choice == 1:
            instruction()
        elif choice == 2:
            game()
            
        elif choice == 3:
            game_over()
            break
        else:
            team()


if __name__ == '__main__':
    main()
