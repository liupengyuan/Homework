# %%
#2、随机生成1万个整数，范围在0-10万之间，求其中每个整数出现的次数。并按照整数大小排序输出整数及出现次数。
import random

from collections import Counter
def number_time():
    n=[]
    number_freq_dict=Counter()
    for i in range(10000):
        number=random.randint(1,100000)
        n.append(number)
    n=sorted(n)
    number_freq_dict.update(number for number in n)
    return number_freq_dict
number_time()
# Out:
# Counter({7: 1,
#          9: 1,
#          23: 1,
#          46: 1,
#          70: 1,
#          81: 1,
#          109: 1,
#          118: 1,
#          119: 1,
#          121: 1,
#          128: 1,
#          134: 1,
#          140: 1,
#          154: 1,
#          168: 1,
#          170: 1,
#          176: 1,
#          180: 1,
#          188: 1,
#          191: 1,
#          198: 1,
#          211: 1,
#          220: 1,
#          231: 1,
#          239: 1,
#          255: 1,
#          267: 1,
#          268: 1,
#          276: 1,
#          291: 1,
#          311: 1,
#          316: 1,
#          317: 1,
#          320: 1,
#          339: 1,
#          353: 1,
#          357: 1,
#          364: 1,
#          365: 2,
#          370: 1,
#          372: 2,
#          390: 1,
#          392: 1,
#          398: 1,
#          402: 1,
#          427: 1,
#          438: 1,
#          440: 1,
#          455: 1,
#          457: 1,
#          468: 1,
#          498: 1,
#          509: 1,
# ...

# %%
#33、对本任务中的语料.txt文件，抽取其5001-10000行存为test1.txt文件，写函数，可得到其与本任务中test.txt文件的共用字以及独用字（相关概念自行百度）。


with open(r'C:\temp\语料.txt') as reader, open(r'c:\temp\test1.txt', 'w') as writer:
    for index, line in enumerate(reader):
        if 5000<index<10000:
            writer.write(line) 
def result(filename):
    words=[]
    with open(filename) as f:
        for line in f:
             words = {word.split('/')[0] for word in line.split()}
    return words
def result2(filename2):
    with open(filename2) as fh:
        for line2 in fh:
            words2 = {word.split('/')[0] for word in line.split()}
    return words2

filename = r'd:\temp\语料.txt'
filename2 = r'd:\temp\test1.txt'
print('共用字是',result2(filename2) &compute(filename))
print('独用字是',result(filename)|compute(filename))

# %%
#4挑战性任务：统计本任务中的语料.txt文件，得到每一个词对应不同词性的频次,输出词频最高的50个条目
def count_words_freq_dict(filename):
    words_freq_dict = {}
    
    with open(filename) as f:
        for line in f:
            words = [word.split('/')[1] for word in line.split()]
            for word in words:
                if word in words_freq_dict:
                    words_freq_dict[word] += 1
                else:                       
                    words_freq_dict[word] = 1
                    
    return words_freq_dict
from operator import itemgetter
filename = r'c:\temp\语料.txt'
result = count_words_freq_dict(filename)
sorted(result.items(),key=lambda x:x[1],reverse=True)[-50:]
