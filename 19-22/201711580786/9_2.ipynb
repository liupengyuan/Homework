# %%
import random
A=[]
B={}
for i in range(1,10001):
     a=random.randint(1,100000)
     A.append(a)
A.sort()
for i in A:
    if i in B:
        B[i] += 1
    else:
        B[i] = 1
print(B)
# Out:
# {5: 1, 7: 1, 8: 1, 14: 1, 18: 1, 23: 1, 32: 1, 59: 1, 82: 1, 111: 1, 112: 1, 115: 1, 118: 1, 124: 1, 133: 1, 146: 1, 167: 1, 174: 1, 233: 1, 240: 1, 245: 1, 274: 1, 287: 2, 288: 2, 301: 1, 311: 1, 314: 1, 315: 1, 329: 1, 335: 1, 342: 1, 343: 1, 353: 1, 397: 1, 409: 1, 410: 1, 412: 1, 416: 1, 417: 1, 418: 1, 434: 1, 437: 1, 475: 2, 480: 1, 481: 1, 485: 1, 492: 1, 496: 1, 505: 1, 523: 1, 531: 1, 532: 1, 537: 1, 544: 1, 557: 1, 562: 1, 565: 1, 569: 1, 576: 1, 587: 1, 599: 1, 600: 1, 616: 1, 628: 1, 631: 1, 640: 1, 645: 1, 646: 1, 655: 1, 659: 1, 660: 1, 684: 1, 691: 1, 705: 1, 708: 1, 720: 2, 724: 1, 732: 1, 733: 1, 745: 1, 752: 1, 756: 2, 784: 1, 785: 2, 795: 1, 796: 1, 799: 1, 802: 1, 804: 1, 805: 1, 819: 1, 823: 1, 827: 1, 833: 1, 850: 1, 877: 1, 891: 1, 895: 1, 897: 1, 928: 1, 931: 1, 935: 1, 950: 1, 955: 1, 957: 1, 962: 1, 971: 1, 978: 1, 990: 1, 995: 1, 1036: 1, 1047: 1, 1050: 1, 1053: 1, 1070: 1, 1077: 1, 1096: 1, 1121: 1, 1122: 1, 1145: 1, 1146: 1, 1153: 1, 1164: 1, 1167: 1, 117
# ...

# %%
with open(r'd:\temp\test.txt', 'w') as fw, open(r'd:\temp\test1.txt', 'w') as fe,open(r'd:\temp\语料.txt') as fr:
    line_number = 0
    for line in fr:
        if line_number < 5000:
            fw.write(line)
            line_number += 1
        elif line_number >= 5000 and line_number < 10000:
            fe.write(line)
            line_number += 1
        else:
            break
word_table = set()
word_table1 = set()
word_table2 = set()
word_table3 = set()
with open(r'd:\temp\test.txt') as fw, open(r'd:\temp\test1.txt') as fe:
    for line in fw:
        word_table |= {word.split('/')[0] for word in line.split()}
    for line in fe:
        word_table1 |= {word.split('/')[0] for word in line.split()}
    for word in word_table1:
        if word in word_table:
            word_table2.add(word)
        else:
            word_table3.add(word)
print(word_table2)#共用字
print(word_table3)#独用字
# Out:
# {'', '票房', '觉得', '政委', '二战', '反思', '该局', '提及', '政坛', '两球', '铁瑾', 'H', '指责', '给予', '45', '穿着', '零时', '沙漠', '丝毫', '小学', '诱发', '抓紧', '黑名单', '复兴', '每次', '发挥作用', '佼佼者', '前三位', '工信', '某某', '擅自', '软', '志愿', '履约', '专题', '融合', '产生', '只能', '本次', '舞蹈', '自由竞争', '祝', '限额', '险些', '莫言', '无关', '管理处', '连通', '极为', '发问', '不已', '搭档', '协助', '行政部门', '大伟', '盐商', '星光', '耗时', '同事', '查办', '整整', '节俭', '煮饭', '颠覆', '中央电视台', '先下', '操作性', '正如', '东南部', '资讯', '胃口', '生涯', '带来', '策划', '精细', '整改', '一代人', '邂逅', '纽约州', '清华', '混乱', '级别', '依旧', '醇香', '下', '大河', '校方', '时常', '出汗', '翻译家', '了结', '限制', '教室', '奋战', '没见', '你', '见', '把握', '上海', '地图', '刘', '黄牛', '全区', '经营者', '监察厅', '美的', '人体', '河南', '伤害', '玉器', '现象', '真凶', '大使', '获救', '平米', '官微', '出生', '加大', '幼儿园', '好球', '乐此不疲', '建立', '装修', '难逃', '解读', '借钱', '腰椎', '外长', '信号', '各路', '这家', '纷纷', '拿到', '白水', '中国队', '商务部', '现身', '甚至', '推新', '党组织', '过去', '曹', '总计', '创作者', '六天', '钱', '或者说', '过节', '来源于', '感触', '消灭', '李澄', '古建', '临近', '运到', '称号', '纤细', '宣传部', '尽可能', '港币', '加剧', '联网', '党中央'
# ...
