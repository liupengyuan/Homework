# %%
#1
def g(m,n):
    k=1
    i=n
    while i>0:
        print(' '*2*i+' ',(m+' ')*k,m*n,(m+' ')*k)
        k+=1
        i=i-1
        
m=input('请输入符号')
n=int(input('请输入行数'))
g(m,n)
# Out:
# 请输入符号*
# 请输入行数5
#             *  ***** *
#           * *  ***** * *
#         * * *  ***** * * *
#       * * * *  ***** * * * *
#     * * * * *  ***** * * * * *

# %%
#2
def a(m,n):
    if m==0:
        return n+1
    elif m>0 and n==0:
        return a(m-1,1)
    elif m>0 and n>0:
        n=a(m,n-1)
        return a(m-1,n)
m=3
n=4
a(m,n)
print(a(m,n))
# Out:
# 125

# %%
#3（1）
import random
def f():
    num=0
    c=1
    z=['+','-','*','/']
    an=[]
    f=[]
    while c>0:
        for j in range(3):
            m=random.randint(a,b)
            o=random.choice(z)
            k=random.randint(a,b)
            if o==z[0]:
                s=m+k
            elif o==z[1]:
                s=m-k
            elif o==z[2]:
                s=m*k
            else:
                s=m/k
            if s>0 and s%1==0:
                num+=1
                print(m,o,k,'=')
                an.append(s)
                f.append(o)
        if num==n:
            break

            

    
n=int(input('请输入题目数量'))   
a=int(input('请输入数字下限'))
b=int(input('请输入数字上限'))
f()
# Out:
# 请输入题目数量15
# 请输入数字下限3
# 请输入数字上限25
# 19 + 22 =
# 10 * 14 =
# 23 - 15 =
# 13 + 19 =
# 22 + 10 =
# 20 * 24 =
# 24 + 7 =
# 5 + 6 =
# 10 + 9 =
# 10 * 12 =
# 4 * 11 =
# 5 + 3 =
# 12 + 4 =
# 13 * 23 =
# 5 + 25 =
# 请输入所有答案41
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9685a285da18> in <module>()
#      41 total=0
#      42 for i in range(n):
# ---> 43     if an[i]==ans[i]:
#      44         if f[i]==z[0] or f[i]==z[1]:
#      45             total+=5
#
# NameError: name 'an' is not defined

# %%
#3（2）
ans=tuple()
ans=input('请输入所有答案')
total=0
for i in range(n):
    if an[i]==ans[i]:
        if f[i]==z[0] or f[i]==z[1]:
            total+=5
        else:
            total+=10
print(total)
# Out:
# 请输入所有答案28,33,2,2,2,2,2,2,2,2,2,2,2,2,2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-956804920a93> in <module>()
#       4 total=0
#       5 for i in range(n):
# ----> 6     if an[i]==ans[i]:
#       7         if f[i]==z[0] or f[i]==z[1]:
#       8             total+=5
#
# NameError: name 'an' is not defined

# %%
#3（1）
import random
def f():
    num=0
    c=1
    z=['+','-','*','/']
    an=[]
    f=[]
    ans=tuple()
    total=0
    while c>0:
        for j in range(3):
            m=random.randint(a,b)
            o=random.choice(z)
            k=random.randint(a,b)
            if o==z[0]:
                s=m+k
            elif o==z[1]:
                s=m-k
            elif o==z[2]:
                s=m*k
            else:
                s=m/k
            if s>0 and s%1==0:
                num+=1
                print(m,o,k,'=')
                an.append(s)
                f.append(o)
        if num==n:
            break
    
    ans=input('请输入所有答案')
    
    for i in range(n):
        if an[i]==ans[i]:
            if f[i]==z[0] or f[i]==z[1]:
                
                total+=5
            else:
                total+=10
    return total

            

    
n=int(input('请输入题目数量'))   
a=int(input('请输入数字下限'))
b=int(input('请输入数字上限'))
print('总分是')
f()
# Out:
# 请输入题目数量15
# 请输入数字下限3
# 请输入数字上限25
# 总分是
# 17 * 13 =
# 15 + 13 =
# 4 + 6 =
# 25 - 11 =
# 11 * 23 =
# 17 * 3 =
# 25 + 20 =
# 7 + 19 =
# 18 + 3 =
# 20 + 10 =
# 11 * 11 =
# 15 + 12 =
# 11 - 10 =
# 12 * 17 =
# 24 * 23 =
# 11 + 20 =
# 25 - 7 =
# 5 * 16 =
# 7 + 17 =
# 24 * 12 =
# 25 * 16 =
# 25 - 13 =
# 16 * 24 =
# 24 + 15 =
# 18 + 19 =
# 23 + 21 =
# 24 + 16 =
# 14 - 3 =
# 14 + 6 =
# 17 * 19 =
# 18 - 6 =
# 15 + 23 =
# 9 + 16 =
# 15 + 8 =
# 10 + 17 =
# 20 * 9 =
# 17 + 19 =
# 4 * 18 =
# 18 - 12 =
# 7 + 3 =
# 7 * 20 =
# 24 * 6 =
# 25 + 24 =
# 11 + 21 =
# 4 * 15 =
# 23 * 22 =
# 16 - 3 =
# 12 - 3 =
# 7 + 5 =
# 20 + 8 =
# 16 * 3 =
# 17 * 24 =
# 11 + 15 =
# 22 - 14 =
# 18 * 5 =
# 11 * 3 =
# 14 + 19 =
# 18 + 12 =
# 19 * 17 =
# 11 + 15 =
# 12 + 12 =
# 20 + 7 =
# 8 * 4 =
# 21 + 18 =
# 20 + 4 =
# 19 + 11 =
# 19 + 5 =
# 23 * 10 =
# 19 * 12 =
# 11 + 7 =
# 11 * 8 =
# 9 - 7 =
# 25 * 4 =
# 15 / 15 =
# 7 + 18 =
# 18 * 23 =
# 9 - 8 =
# 25 + 13 =
# 18 + 3 =
# 8 + 20 =
# 20 * 3 =
# 19 + 16 =
# 5 * 21 =
# ...

# %%
#4(a)
with open(r'd:\成语大全(含成语解释)_utf8.txt',encoding='utf-8')as f:
    text = f.read()
    words = [line.spilt('/')[0] for line in text.split()]
    print(words)
    idioms={}
    idioms1=[]
    for word in words:
        if len(word)==4 and word in idioms:
            idioms1.append(word)
            idioms[word]+=1
        elif len(word)==4 and word not in idioms:
            idioms[word]=1
    print(idioms1)

# %%
from collections import Counter

def count_words_freq_dict():
    words_freq_dict = Counter()
    a=[]
    
    with open(r'd:/test_re_gbk.txt') as fh:
        test=fh.read
        test=[word.split('/')[0] for word in test.split()]
        for idiom in idioms:
            if idiom in test:
                a.append(idiom)

        words_freq_dict.update([a])
    return words_freq_dict

print(count_words_freq_dict())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-bffbe5748bf5> in <module>()
#      15     return words_freq_dict
#      16
# ---> 17 print(count_words_freq_dict())
#
# <ipython-input-20-bffbe5748bf5> in count_words_freq_dict()
#       7     with open(r'd:/test_re_gbk.txt') as fh:
#       8         test=fh.read
# ----> 9         test=[word.split('/')[0] for word in test.split()]
#      10         for idiom in idioms:
#      11             if idiom in test:
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'split'

# %%
#(c)
from collections import Counter

def count_words_freq_dict():
    words_freq_dict = Counter()
    
    with open(r'd:/test_re_gbk.txt') as fw:
        for line in fw:
            words_freq_dict.update([word.split('/')[0] for word in line.split()])
    return words_freq_dict
print(count_words_freq_dict())
# Out:
# Counter({'n': 76628, 'x': 63637, 'v': 59686, 'm': 25920, 'd': 18225, 'uj': 15590, 'p': 13234, 'r': 10942, 'nr': 10531, 'c': 9321, 'a': 8249, 'ns': 8153, 'vn': 7722, 't': 6063, 'f': 5197, 'ul': 3284, 'nz': 2603, 'l': 2561, 'b': 1743, 'i': 1729, 'nt': 1723, 'j': 1707, 'eng': 1616, 'u': 1580, 'q': 1339, 's': 1281, 'nrt': 995, 'ad': 932, 'zg': 754, 'ng': 574, 'uz': 408, '': 384, 'k': 371, 'uv': 344, 'z': 322, 'y': 308, 'an': 302, 'vg': 239, 'ug': 238, 'mq': 219, 'ud': 205, 'nrfg': 133, 'vd': 92, 'h': 90, 'g': 76, 'ag': 75, 'tg': 64, 'df': 55, 'o': 40, 'rz': 36, 'e': 31, 'rg': 8, 'dg': 7, 'vq': 6, 'vi': 6, 'yg': 6, 'rr': 5})

# %%
#(d)
with open(r'd:/test_re_gbk.txt') as fs:
    tet=fs.read
    wor=[]
    for line in tet.split(): 
        for word in line:
            word.split('/')
            if word[1] =='nr':
                wor.append(word[0])
    print(wor)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-8a1bce7fcaa7> in <module>()
#       3     tet=fs.read
#       4     wor=[]
# ----> 5     for line in tet.split():
#       6         for word in line:
#       7             word.split('/')
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'split'

# %%
#(e)
def get_ch_table(line):
    ch_table = []
    total1=0
    for ch in line:
        if ch not in ch_table:
            ch_table.append(ch)
            total1=total1+len(ch)
    return ch_table

# 主程序
fh = open(r'd:/test_re_gbk.txt')
fw=open(r'd:\成语大全(含成语解释)_utf8.txt',encoding='utf-8')
text1= fh.read()
text2=fw.read()
chs = get_ch_table(text1.replace('\n', ''))
zhs=get_ch_table(text2.replace('\n', ''))
print(total1/len(chs),chs)
