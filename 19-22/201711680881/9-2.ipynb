# %%
#2、随机生成1万个整数，范围在0-10万之间，求其中每个整数出现的次数。并按照整数大小排序输出整数及出现次数。
import random
numbers=[random.randint(1,100000)  for i in range(10000)]
numbers.sort()
print(numbers)
number_list={}
for number in numbers:
    if numbers.count(number)>0:
        number_list[number]=numbers.count(number)
print(number_list)
# Out:
# [2, 11, 21, 38, 45, 53, 58, 70, 73, 73, 73, 89, 96, 100, 109, 140, 142, 162, 174, 175, 176, 183, 185, 187, 190, 192, 198, 200, 212, 230, 234, 237, 242, 255, 257, 276, 279, 291, 292, 309, 311, 327, 343, 350, 359, 366, 366, 375, 382, 401, 411, 415, 424, 424, 428, 431, 432, 437, 443, 450, 456, 467, 470, 481, 505, 514, 529, 552, 555, 565, 579, 579, 590, 600, 634, 655, 663, 676, 683, 687, 695, 695, 696, 706, 739, 749, 752, 753, 757, 808, 813, 818, 827, 841, 842, 849, 901, 910, 934, 942, 943, 946, 950, 953, 956, 964, 979, 979, 985, 985, 990, 995, 1007, 1050, 1081, 1084, 1086, 1093, 1111, 1113, 1124, 1138, 1150, 1170, 1194, 1236, 1241, 1258, 1265, 1269, 1276, 1281, 1283, 1293, 1296, 1298, 1309, 1311, 1312, 1321, 1342, 1359, 1361, 1372, 1372, 1378, 1400, 1405, 1414, 1433, 1437, 1439, 1448, 1450, 1466, 1481, 1487, 1496, 1507, 1509, 1516, 1523, 1525, 1532, 1577, 1584, 1596, 1598, 1599, 1624, 1628, 1642, 1663, 1665, 1671, 1680, 1693, 1737, 1747, 1750, 1763, 1765, 1766, 1783, 1798, 1811, 1818, 1
# ...

# %%
#3、对本任务中的语料.txt文件，抽取其5001-10000行存为test1.txt文件，写函数，可得到其与本任务中test.txt文件的共用字以及独用字。
with open(r'd:\temp\test.txt', 'w') as fw, 
open(r'd:\temp\语料.txt') as fr:
    line_number = 0
    for line in fr:
        if line_number < 5000:
            fw.write(line)
            line_number += 1
        else:
            break

with open(r'd:\temp\test1.txt','w') as xin,
open(r'd:\temp\语料.txt') as yuan:
    lieshu=0
    for line in yuan:
        if lieshu>5000 and lieshu<10000:
            xin.write(line)
            lieshu+=1
        elif lieshu>10000:
            break
            
def word_table(file):
    word_table=[]
    with open(file)as f:
        text=f.read()
        words=[word.split('/')[0] for word in text.split()]
        for word in words:
            if word not in word_table:
                word_table.append(word)
        return word_table

file=r'd:\temp\test.txt'
file1=r'd:\temp\test1.txt'
table=word_table(flie)
table1=word_table(flie1)

together=[]
table1_only=[]
table_only=[]
for word in table:
    if word in table1:
        together.append(word)
    else:
        table_only.append(word)
for word in table1:
    if word not in together:
        table1_only.append(word)
        
print('test独用字表：',table_only)
print('text1独用字表：',table1_only)
print('共用字表：',together)
# Out:
#   File "<ipython-input-20-13a3e65ca27e>", line 2
#     with open(r'd:\temp\test.txt', 'w') as fw,
#                                                ^
# SyntaxError: invalid syntax

# %%
import re
from collections import Counter

def word_table(file):
    word_table=[]
    with open(file)as f:
        text=f.read()
        words=[word.split('/')[0] for word in text.split()]
        for word in words:
            if word not in word_table:
                word_table.append(word)
        return word_table
words=r'd:\temp\语料.txt'
word_table=word_table(words)
word=Counter(word_table)
print(word.most_commom(50))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-19-1e1ec1559c61> in <module>()
#      12         return word_table
#      13 words=r'd:\temp\语料.txt'
# ---> 14 word_table=word_table(words)
#      15 word=Counter(word_table)
#      16 print(word.most_commom(50))
#
# <ipython-input-19-1e1ec1559c61> in word_table(file)
#       5     word_table=[]
#       6     with open(file)as f:
# ----> 7         text=f.read()
#       8         words=[word.split('/')[0] for word in text.split()]
#       9         for word in words:
#
# UnicodeDecodeError: 'gbk' codec can't decode byte 0x80 in position 110: illegal multibyte sequence
