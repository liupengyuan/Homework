# %%
import random
A = {}
numbers = [random.randint(1,100001) for i in range(10000)]
for number in numbers:
    if number in A:
        A[number] += 1
    else:
        A[number] = 1
print (A)
# Out:
# {50570: 1, 17714: 1, 89725: 1, 55611: 1, 34185: 1, 15621: 1, 66131: 1, 19842: 1, 67077: 1, 59520: 2, 82514: 1, 37643: 1, 26922: 1, 3940: 1, 70573: 1, 9545: 1, 17133: 1, 52630: 2, 40961: 1, 25895: 1, 57719: 1, 76436: 1, 57249: 1, 63345: 2, 70736: 2, 83448: 2, 56337: 1, 46461: 2, 6330: 1, 60981: 1, 45137: 1, 98280: 1, 73846: 2, 37457: 1, 22254: 1, 61115: 1, 70861: 1, 18472: 1, 19930: 1, 33225: 1, 98148: 1, 37693: 1, 40004: 1, 69039: 1, 8094: 1, 29081: 1, 21255: 1, 11118: 1, 49159: 1, 56756: 1, 15503: 1, 11297: 2, 53642: 1, 3245: 1, 73310: 1, 84881: 1, 90913: 1, 54964: 1, 62921: 1, 23110: 1, 6319: 1, 8259: 1, 68541: 1, 79824: 1, 88736: 2, 47454: 1, 61118: 1, 26999: 1, 77260: 1, 55517: 2, 47696: 1, 67975: 1, 39326: 1, 10077: 1, 72193: 1, 11579: 1, 83783: 1, 18445: 1, 25944: 1, 57917: 1, 28907: 1, 86690: 1, 22330: 1, 43261: 1, 56421: 1, 55479: 1, 8261: 1, 40291: 1, 33939: 1, 57059: 1, 16852: 2, 23010: 1, 47234: 2, 92370: 1, 35272: 1, 90530: 1, 99881: 1, 66085: 1, 56599: 2, 23288: 1, 66282
# ...

# %%
def c_table(filename):
    words_table = set()
    c_table = set()
    with open(filename) as f:
        for line in f:
            words_table |= {word.split('/')[0] for word in line.split()} 
            for word in words_table:
                c_table |= {c for c in word}
        return c_table
                                        
word_1 = c_table(r'C:\temp\test.txt')
word_2 = c_table(r'C:\temp\test1.txt')

print('共用字是',word_1 & word_2)
print('独用字是',word_1 - word_2)
