# %%
#2、随机生成1万个整数，范围在0-10万之间，求其中每个整数出现的次数。并按照整数大小排序输出整数及出现次数。

import random
from collections import Counter
list = []
for i in range(1,10001):
    x=random.randint(0,100001)
    list.append(x)
    a=Counter(list)
print(a)
# Out:
# Counter({95185: 4, 95204: 3, 28952: 3, 8442: 3, 60343: 3, 264: 3, 41874: 3, 77373: 3, 79105: 3, 94358: 3, 82735: 3, 53883: 3, 39913: 3, 50186: 3, 24800: 3, 66075: 3, 66411: 3, 67344: 3, 66249: 2, 98977: 2, 15038: 2, 38254: 2, 59365: 2, 34816: 2, 25163: 2, 49159: 2, 72700: 2, 47577: 2, 22245: 2, 43783: 2, 72290: 2, 23407: 2, 1052: 2, 61885: 2, 37962: 2, 2752: 2, 32106: 2, 47232: 2, 2584: 2, 19905: 2, 9298: 2, 94519: 2, 54591: 2, 50089: 2, 55707: 2, 91132: 2, 8949: 2, 71367: 2, 19662: 2, 11605: 2, 57222: 2, 78234: 2, 69746: 2, 33863: 2, 2587: 2, 51671: 2, 84306: 2, 38223: 2, 55836: 2, 63888: 2, 44399: 2, 92288: 2, 80760: 2, 81775: 2, 69050: 2, 8696: 2, 59470: 2, 61750: 2, 5239: 2, 32788: 2, 48987: 2, 3242: 2, 7441: 2, 25060: 2, 96792: 2, 53030: 2, 61485: 2, 34671: 2, 40373: 2, 67702: 2, 40304: 2, 32205: 2, 30596: 2, 46502: 2, 39399: 2, 27722: 2, 35462: 2, 91294: 2, 14929: 2, 56806: 2, 56615: 2, 53262: 2, 90060: 2, 35417: 2, 84901: 2, 26421: 2, 87527: 2, 39945: 2, 42751: 2, 1734: 2, 289
# ...

# %%
#3、对本任务中的语料.txt文件，
# 随机抽取其5001-10000行存为test1.txt文件，写函数，可得到其与本任务中test.txt文件的共用字以及独用字（相关概念自行百度）
with open(r'd:\temp\test.txt', 'w') as fw, open(r'd:\temp\语料.txt') as fr:
    line_number = 0
    for line in fr:
        if line_number < 5000:
            fw.write(line)
            line_number += 1
        else:
            break
with open(r'd:\temp\test1.txt', 'w') as fw, open(r'd:\temp\语料.txt') as fr:
    line_number = 0
    for line in fr:
        if 5000< line_number <10001:
            fw.write(line)
            line_number += 1
        else:
            break

filename = r'd:\temp\test.txt'
word_table1 = set()
with open(filename) as f:
    for line in f:
        word_table |= {word.split('/')[0] for word in line.split()}
for i, word in enumerate(word_table1):
    a.append(word)
filename = r'd:\temp\test1.txt'
word_table2 = set()
with open(filename) as f:
    for line in f:
        word_table |= {word.split('/')[0] for word in line.split()}
for i, word in enumerate(word_table2):
    b.append(word)
print(word_table1 & word_table2)
# Out:
# set()

# %%
#挑战性任务：统计本任务中的语料.txt文件，得到每一个词对应不同词性的频次，可表示为：{词:[('n',1000), ('v', 98)...],...}，
#即在dict对象中，key为词，value为列表，输出词频最高的50个条目。
