# %%
import random
list=[]
for i in range(10000):
    list.append(random.randint(0,100000))

dict={}
for m in list:
    if m not in dict:
        dict[m]=1
    else:
        dict[m]+=1

for key in sorted(dict.keys()):
    print(key, dict[key])
# Out:
# 25 1
# 33 1
# 34 1
# 40 1
# 44 1
# 50 1
# 55 1
# 61 1
# 80 1
# 90 1
# 100 1
# 111 1
# 122 1
# 138 1
# 142 1
# 169 1
# 171 1
# 191 1
# 192 1
# 208 1
# 219 1
# 229 1
# 242 1
# 254 1
# 257 1
# 260 1
# 268 1
# 271 1
# 295 1
# 297 1
# 299 1
# 313 2
# 325 1
# 328 1
# 349 1
# 353 1
# 378 1
# 390 1
# 401 1
# 402 1
# 417 1
# 418 1
# 434 1
# 446 1
# 459 1
# 536 1
# 539 1
# 552 1
# 554 1
# 560 1
# 582 1
# 608 1
# 610 1
# 611 1
# 615 1
# 620 1
# 635 1
# 639 1
# 643 1
# 647 1
# 651 2
# 653 1
# 658 1
# 664 1
# 680 1
# 681 1
# 685 1
# 689 1
# 690 1
# 694 1
# 696 1
# 701 1
# 730 1
# 756 1
# 758 2
# 761 1
# 766 1
# 773 1
# 792 1
# 834 1
# 843 1
# 847 1
# 868 2
# 883 1
# 905 1
# 914 1
# 920 1
# 927 1
# 928 1
# 948 1
# 955 1
# 970 2
# 975 1
# 988 1
# 1015 1
# 1042 1
# 1050 2
# 1062 1
# 1077 1
# 1104 1
# 1111 1
# 1114 1
# 1132 1
# 1140 1
# 1157 1
# 1168 1
# 1171 1
# 1173 1
# 1179 1
# 1191 1
# 1194 1
# 1217 1
# 1250 1
# 1251 1
# 1259 1
# 1279 1
# 1283 1
# 1294 1
# 1296 1
# 1302 1
# 1323 1
# 1368 1
# ...

# %%
with open(r'C:\temp\语料.txt') as f:
    fh=open(r'C:\temp\语料.txt', 'w')
    fh.writelines(f.readlines()[1:5000])
    fh=open(r'C:\temp\语料.txt')
    text=fh.read()
          
with open(r'C:\temp\语料.txt') as f:
    fh1 = open(r'c:\\temp\\text1.txt', 'w')
    fh1.writelines(f.readlines()[5001:100000])
    fh1=open(r'c:\\temp\\text1.txt')
    text1=fh1.read()

fh.close
fh1.close

text = text.replace('、', '')
text1 = text1.replace('、', '')
m=set(text)
nl=set(text1)
i= nl.intersection(s)
p=list(i)
print('共用字',l)
p1=n.difference(s)
m1=list(i1)
print('独用字',m1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-ddf2b106bc64> in <module>()
#      18 m=set(text)
#      19 nl=set(text1)
# ---> 20 i= nl.intersection(s)
#      21 p=list(i)
#      22 print('共用字',l)
#
# NameError: name 's' is not defined

# %%
from collections import defaultdict
with open(r'C:\temp\语料.txt') as fh:
    text = fh.read()
    words = [word.split('/') for word in text.split()]
    table=[word[0] for word in words]
    words_freq_dict = defaultdict(int)
for word in table:
    words_freq_dict[word] += 1
print(words_freq_dict)
# Out:
# defaultdict(<class 'int'>, {})
