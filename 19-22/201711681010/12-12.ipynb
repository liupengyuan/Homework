# %%
import random

def get_ch_table(line):
    ch_table = []
    for ch in line:
        if ch not in ch_table:
            ch_table.append(ch)
    return ch_table

def world_table():
    ch = []
    for i in range(n*10):
        tex = random.choice(get_ch_table(text))
        ch.append(tex)
    fht = open(r'c:\temp\n.txt','w')
    fht.write('\n'.join(ch))
    fht.close()
    return ch
    
    
fh = open(r'c:\temp\成语大全.txt')
text = fh.read()
fh.close()

n = 0
while n < 10:
    n +=1
    print(world_table())
# Out:
# ['挑', '室', '穷', '魅', '好', '麟', '填', '摸', '宠', '餐']
# ['德', '喻', '曲', '红', '砖', '外', '偷', '毋', '鸠', '漓', '下', '窠', '虫', '歧', '觑', '穿', '方', '躇', '假', '接']
# ['涂', '甘', '丑', '讳', '止', '谁', '风', '救', '弹', '迁', '勿', '囊', '涛', '周', '穿', '从', '归', '军', '怒', '炼', '喜', '雁', '幽', '腋', '阻', '筚', '惶', '七', '竽', '大']
# ['泪', '衰', '临', '戚', '背', '鼓', '攘', '菲', '抽', '临', '恨', '没', '晦', '丽', '牢', '呈', '狗', '蓉', '度', '合', '座', '倦', '岸', '忠', '惑', '离', '峰', '复', '木', '程', '今', '禁', '义', '口', '尔', '货', '逢', '迫', '胡', '闻']
# ['岸', '眸', '张', '行', '化', '其', '动', '内', '臼', '犬', '枪', '潭', '军', '殚', '想', '德', '今', '若', '垂', '奈', '瘁', '寡', '俊', '己', '面', '对', '余', '听', '单', '索', '虎', '杜', '投', '让', '巷', '塞', '开', '年', '富', '奇', '动', '则', '称', '尾', '苟', '织', '阋', '扫', '淡', '掠']
# ...
