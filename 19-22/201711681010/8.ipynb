# %%
import random

def win():
    print(
        '''
           ======恭喜你，你赢了=======
        
    
                ."".    ."",
                |  |   /  /
                |  |  /  /
                |  | /  /
                |  |/  ;-._ 
                }  ` _/  / ;
                |  /` ) /  /
                | /  /_/\_/\
                |/  /      |
                (  ' \ '-  |
                 \    `.  /
                  |      |
                  |      |
          
          ======恭喜你，你赢了=======
        '''
    )
    return
    
def lose():
    print(
        '''
           ======YOU LOSE=======
        
    
                

                   .-"      "-.
                  /            \
                 |              |
                 |,  .-.  .-.  ,|
                 | )(__/  \__)( |
                 |/     /\     \|
       (@_       (_     ^^     _)
  _     ) \_______\__|IIIIII|__/__________________________
 (_)@8@8{}<________|-\IIIIII/-|___________________________>
        )_/        \          /
       (@           `--------`
       
       
       
          ======YOU LOSE=======
        '''
    )
    return


def main():
    score_man = 0
    score_rob = 0
    idiom_robot = []
    answer_idiom = []
    idiom_rob = random.choice(idioms)
    n = 0
    while score_man >= 0:
        print(idiom_rob)
        idiom_robot.append(idiom_rob)
        ans_idiom = input('请输入接龙成语，回车结束，直接回车表示退出游戏：')
        answer_idiom.append(ans_idiom)
        n += 1
        if answer_idiom[n-1].startswith(idiom_robot[len(idiom_robot)-1][3]):
            print('答对了，加十分')
            score_man += 10
            print('你当前的分数是：', score_man)
            for idiom in idioms:
                if idiom[0].startswith(answer_idiom[len(answer_idiom)-1][3]):
                    idiom_rob = idiom
                
        else:
            print('答错了')
            print('你当前的分数是：', score_man)
            score_man = -10
    else:
        lose()
        return

fh = open(r'c:\temp\成语大全.txt')
text = fh.read()
fh.close()

text = text.replace('、', '')
start = 0
end = 0
idioms = []
while end < len(text):
    if text[end] == '\n':
        idioms.append(text[start:end])
        start = end + 1
    end += 1
    


main()
# Out:
# 侧目而视
# 请输入接龙成语，回车结束，直接回车表示退出游戏：视而不见
# 答对了，加十分
# 你当前的分数是： 10
# 见异思迁
# 请输入接龙成语，回车结束，直接回车表示退出游戏：钱不嫌多
# 答错了
# 你当前的分数是： 10
#
#            ======YOU LOSE=======
#
#
#
#
#                    .-"      "-.
#                   /                             |              |
#                  |,  .-.  .-.  ,|
#                  | )(__/  \__)( |
#                  |/     /\     \|
#        (@_       (_     ^^     _)
#   _     ) \_______\__|IIIIII|__/__________________________
#  (_)@8@8{}<________|-\IIIIII/-|___________________________>
#         )_/        \          /
#        (@           `--------`
#
#
#
#           ======YOU LOSE=======
