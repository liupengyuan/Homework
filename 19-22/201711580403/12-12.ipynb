# %%
import random
fh = open(r'c:\temp\idioms.txt')
text = fh.read()
text=text.replace('、', '' )
text=text.replace('\n', '' )
i=1
for k in range(10,101,10):
    while i<=k:
        ch=random.choice(text)
        i+=1
        print(ch)
for m in range (1,11):
    n=str(m)
    fh = open (r'c:/temp/'+n+'.txt','w')
    fh.writelines(idioms)
    fh.close()
# Out:
# 车
# 法
# 碧
# 夜
# 兵
# 小
# 无
# 禽
# 面
# 幽
# 香
# 无
# 能
# 气
# 流
# 见
# 地
# 捭
# 蹴
# 及
# 本
# 制
# 鞠
# 马
# 渭
# 约
# 朋
# 欺
# 钧
# 事
# 来
# 天
# 生
# 代
# 对
# 颐
# 大
# 美
# 宠
# 云
# 单
# 浮
# 金
# 虎
# 马
# 简
# 干
# 千
# 时
# 白
# 愿
# 至
# 有
# 缭
# 甚
# 食
# 字
# 臼
# 雨
# 马
# 发
# 手
# 开
# 闻
# 知
# 章
# 点
# 动
# 步
# 里
# 贻
# 天
# 士
# 意
# 面
# 气
# 旗
# 笑
# 蛇
# 之
# 马
# 大
# 添
# 飞
# 界
# 不
# 装
# 预
# 结
# 观
# 意
# 名
# 本
# 无
# 月
# 万
# 无
# 青
# 沉
# 字
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-84ce02ced60c> in <module>()
#      13     n=str(m)
#      14     fh = open (r'c:/temp/'+n+'.txt','w')
# ---> 15     fh.writelines(idioms)
#      16     fh.close()
#      17
#
# NameError: name 'idioms' is not defined
