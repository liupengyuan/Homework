# %%
import datetime,random
start=datetime.datetime.now()
def search(list,item):
    pos=0
    found=False
    while pos!=len(list) and not found:
        if list[pos]==item:
            found=True
            print(list[pos])
        else:
            pos+=1
    return found
x=[random.randint(1,110000) for i in range(1000)]
A=[x for x in range(1,100001)]
random.shuffle(A)
B=A
for i in x:
    search(B,i)
end=datetime.datetime.now()
time=end-start
print('运行时间为',time)
# Out:
# 41293
# 13936
# 2464
# 29516
# 4131
# 49231
# 79441
# 10786
# 31400
# 17649
# 35275
# 74831
# 29919
# 50033
# 4982
# 39290
# 27446
# 97458
# 18803
# 69058
# 89168
# 59408
# 82766
# 10484
# 37991
# 52109
# 44924
# 79723
# 71656
# 56070
# 53188
# 60593
# 67008
# 62314
# 89454
# 25659
# 46345
# 65755
# 7340
# 31916
# 34918
# 32192
# 42878
# 19083
# 96067
# 63452
# 33561
# 79772
# 75008
# 7637
# 45434
# 91990
# 98186
# 57589
# 67780
# 73909
# 82575
# 12591
# 18617
# 53867
# 40484
# 28986
# 41984
# 56314
# 83718
# 98183
# 79334
# 8460
# 13173
# 53451
# 86396
# 12088
# 8321
# 65177
# 10548
# 33029
# 47722
# 85110
# 52122
# 30796
# 20722
# 5531
# 69700
# 69678
# 39786
# 51272
# 99006
# 5589
# 78751
# 27333
# 27439
# 68996
# 21669
# 312
# 77640
# 72015
# 14207
# 35595
# 5834
# 41606
# 62105
# 9089
# 78354
# 43815
# 92871
# 221
# 55471
# 80818
# 6058
# 87781
# 46293
# 21173
# 59273
# 78049
# 72347
# 81894
# 65479
# 62338
# 73131
# 75814
# 72639
# 12668
# 17751
# 82302
# 17778
# 99011
# 975
# ...
