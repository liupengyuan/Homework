# %%
from collections import Counter
import random

numbers=[]
n=1
for i in range(10000) :
    num=numbers.append(random.randint(1, 100000))
sorted(numbers)
# Out:
# [38,
#  47,
#  56,
#  61,
#  63,
#  68,
#  69,
#  76,
#  78,
#  88,
#  98,
#  106,
#  112,
#  140,
#  144,
#  182,
#  185,
#  199,
#  207,
#  208,
#  211,
#  237,
#  244,
#  261,
#  267,
#  277,
#  282,
#  289,
#  290,
#  306,
#  332,
#  343,
#  351,
#  379,
#  387,
#  395,
#  421,
#  435,
#  455,
#  459,
#  469,
#  476,
#  494,
#  496,
#  498,
#  530,
#  538,
#  543,
#  559,
#  568,
#  593,
#  621,
#  626,
#  652,
#  669,
#  669,
#  669,
#  674,
#  721,
#  732,
#  732,
#  743,
#  744,
#  759,
#  785,
#  791,
#  792,
#  795,
#  813,
#  822,
#  833,
#  844,
#  851,
#  876,
#  878,
#  887,
#  888,
#  889,
#  906,
#  912,
#  920,
#  929,
#  940,
#  948,
#  948,
#  951,
#  963,
#  973,
#  978,
#  980,
#  983,
#  1004,
#  1005,
#  1009,
#  1058,
#  1102,
#  1106,
#  1107,
#  1121,
#  1149,
#  1163,
#  1163,
#  1165,
#  1177,
#  1179,
#  1188,
#  1205,
#  1215,
#  1228,
#  1237,
#  1239,
#  1262,
#  1291,
#  1294,
#  1297,
#  1333,
#  1335,
#  1335,
#  1360,
#  1368,
#  1368,
#  1377,
# ...

# %%
from collections import Counter


text = 'abracadabra'
n=3
Counter(text).most_common(n)
# Out:
# [('a', 5), ('b', 2), ('r', 2)]
