# %%
#随机生成1万个整数，范围在0-10万之间，求其中每个整数出现的次数。并按照整数大小排序输出整数及出现次数。
import random,collections
A=[]
for i in range(10001):
    a=random.randint(0,100000)
    A.append(a)

B = sorted(A)
C = collections.Counter(B)
for c in C:
    print(c,C[c])
# Out:
# 19 1
# 41 1
# 45 1
# 56 1
# 73 1
# 99 1
# 106 1
# 140 1
# 151 1
# 152 1
# 160 1
# 166 1
# 169 1
# 184 1
# 185 1
# 205 1
# 210 1
# 216 1
# 228 1
# 232 1
# 233 1
# 240 1
# 250 1
# 253 2
# 255 1
# 256 1
# 272 1
# 276 1
# 285 1
# 291 1
# 299 1
# 325 2
# 349 1
# 355 1
# 368 1
# 374 1
# 416 1
# 427 1
# 436 1
# 438 1
# 443 1
# 444 1
# 466 1
# 469 1
# 481 1
# 487 1
# 493 1
# 509 1
# 546 1
# 554 1
# 576 1
# 602 1
# 604 1
# 620 2
# 629 1
# 632 1
# 638 1
# 641 1
# 650 1
# 662 1
# 668 1
# 685 1
# 697 1
# 722 1
# 743 1
# 746 1
# 748 1
# 770 1
# 778 1
# 779 1
# 782 1
# 794 1
# 801 1
# 811 1
# 818 1
# 827 2
# 856 1
# 891 1
# 912 1
# 914 1
# 936 1
# 941 1
# 953 1
# 962 1
# 963 1
# 970 1
# 980 1
# 995 1
# 1000 1
# 1013 1
# 1016 1
# 1038 1
# 1039 1
# 1043 1
# 1045 1
# 1054 1
# 1055 1
# 1056 1
# 1068 1
# 1074 1
# 1079 1
# 1096 1
# 1111 1
# 1120 1
# 1137 1
# 1151 1
# 1162 1
# 1184 1
# 1208 1
# 1220 1
# 1233 1
# 1237 1
# 1242 1
# 1244 1
# 1258 1
# 1270 1
# 1298 2
# 1337 1
# 1342 1
# 1345 1
# 1348 1
# ...

# %%
#对本任务中的语料.txt文件，抽取其5001-10000行存为test1.txt文件，写函数，可得到其与本任务中test.txt文件的共用字以及独用字（相关概念自行百度）


G=[] 
D=[]
str1=[]
str2=[]
table1=[]
table2=[]
with open(r'/Users/apple/Desktop/test1.txt', 'w+') as fw, open(r'/Users/apple/Desktop/语料.txt',encoding='gbk') as fr:
    num = 0
    text1=fr.read()
    text2=fw.read()
    for line in fr:
        if num >= 5001 and num <= 10000:
            fw.write(line)
            num += 1
        else:
            break

words = [word.split('/')[0] for word in text1.split()]
for word in words:
    if word not in table1:
        table1.append(word)


words = [word.split('/')[0] for word in text2.split()]
for word in words:
    if word not in table2:
        table2.append(word)


for m in table1:
    if m in table2:
        G.append(m)
    else:
        D.append(m)
            
print(G,D)
# Out:
# [] ['习近平', '新年贺词', '为', '人民', '点', '赞', '发表', '二', '〇', '一', '五年', '提出', '开弓', '没有', '回头', '箭', '改革', '关头', '勇者胜', '新年好', '“', '5', '、', '4', '3', '2', '1', '，', '新年快乐', '！', '”', '今天', '零时', '奥林匹克', '中心区', '主会场', '梦想', '辉映', '冰雪', '北京', '同心', '欢聚', '诚邀', '五环', '2015', '年', '新年', '倒计时', '活动', '举行', '。', '与此同时', '延庆', '八达岭长城', '分会场', '和', '张家口', '崇礼', '同步', '联动', '汇聚', '起', '三地', '万众', '对', '申办', '2022', '冬奥会', '的', '热情', '期待', '首席', '摄影记者', '蔡', '代征', '', '摄', 'A02', '版', '·', '要闻', '时事', 'A03', '新闻', '公积金', '贷款', '上限', '今', '起调', '至', '120', '万', 'A06', '呼格', '吉勒', '图', '父母', '获', '赔偿', '206', '万元', 'A11', '国内新闻', '一年', '大', '涨', '千点', 'A股', '完美', '收官', 'A15', '经济', '我们', '各级', '干部', '也', '是', '蛮', '拼', '国家', '主席', '●', '向', '南水北调', '40', '移民', '致敬', '我', '要', '伟大', '时间', '过', '得', '真快', '2014', '就要', '过去', '了', '正在', '走来', '在', '这', '辞旧迎新', '时刻', '全国', '各族人民', '香港特别行政区', '同胞', '澳门特别行政区', '台湾同胞', '海外侨胞', '世界', '各国', '各', '地区', '朋友', '们', '致以', '祝福', '令人难忘', '锐意', '推进改革', '啃下', '不少',
# ...

# %%
#统计本任务中的语料.txt文件，得到每一个词对应不同词性的频次，可表示为：{词:[('n',1000), ('v', 98)...],...}，即在dict对象中，key为词，value为列表，输出词频最高的50个条目  
from collections import Counter


def count_words_freq_dict(filename):
    words_freq_dict = {}
    
    with open(filename) as fh:
        for line in fh:
            words = [word.split('/')[0] for word in line.split()]
            for word in words:
                if word in words_freq_dict:       
                    words_freq_dict[word] += 1
                else:                             
                    words_freq_dict[word] = 1 
    return words_freq_dict


filename = r'/Users/apple/Desktop/语料.txt'
table = count_words_freq_dict(filename)

A=[]
for i, item in enumerate(table):
    print(item, table[item])
    A.append(table[item])
    A.sort
    for i in range(-1,-51,-1) :
        print(A[i])
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-7-9e3a4fe95f13> in <module>()
#      18
#      19 filename = r'/Users/apple/Desktop/语料.txt'
# ---> 20 table = count_words_freq_dict(filename)
#      21
#      22 A=[]
#
# <ipython-input-7-9e3a4fe95f13> in count_words_freq_dict(filename)
#       7
#       8     with open(filename) as fh:
# ----> 9         for line in fh:
#      10             words = [word.split('/')[0] for word in line.split()]
#      11             for word in words:
#
# ~/anaconda3/lib/python3.6/codecs.py in decode(self, input, final)
#     319         # decode input (taking the buffer into account)
#     320         data = self.buffer + input
# --> 321         (result, consumed) = self._buffer_decode(data, self.errors, final)
#     322         # keep undecoded input until the next call
#     323         self.buffer = data[consumed:]
#
# ...
