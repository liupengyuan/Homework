# %%
def get_ch_table(line):
    ch_table = []
    for ch in line:
        if ch not in ch_table:
            ch_table.append(ch)
    return ch_table


fh = open(r'/Users/apple/Desktop/idioms.txt',encoding='gbk')
text = fh.read()
chs = get_ch_table(text.replace('\n', ''))

print(len(chs))

import random

for m in range(0,100,10):
    random.shuffle(chs)
    for i in range(10):
        cha = random.choice(chs)
        con.append(cha)
    print(con)
# Out:
# 1251
# ['则', '戛', '真', '飞', '擎', '逢', '素', '灯', '阖', '地', '诸', '然', '正']
# ['则', '戛', '真', '飞', '擎', '逢', '素', '灯', '阖', '地', '诸', '然', '正', '烂', '哭', '辣', '投', '麟', '星', '四', '侃', '柯', '尾']
# ['则', '戛', '真', '飞', '擎', '逢', '素', '灯', '阖', '地', '诸', '然', '正', '烂', '哭', '辣', '投', '麟', '星', '四', '侃', '柯', '尾', '雁', '仪', '校', '心', '孜', '此', '听', '右', '驴', '中']
# ['则', '戛', '真', '飞', '擎', '逢', '素', '灯', '阖', '地', '诸', '然', '正', '烂', '哭', '辣', '投', '麟', '星', '四', '侃', '柯', '尾', '雁', '仪', '校', '心', '孜', '此', '听', '右', '驴', '中', '在', '果', '厚', '士', '悛', '踏', '瞥', '踏', '残', '椟']
# ['则', '戛', '真', '飞', '擎', '逢', '素', '灯', '阖', '地', '诸', '然', '正', '烂', '哭', '辣', '投', '麟', '星', '四', '侃', '柯', '尾', '雁', '仪', '校', '心', '孜', '此', '听', '右', '驴', '中', '在', '果', '厚', '士', '悛', '踏', '瞥', '踏', '残', '椟', '禽', '禽', '弓', '图', '鹤', '敌', '代', '索', '豁', '凌']
# ...
