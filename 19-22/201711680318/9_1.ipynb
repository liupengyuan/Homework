# %%
   
def run():
    #顺序查找法
    start_time = time.time()
    for word in list_C:      
        
        for i in range(100000):
            word_1 = list_B[i]
            if word == word_1:
                print(word,'位置：',i+1)
            i += 1
    end_time = time.time()
    all_1 = end_time - start_time
    print('time_1:',all_1)    




def runs():    
    #二分法
    start_time = time.time()
    for word in list_C:
        m = bisect.bisect_left(list_A,word)
        if word == list_A[0]:
            print(word,'位置：',1)
        else:
            if  m<100000:
                print(word,'位置：',m+1)
    end_time = time.time()
    all_2 = end_time - start_time
    print('time_2:',all_2)    
    

runs()
import time,random,bisect,copy
list_A = []
m = 1
for i in range(100000):
    lists = list_A.append(m)
    m+=1
list_B = list_A.copy()
random.shuffle(list_B)
    
for i in range(1000):
    number = random.randint(1,110000)
    list_C.append(number)
    
run()
print('---------------------------')
runs()
# Out:
# 84339 位置： 84339
# 56081 位置： 56081
# 11619 位置： 11619
# 20930 位置： 20930
# 14877 位置： 14877
# 5536 位置： 5536
# 37654 位置： 37654
# 89886 位置： 89886
# 12982 位置： 12982
# 34496 位置： 34496
# 17375 位置： 17375
# 34729 位置： 34729
# 81638 位置： 81638
# 19293 位置： 19293
# 41150 位置： 41150
# 70441 位置： 70441
# 13500 位置： 13500
# 97820 位置： 97820
# 80106 位置： 80106
# 73477 位置： 73477
# 57347 位置： 57347
# 63712 位置： 63712
# 53085 位置： 53085
# 30737 位置： 30737
# 79900 位置： 79900
# 70660 位置： 70660
# 55956 位置： 55956
# 16755 位置： 16755
# 55846 位置： 55846
# 58982 位置： 58982
# 70556 位置： 70556
# 59222 位置： 59222
# 24585 位置： 24585
# 65765 位置： 65765
# 73557 位置： 73557
# 20710 位置： 20710
# 33290 位置： 33290
# 90037 位置： 90037
# 25897 位置： 25897
# 34019 位置： 34019
# 87783 位置： 87783
# 75387 位置： 75387
# 42923 位置： 42923
# 79670 位置： 79670
# 58263 位置： 58263
# 83539 位置： 83539
# 4242 位置： 4242
# 41021 位置： 41021
# 78132 位置： 78132
# 10082 位置： 10082
# 71579 位置： 71579
# 25145 位置： 25145
# 71214 位置： 71214
# 16399 位置： 16399
# 36423 位置： 36423
# ...
