# %%
import random

#定义函数，统计字表
def get_ch_table(line):
    ch_table = []
    for ch in line:
        if ch not in ch_table:
            ch_table.append(ch)
    return ch_table


def get_my_table(file_name):
    with open(file_name) as fh:     #导入文件
        text = fh.read()
    idioms = text.split()
    chs = get_ch_table(text.replace('\n', ''))   #得到字表
    return chs

def my_file(n):
    chs = get_my_table(file_name)
    words = ''
    idiom = ''
    for i in range(10*n):
        idiom = random.choice(chs)
        words = words + idiom
    return words

def my_work():
    for j in range(1,11):
        words = my_file(j)
        print('文件',j,words)
        if j == 1:
            fh = open(r'C:\Users\czy\Downloads\1.txt','w')
            fh.writelines(words)
            fh.close()
        if j == 2:
            words =  my_file(j)
            fh = open(r'C:\Users\czy\Downloads\2.txt','w')
            fh.writelines(words)
            fh.close()
        if j == 3:
            words =  my_file(j)
            fh = open(r'C:\Users\czy\Downloads\3.txt','w')
            fh.writelines(words)
            fh.close()
        if j == 4:
            words =  my_file(j)
            fh = open(r'C:\Users\czy\Downloads\4.txt','w')
            fh.writelines(words)
            fh.close()
        if j == 5:
            words =  my_file(j)
            fh = open(r'C:\Users\czy\Downloads\5.txt','w')
            fh.writelines(words)
            fh.close()
        if j == 6:
            words =  my_file(j)
            fh = open(r'C:\Users\czy\Downloads\6.txt','w')
            fh.writelines(words)
            fh.close()
        if j == 7:
            words =  my_file(j)
            fh = open(r'C:\Users\czy\Downloads\6.txt','w')
            fh.writelines(words)
            fh.close()
        if j == 8:
            words =  my_file(j)
            fh = open(r'C:\Users\czy\Downloads\6.txt','w')
            fh.writelines(words)
            fh.close()
        if j == 9:
            words =  my_file(j)
            fh = open(r'C:\Users\czy\Downloads\6.txt','w')
            fh.writelines(words)
            fh.close()
        if j == 10:
            fh = open(r'C:\Users\czy\Downloads\10.txt','w')
            fh.writelines(words)
            fh.close()
        
    return 
        



file_name = r'C:\Users\czy\Downloads\idioms.txt'
my_work()
# Out:
# 文件 1 川履鹏兰蒙出驴莫越再
# 文件 2 藉舍腾晚邪笑湖形织状锤入处狗如峰香开胆固
# 文件 3 泰魅霸忾凿塞为荆祖惑遇豁岂武吹苒复仪沽琴校百庖取壮捉甚击穷解
# 文件 4 鹄得鬓颠翩结志侃蔚占杏禽华袖杜翁念子瞥差秋入扑顾通琳肓覆曲狼世声晨手败乌相噤教漫
# 文件 5 渴八蒙蒙见眈光道克见久始转愚缺也柯投果走视运梦贵在鲋角巴业物我放狱久赅报怒臼鳞进郑贤旷狭户齐膏白及穴
# 文件 6 缭弄状主秣口砖擎鹏枝悬谢杀位黔贼继曲副右庸赶扑精苛逝马缺驯惭急栗争兵能众名愎涂筚美到花泪巢帷夕庖向怙秒按叱群孜荆枪虚自东
# 文件 7 眸豹因性先正已诨通翻度途集悬羁化孜泾赵走狱革火凿寒处黔肉坤于河孟毛沓敬众尤锲浮联神穴泪银百马微苟象归怡砖路睫障肝茕染的盖占报掩项根颖制缚侃治
# 文件 8 交狱阔伦筚鼻穷是珠我饮鼠睛预仁鸟顾楚禹翁一涂缪孑玑睛中雪侯抛归衰潜刀色淡苛所营制枪下趋机叱线插莫刀墨维监荡怨坐名瀣断笑借徙怪桑财狐生发镜壁奇誉心烈程呈楚座闺垂蜃
# 文件 9 洋开编车牝郑帘肓鹤貂置秽静时羊点犬射栩滥防鼎养货貉旁狱老端倍船涂鬓闭深水盲甘烂淫驴情实造翻惭居总徙惊云曾和杨能顾驰潜报福带逑徒勿雅弥心纶睛晨韬仁岸石价谢友秦静乎独枉情再屋择呈惑醉俊
# 文件 10 唯掠西在耿苟亡寒照座讽婚蜜间堂唇固悚狼眼观豹本围巫薪提奂今东愎底顾朵提色陷炙蹴猿晕哭晦江补节殄童鸣益弟实立帝鸡杨笔怡循骥韦四巢铩烈霸浪公迷沉火愿曲石插仓驹晋荆兴线狡成琴营祥驯足关断厦织恒独懈弟怡踏循经
